# %% [markdown]
# # 크롤링 테스트

# %%
import os
import sys
import urllib.request

# %%
import pandas as pd
import numpy as np

# %%
# 함수로 정의 / txt 파일로 저장

import re
import json
import math
import datetime
import requests
import urllib.request
import urllib.error
import urllib.parse
from bs4 import BeautifulSoup

# %% [markdown]
# # 크롤링 실습

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# # 불필요한 내용 제거

# %%
data=pd.read_csv("/content/drive/MyDrive/outlier/심상정.csv")
#data=data['comment']
data
# Out:
#                                                  tweet  ...                                               link
# 0    이번투표는 남자는 안뽑을것같다 심상정이 다른 정치인들보다 클 린하다 옳은사람이다 이...  ...  https://twitter.com/ppappapdirara/status/14627...
# 1    심상정 안철수에 빠른 시일 내 조건 없이 만나자 양당체제 종식 기자회견서 안철수 김...  ...  https://twitter.com/no1nmh/status/146277465092...
# 2    단지 소수자인 자신을 심상정이 언급해주는 것만으로 감동받아 지지해주는 분들이 있는가...  ...  https://twitter.com/escrimeurk/status/14627742...
# 3    심상정이 안철수의 제안을 긍정적으로 수용한 듯한데 트위터 좌파 의 일부의 부정적 반...  ...  https://twitter.com/escrimeurk/status/14627735...
# 4     histopian 몇몇 철 안든 어린 의원들 치기나 미성숙이라고 생각했는데 정의당...  ...  https://twitter.com/EunieShin/status/146277347...
# ..                                                 ...  ...                                                ...
# 333   심상정 사적 욕망에 李 비판 인정욕구 강해 김어준 방송 심리분석 김어준이 사적 욕...  ...  https://twitter.com/dareto_tell_oo/status/1462...
# 334  양당제가 아닌 우리나라서 40년 묵은 두당정치 란 의미는 정의당 니들이 그간 국민들...  ...  https://twitter.com/GreedyWhiteBear/status/146...
# 335            심상정 이재명과의 단일화 가당치 않다 발언 등 분석 Pi4a6md9zV  ...  https://twitter.com/estarkkr/status/1462304136...
# 336  난 걍 되든 안 되든 심상정 찍을꺼야 저딴 똥에 내 투표권 행사할 순 없어 트위터리...  ...  https://twitter.com/ferret_in_nest/status/1462...
# 337  나도 심씨 싫어하지만 여니께 하던 짓거리를 똑같이 하고 있네 이것들은 정말 악마다 ...  ...  https://twitter.com/shoeRoof/status/1462302155...
#
# [338 rows x 4 columns]

# %%
# 한글과 띄어쓰기만 추출
import re
result=[]
hangul = re.compile('[^ ㄱ-ㅣ가-힣+]')
#hangul = re.compile('[^ \u3131-\u3163\uac00-\ud7a3]+')

for i in range(len(data)):
  result.append(hangul.sub('', data['tweet'][i])) 
result
# Out:
# ['이번투표는 남자는 안뽑을것같다 심상정이 다른 정치인들보다 클 린하다 옳은사람이다 이런말은 못하겠는데 적어도 대놓고 쌉소리는 않하잖여 ',
#  '심상정 안철수에 빠른 시일 내 조건 없이 만나자 양당체제 종식 기자회견서 안철수 김동연에 회동 제안 노회찬 없는 정의당 참 안쓰럽다 페미들만 잔뜩 모아 놓은 이상한 모습에 사욕 가득한 심상정 ',
#  '단지 소수자인 자신을 심상정이 언급해주는 것만으로 감동받아 지지해주는 분들이 있는가 하면 그저 겉멋에 들어 대학교 학술동아리를 졸업 후에도 꾸준히 하고 있는 머저리들도 있고 ',
#  '심상정이 안철수의 제안을 긍정적으로 수용한 듯한데 트위터 좌파 의 일부의 부정적 반응을 보니 역시',
#  '  몇몇 철 안든 어린 의원들 치기나 미성숙이라고 생각했는데 정의당 지도부의 총체적 난국이네요 그 내용을 다 들은 사람으로 심상정 후보 이해하는데 도움이 됐지 네가티브 아니라고 생각했는데 정의당엔 지도자가 없네요 ',
#  '외부인사 추천 허경영 안철수 심상정',
#  '사회심리연구소 함께 의 김태형 소장 년도 심상정 후보측의 요청으로 심상정이라는 인물에 대한 책을 공저함 그때 심리분석도 함께 씀 다큰 어른은 크게 변하지 않는다 는 얘기와 함께 년전 책내용 그대로 말한건데 왜 이제와서 딴지야 정의당은 니들도 이 책 안봤냐 ',
#  '이재명 윤석열이 저렇게 멍청하게 하는데도 말 잘하고 정책 잘내는 심상정이 밀린다는게 안 믿김',
#  '한국인분들 심상정 의원을 청와대로 보내 주길 바랍니다 ',
#  '투자의 입장에서 봐도 이재명은 오너만 해먹는 자본잠식 부실기업 윤석열은 대가리 빈 페이퍼컴퍼니 심상정은 평타정도 치는 강소기업인데 주식이고 코인이고 투자 광풍이 분 나라치고 망하지는 않을 강소기업에는 절대 투자를 안하려는 꼬라지가 너무나 한국 수준에 딱 맞는 상황인듯 ',
#  '민주당 이명박과 남자 박근혜가 대선후보라는 초유의 사태에서 둘 다 최악의 선택지임에도 굳이 심상정은 고려조차 안한다는거 이성적으로 생각할 때 이재명과 윤석열은 진짜 좆되는 선택이지만 심상정은 최소한 최악은 피할 수 있는데도 선택을 안함 그게 한국 국민 수준을 보여주는 방증임 ',
#  '  심상정아줌 치매',
#  '이런 절호의 기회조차도 안철수 따위와 연대를 한다며 똥볼을 차고있는 정의당에 한심한 애도를 표한다 목마르다고 바닷물을 마시는 미련함  ',
#  '정의당은 지들 밥그릇을 걷어차는구나 심상정이 이제 페미당으로 만들어서 국힘당에 갖다바치냐 노회찬 살아계셨음 어쩔뻔 했니',
#  '과거 전두환이 정의사회 구현이라는 표어를 사용했는데 심상정의 정의당이 전두환의 정의사회를 닮았다',
#  '심상정 안철수에 빠른 시일 내 조건 없이 만나자 민주당에 기생하며 다른 군소정당 죽이는데 앞장서더니 이제 와서 ',
#  '심상정은 아무말 대진치 해도 책임질 일이 없으께 얼마나 좋냐 암껏 시 부러도 되고 ',
#  '아니 진짜 여자들 직장인들만 심상정 찍어도 심상정 될 것 같은데 빨강파랑이 둘 다 최악인데 마음에 안 들지언정 차악인 사람을 뽑는 게 낫지 않겠냐고',
#  '성심당축제도햇겟다 심상정 가보자고',
#  '어제  스트레이트 지난주랑 같은   이고 이번주는 걸그룹 오디션 프로 땜에 결방하고 다음주에 한댄다 폐지각인데 그리고 피디수첩 내일은 위드코로나 편이고 분토론은 심상정 특집이고 패널은 심상정 장하나 성한용 김종혁이란다 노잼 될듯 ',
#  '   노회찬은 심상정이아니까요 어쩌면 노회찬은 정의당의 막가파에 걸림돌이었을까 ',
#  '  심상정은 왜 윤석열에게 러브콜을 했는가 이런거 주제로 하는데 배진교가 나올리 있나 심상정 흑화 그것이 알고 싶다 배진교는 빼엑 ',
#  '  심상정 심리분석을 문제삼았나보네요 분석이 정확해서 찔렸나보네 욕구를 숨기던 사람이 속마음 틀키면 이럴수 있겠다 싶네요 ',
#  '심상정 나왔어봐 대본보다 더 잘했을듯 ',
#  '안철수와 심상정이 친구도 아니고 심지어 정치성도 판이하게 다른데 다른 편끼리 가끔은 협력했다가 떨어지는 건 기본적인게 아닌가요 ',
#  '아니 징짜 다뵈 심상정 인물 비평땜에 그런거야 우와 밴뎅이 소갈딱지네 푸하하하하',
#  '  빗나간 종부세 전망 대상자 만 명 육박에도 여전히 일부만 해당  국민을 속이는 데만 도가튼 문재인 사기꾼 정부 문재인은 진즉에 탄핵을 당했어야        ',
#  '음 윤석열이 될 거 같아 음 그냥 원래 트위터 여론이 남한 전체의 여론은 아니었잖아 그냥 음 윤석열이 될 거 같아 안되었으면 좋겠다 심상정씨가 되면 좋겠다 ',
#  '  문재인정부 시작할 때 새누리는 역사속으로 사라지고 민주당과 정의당 두 정당체제로 갈 거라고 하는 사람 정말 많았는데 정의당이 경선을 날로 해먹으면서 정의당은 아웃 오브 안중되버림 좀 잘 하던가 ',
#  '꿈은 꾸는게 당연하지요 그리고 꿈을 나눠줘야하는데 노회찬 사후 정의당의 색깔이 너무 많이 퇴색되었다 영상 심상정이 또 다시 대통령에 도전하는 이유 출처 시사 네이버 뉴스 ',
#  '뭘 고민해 심상정 있잖아',
#  '와아 쉴드칠껄 쳐라 심상정에 표 분산 막겠다고 스토커처럼 하는 것도 웃기지만 비판 자체가 딸 어쩌고 완전 코미디 이재명이 뭐라고 다들 왜 이러지',
#  '시발 진짜 비참한 포인트는 저런 새끼가 정말 대통령이 될지도 모른다는 거지 심상정 안철수는 가능성이라도 없는데 저새끼는 세상에 시발 ',
#  '근데 이건맞지 심상정가자니까',
#  '  몇 년째 심상정후보에게 투표했늨데요 계속 지지할거고요 여튼 소형원자로건에 대한 심상정씨의 주장에는 동의하기 힘듭니다 다시 알아보셨으면 합니다 ',
#  '  후보님 답답합니다 역사의 서구민주국가도 아닌 한국 땅에서 진보당이 뻗을다리가 있나요 계란으로 바위치기 이해합니다만 답답합니다 백성은 진보당보다는 힘있는 진보세력을 더 원할듯 당합당해서 가 권력을 얻은것처럼 민주 열린 정의로 합쳐서 미래권력을 잡으세요 당원을 설득하세요',
#  ' 할머니 할아버지 윤석열 뽑지 마세요 이재명 뽑지 마세요 심상정 뽑아주세요 윤석열이나 이재명 둘 중 하나가 대통령 당선되면 그때부터 손녀 죽어간다 손녀 인생 망해요',
#  '  써글 심상정이 한티 전화오면 나 그 상품에 관심읍따 라고 할 꺼임 광고성 전화는 딱 싫어 ',
#  '월 주차 여론조사 지난 주에  넘게 벌어진 걸 보고 대중과 나의 판단은 이렇게나 벌어졌나 싶었는데 이번에 그 간격이  로 줄어들어서 월 주차가 기다려진다 심상정 아주머니는 페미니스트 대통령 야심차게 꺼내들었는데   빠짐 그걸로 외연확장 안된다니까 골목대장 하고 싶은 모양 ',
#  '심상정이 젤나은데',
#  '신지예씨가 안철수의 노동정책이 심상정과 가깝다고 해서 찾아봤다 제일 위에 뜨는 기사다 저는 지난 대선 때 노동시장의 양극화를 줄이려면 비정규직의 정규직화보다는 비정규직의 직업 안정성과 보수를 높이는 쪽으로 노동개혁을 해야 한다고 했다 ',
#  '원전이 안되면 대안을 제시하는 게 정당이지 무조건 나빠요 쟤네 뭐 모르고 떠들어요 아시죠 위험한거 이런 선동뿐임 도대체 심상정은 컨텐츠도 없이 얼마나 오래 해먹는거임 ',
#  '  심상정 심리분석 땜에 삐진건가요 ',
#  ' 현장영상 심상정 안철수 조건 없이 만나자 제지대 공조 시동     덜나쁜사람을 뽑는 차악선거보다 더 나은 대안이 되지 않을까 싶지만 가능할는지 ',
#  '  심상정 전화통 오지않았어요 ',
#  '종인이가 상정이랑 만나면되겠군 김종인 심상정 허경영 안철수 환상의 듀오다 ',
#  '  감각이 많이 떨어졌다 노회찬없는 정의당 저물어 간다 ',
#  '심상정 안철수에게 만나자 제지대 공조 제안  심상정은좌파인데 좌파하고 왜손잡아 안철수가 좌파당후보하고 손잡으면안되는거야',
#  '심상정이 돼도 당연히 여가부가 없어지지 똥꼬충트랜스정신병들무지개법썩흐응딱련들도 정의로운세상을위해 보살펴줘야하니까',
#  '안티백서 지방차별질하는 심상정을 왜 올려치나요 ',
#  '해묵은 생존법 파트너 바꿔가며 다 해봤고 정당이념 다른 물리적 합당도 안된다는거 알았고 유시민은 이것저것 다해보고 더이상 할게없다고 정치안하는 거고 심상정은 자기가 하는게 진보의 역사라며 남아있는거고 ',
#  '방송사고 왜 실트인가 했네 근데 윤석열이 멍청이인걸 이재명을 올려친다고 심상정을 뽑으세요 님들아 왜 고만고만한 놈들 두고 고민하고있어',
#  '심상정 안철수 빠른 시일 내 조건 없이 만나자 이 윤에 쏠린 대선판 깨기 위한 제지대 연쇄 회동 오마이뉴스 사주팔자 에 무슨 살 이 끼면 저러는 걸까 살다 첨 명리학에 관심 셀프사주를 보니 살 귀인 귀인 귀인이란 것도 있고 상당히 맞는 것 같아 깜놀 ',
#  '이번에도 완주 할 생각이 없나보네 심상정 안철수 조건 없이 만나자 제지대 공조 제안 ',
#  '심상정 전략과 전술을 뒤바꾸고 있네요 먼저 노동통일생태세력과의 연합에 기초하여 이재명 김동연 안철수 중 상대적 진보측과의 연대를 모색해야 하는데 아무 기준도 없이 권력욕만 남는 양당 타파 제지대를 먼저 꺼내다니 ',
#  '심상정 안철수에 빠른 시일 내 조건 없이 만나자 출처 한겨레 네이버 뉴스  드디어 심상정이 미쳤다 완전 미쳤다 어디 손내밀때가 없어서 안철수에게 손을 내민단 말이냐 다시는 심상정을 쳐다볼일은 없을 것이다 미쳐도 더럽게 미쳤구나 안철수와 연대라니 ',
#  '  매경 심상정의당 장씨 최악의 조합',
#  '대한민국의 문제는 양당체제에서 온 것이 아니다 당이 여러개면 그럼 나라가 좋아지나 근데 어쩌나 지금도 당이 여러개인데 자기들이 못해서 지지율이 안나오는건데 그래서 한다는 짓거리가 안철수랑 손을 잡나 심상정이 원하는 건 본인이 인정받고 소속정당이 커지는 것 뿐 ',
#  '심상정은 어쩌다가 저렇게 됐나 ',
#  '물리적 나이만 먹은 유아독존 소아 심상정과 안띨수 ',
#  '심상정 후보가 양당체제 종식을 위한 제지대 공조 를 위해 우선 안철수 후보와 조건 없이 만나자고 제안했다 심 후보는 안철수 김동연 후보뿐만 아니라 소수정당과 정치세력 시민사회 등을 만나 제지대를 넓혀가겠다는 구상이다 ',
#  '님은 심상정뽑을거잖아요',
#  '심상정뽑아',
#  '좋은 결과를 얻을 가능성은  미만으로 예상한다 그렇지만 시도할 가치는 있다고 본다 에 손 내민 심상정 제지대 공조 시작 세계일보 ',
#  '이 계정 마음 찍는 계정으로만 쓰는 중인데 요즘 심상정 글 존나 싸질러서 대선때까지 심상정무새될듯 하지만 바카새끼들잇 ',
#  '누구 뽑냐고 하지 말고 심상정 심상정 있잖아 후보가 윤석열 이재명 두명뿐이냐고 여기서도 심상정 스루하지 말라고 ',
#  '아니 왜 그런 간담회를 했냐고 그것만 안 했어도 진짜 한치의 고민도 없이 심상정 찍는데 이제는 뭐랄까 시발 여자를 인간 대접해주는 후보 찍는다 고 심상정에게 표를 던져도 그리 개운하진 않은 기분이란 말이지 ',
#  '씨발 진짜 너무 좆같은 일이다 근데 그 와중에 심상정은 안티백서 같은 간담회나 했고 하 ',
#  '  심상정님 바쁘신데 죄송하지만 랜선 싸인을 받고 싶은데 괜찮으실까요 사진으로 올려주시면 영광스럽게 받겠습니다 ',
#  '선거 직전까지 최대한 나발을 분다 최대한 떠들어놓은 뒤에 문죄인패거리와 붙어먹는다 이게 심상정의 인생이지 예외란 없다 ',
#  '심상정이 년의 안철수도 아니고 년의 안철수에게 만남을 제안하는 뉴스를 접해야 되는 난 무슨 죄인가 ',
#  '심상정이 오늘 안철수랑 손을 잡겠다고 했는데 안철수라는 정치인이 정치적 방향성이 달라서 불안하네 그래도 몇 일 전에 안철수가 꺼냈던 모병제정책 같은 걸 보면 흥미를 느꼈을지도 모름 진보 안에서만 이야기를 나눈다면 고인물이 될 거라고 생각했을지도 모르지 ',
#  '  쯧쯧 심상정이도 이제 맛탱이가 갔구나 ',
#  '지인이 심상정은 무서운 사감누나 같다 그러길래 앞에서 웃고 말았다 홍준표는 웃기고 윤석렬은 도리도리이고 이재명은 김부선으로 불리고 그게 한국 보편적 정치수준이다 ',
#  ' 심상정 워맨스가 필요해 출연 정치인 아닌 둘째며느리의 삶 공개 ',
#  '나 일하는 곳 이재명이 되면 사라지는 곳이고 윤석열이 되면 조오오오오오오오오오오오오오온나 바빠지는 곳이라 둘의 인성이던 정책이던  다 필요없고 둘다 안되면 좋겠고 심상정이 되면 좋갰다',
#  '심상정 안철수 조건없이 만나자 제안 참새와 메추라기가 만나면 무슨 소리가 날까 참 궁금하다 ',
#  '미쳐도 곱게 미쳐야지 숙명이 양당체제 종식인데 노동자 기반으로 한 당은 왜 들어가서 허송세월 했는지 결국 안철수 심상정 양당체제 종식 나의 숙명 안철수에 만남 제안 ',
#  '두놈 다 답이없음 사표가 되더라도 나는 심상정 뽑아 ',
#  '  저 올해 첫 투표하는데 심상정 후보님을 뽑을 수 있게 되어서 매우 영광이에요 ',
#  '말도 안되는 소리들 좀 작작 하고 자기 길을 가라고 안철수 김동연이랑 연대하는 심상정을 누가 보고싶어하는데 ',
#  '근데 진짜 이번 대선 두고 카레맛 똥  똥맛 카레 비유 그만 해야 내 기준에선 이재명 먹기 싫은 음식 윤석열 음식이 아님 심상정 과발효된 음식 안철수 음식이었던 것 인데 ',
#  '  와우 그럼프로로 심상정 대통되는겨 철수는왜봐 그럼 프로로 대통해볼라꼬 ',
#  '제가 안철수 대표를 지지할 수 없는 가장 큰 이유가 정치 혐오를 팔아 지지세를 불린다는 점이었습니다 그렇기에 심상정 의원의 이런 행보는 참으로 안타깝네요 ',
#  ' 심상정 은 문재인과 민주당과 짜짝꿍해서 대한민국을 아작내는데 일조해 놓고 이제와서 무슨 낯짝인지 기생충정치',
#  '역시 심상정의당 김태형씨가 이미 책에 썼던 내용이라고 하던데 자기가 써달라고 부탁해놓고 책도 안읽었나봄 더 욕먹은 다른 후보들도 가만히 있는데 심상정의당만 난리네 ',
#  '아 이대로라면 모자걸이가 오케이 심상정 해야되는데 현실은 이재명 이 될 확률이 높다는게 하 ',
#  '정의당 하는 짓이 그렇지 다스뵈이다는 지상파 방송 아니고 인터넷 방송 방송한 자료는 예전에 심상정이 해달라 해서 한 심리분석 후 낸 책이고 그 책에 자르고 안실린 내용 덧붙여 내보낸 인터넷 방송 일 뿐인 것을 정의당 배진교 명비어천가 김어준 방송 보이콧 ',
#  '심상정이 찍을려면 아프가니스탄 난민을 찍겠다 ',
#  '홍준표 국민의힘 의원이 공약으로 내세웠던 공영방송 통폐합 및 민영화에 대해서는 이재명 심상정 안철수 후보가 반대했고 윤석열 후보가 조건부 찬성 입장을 냈다 홍준표 이재명 심상정 안철수 윤석열 국민의힘 공영방송 공영방송민영화 언론중재법 언론 ',
#  '심상정 유시민 그들의 민낯 앞에선 정의로운척 하면서 뒤에선 온갖 더러운 짓을  진보당 이석기의원석방 진보당해산무효',
#  '헤어지고 심상정캠프 들어가는 레즈비언 어떻게생각함',
#  '  쪽수가 적은것은 간판만 정의당이지 백성들에게 정의로운 당으로 비쳐지지 않앗기 때문',
#  ' 연예 심상정 정의당 대선후보 워맨스가 필요해 출연 ',
#  ' 심상정 이재명 비판 사욕 탓 에 정의당 김어준 방송 보이콧 다음 뉴스 ',
#  '김어준이 사회심리학자 를 불러서 심상정이 권력욕에 찌들었다고 비난했는데 적어도 이 부분은 김어준이 잘못했고 그 사회심리학자는 자격이 없음 언제 사회심리학이 개개인 심리 추측 궁예질 하는 학문이었나 ',
#  '진보의 대모 심상정 후보께서 성소수자의 격리와 온갖 의제에서 보수적인 입장을 고집하시고 제보 조작 사건을 일으킨 국민의당의 안철수에게 손을 내미는군요 거대 양당 프레임에 빠지셔서 진보고 나발이고 이것저것 다 주워드시는 모습 보기 좋습니다 지금 좀 후달리긴 하죠 ',
#  '  나라에 인재가 이리도 없습니까 누굴 지지하고 투표를 합니까 대통령을 뽑자고 하는건지 범죄 대통령을 뽑자고 하는건지 정당을 떠나 국민을 위한 정치인은 없는거 같습니다 지들 밥그릇에 밥알 한톨 안떨어 뜨리려하는 자들이 무슨 국민들을 대변 한다고',
#  '양당체제 종식을 위한 제지대 공조를 시작하겠습니다 ',
#  '두 당 중에서만 집권할 수 있는 체제 이제는 끝내야 합니다 이번 대선은 두 가지 메뉴 중에서만 선택을 강요당해온 국민들이 이 딜레마를 해결하는 대선이 되어야 합니다 기후위기와 극심한 불평등 그리고 누적된 차별을 해결하기 위해서 과거가 아닌 미래로 가는 정권교체를 해야 합니다 ',
#  '심상정을 제외하곤 대선주자들부터 당대표와 선대위까지 이른바 이대남 표심 잡기를 위해 되도 않는 짓거리들을 앞다퉈하고 있다 그 와중에 홍준표는 주제에 무슨 청년정치 를 시작하겠다고 하질 않나 정말 이제 이 나라에서 청년이라는 단어와 세대는 심각하게 오염된 거 같다 ',
#  '심상정은 주일제도 해준다 그러고 포괄적 차별금지법도 해준다 그러고 페미니스트라고 그러고 안뽑을 이유가 무엇 ',
#  '이재명이 대남에게 구애하는건 절대있을수없지만 안철수에게 심상정이 구애하는건 아무 상관없는 일이시겠지 ',
#  '심상정 찍자고 열내고 있는데 뭐 안철수랑 합친다고 ',
#  '심상정 유시민의 민낯 그리고 이정희의 진심  진보당 이석기의원석방 진보당해산무효',
#  '  우주의 힘이 도와서 이재명 구속되거나 심상정이 뽑히지 않는다면 같이 포르투갈가요 본상',
#  '민주당 놈들은 특히나 심상정 후보 찍는 여자들 표가 마치 원래 지들 표인양 생각하나본데 웃기지마 여자들 눈에 민주당이나 국힘당이나 전부 납작하거덩 ',
#  '심상정 후보가 저 두 당 차이보다 배 많은 표를 가져가면 좋겠다 두 당 놈들 누가누가 여혐 잘하는지 시합하는데 그에 맞게 처리해줘야지 ',
#  ' 오마이포토 이재명 윤석열부터 허경영까지 대선주자 총출동 김영삼전대통령추모식 허경영 심상정 이재명 윤석열  오마이포토',
#  '심상정 정의당 대선후보 전격 출연 리얼한 며느리 워맨스 공개  출처 나인스타즈 네이버 포스트 심상정 며느리워맨스 워맨스 워맨스가필요해 대선후보 심상정예능 정의당',
#  '단순히 거대양당 이 아니라는 이유로 심상정과 안철수 김동연을 함께 묶는 것이 옳은가 정당들의 구체적인 포지션을 빼고 간략하게 이야기하자면 수직선에서 심상정은 민주당의 좌측에 위치해 있고 안철수와 김동연은 민주당보다 우측 국힘보다 좌측에 위치해 있다 이들이 연합한다고 해서',
#  '우주의 힘이 작용해서 이재명이 사퇴하거나 심상정이 뽑혔음 좋겠다 제발',
#  '정의를 완전히 없애버린 일등공신 심상정 양당체제 종식 위한 제지대 공조 오늘부터 시작 안철수 만나자 다음 뉴스 ',
#  '   성심당과 심상정에서 무슨 공통점을 찾겠다구 ',
#  ' 김어준의 다스뵈이다 회 심상정 심리분석 도이치모터스 최순실 어게인  출처 ',
#  '결국 심상정 이야기 하다 고기뷔페 가는걸로 결론내고 후식으로 딸기케익 먹기로 함',
#  '  안타깝다 양당체제 종식을 안철수랑해서 무슨 의미가 있을까요 제발 정신좀 차리시죠 심상정의원님 ',
#  '양당체제 종식을 왜 정의당 국민의당 양당이 함 기본소득당이랑 하면 안돼 안철수 조건없이 만나자 심상정 양당체제 종식 연대 제안 사진관 다음뉴스 ',
#  ' 연예 정의당 대선후보 심상정  워맨스가 필요해 출연 월 중 방송 ',
#  '심상정아 겨우 연대할 녀석이 안철수냐 너를 옛날에 지지 했던 노동계 에게 자괴감 들게 하지말고 이제 됐으니 정치판에서 떠나라 너의 노욕이 보기 흉하다 ',
#  '다스뵈이다에서 심리학자가 분석한 심상정을 보니까 다 맞는 말인 것 같던데 심상정은 그런 걸 못참는구나 원래 거울보고 맘에 안들면 한동안 속상한 법이지 그 심리학자가 심상정측에서 심리분석을 해달래서 분석한 책도 냈다던데 한번 들어봐라 틀린 말 하는지  ',
#  '  지랄났다 진짜 야 정의당은 이래도 심상정 대표님이 말하셨던 난민사태가 자기 당에서 안 남 독하다 독해 ',
#  '성심당에서 심상정을 뽑아내는 건 억지스러움 ',
#  ' 김어준이 잔대가리 겁나게 굴린 게 원인이겠지 아무리 컨벤션 효과가 걷힌다고 하더라도 퍼 차이나던게 무슨 주말 지나고 이재명과 윤석열이 정확히 동일스코어로 된다는게 말이 되나 그 사이 큰 사건도 없었는데 앞으로 이 여론을 바탕으로 심상정 사표론 본격적으로 나올 듯 ',
#  '  안철수은 제지대 심상정은 제지대가 어울릴 듯',
#  '안철수는 국힘당 바라보고 심상정은 안철수 바라보고 참 좋은 풍경이야 ',
#  '심상정의 최대의 실책이 될 텐데 ',
#  '심상정도 안철수 맛 좀 보셔야지',
#  '대화 나누는 이재명윤석열과 심상정안철수 ',
#  '심상정은 안철수 만나러가고 이수정은 윤가놈 손잡으러가는데 왜 민주당 지지자를 때리지 또라이들인가',
#  '  심상정 안철수',
#  '심상정 후보는 안철수 후보에게 빠른 시일 내에 조건 없이 만나 의견을 교환하자 고 말했습니다 ',
#  ' 심상정 정말 꼭 완주하세요',
#  '심상정이 안철수를 만나자고 했단다 씨벌 정색 ',
#  '심상정은 안철수의 길을 가는군요 결말도 비슷할 겁니다 ',
#  '부고외엔 무관심 정치인 아직 살아있었구나 몰랐네 제지대 회동 나서는 심상정 안철수에 첫 만남 제안 양당체제 종식 연대하자 ',
#  '제지대 회동 나서는 심상정 안철수에 첫 만남 제안 양당체제 종식 연대하자  ',
#  '심상정 안철수 조건 없이 만나자 제지대 공조 시동 ',
#  '찐으로 잘하는 여성작가만 피해를 보는거다 폐미의 잘못된 인식으로 인해 아주 폐미는 정치인들한 농락당하기 딱 좋은 것도 아니고 지네편들어주이 얼쑤 좋다 이러네 심상정 절대 뽑음 안댐 진짜로',
#  '안철수의 정책연대 제안에 심상정은 조건없이 만나자고 화답 양정당이 서로 싸우면서 밀어주고 끌어주며 너한번 나한번하는 양당정치를 이번에는 바꿔야 한다 쌍특검 연대부터 출발합시다 ',
#  '출처 중앙일보 제목 김어준 방송 나온 심리학자 심상정  비판하는건 심리문제 원희룡 씨 부인이 한 얘기 가지고 그 난리를 쳐놓고 방송 나와서 이재명 비판한 심상정 심리를 따진다고 진짜 뭐하는 정신 나간 놈들이세요 ',
#  '  심상정은 자신이 결국 이 정도밖에 안된다는 것을 근 년동안 두고두고 보여주는 중',
#  '제 지대 반문연대 그래 봐야 반문연대 중대 안철수 조건없이 만나자 심상정 양당체제 종식 연대 제안 사진관 다음 뉴스 ',
#  '찐남 푸포부친 이번 대선 심상정 뽑는다 선언하심 ',
#  '심상정이나 신지예가 말하는 제지대 통합이 과연 얼마나 진보적인가에 대해 나는 도통 이해를 할 수가 없다 차라리 해묵은 진보정당 대통합선언이 훨씬 변혁적이며 성공가능성이 높을 것이다 이제는 은퇴를 앞둔 심상정의 얕은 수나 새 시대의 정치를 이야기 하면서 방법론 적으로는 늙은',
#  '김재연 심상정 진보여성 단일화면 명분이라도 있지 그건 싫은거지 ',
#  '심상정 제지대 공조 시작  조건없이 만나자 출처 동아일보 네이버 뉴스 ',
#  '구경이 보다가 심상정 아들 왜 심씨아님 처럼 용국장 아들들 왜 용씨 아님 하고있던 나',
#  '성심당이랑 로오히 콜라보요 심상정이라도 나옴 진짜근본없는츠윗 ',
#  '윤석열은 막아야 근데 디씨갤주인증한놈을 뽑을수는 역시소신투표를 근데윤석열은막아야씨발 근데씨발이재명을뽑을수는 역시답은심상정밖에 근데씨발',
#  '  속 시원했던 분이 왜 그렇게 뜬구름만 잡고 답답해지셨을까요 역대급 비호감 정당 이래요 당이 왜 침체됐는지를 알아야지요 가장 큰 문제는 내부에 있어요 일례로 류 정 장 영 같은 철부지들 하는 꼴만 봐도 그래요 소꿉장난 놀이터로 바꾸실 모양 정의당은 아직 뼛 속 부터 치열해야 합니다 ',
#  '믿고 싶은 것만 믿는 정치가 본인들이 비판하던 팬덤 정치와 어디가 그리 다르답니까 심상정의 진보 중도 단일화 이데올로그세요 ',
#  '제발 헛소리들 좀 하지 마세요 심상정이 노동개악 하기로 했나요 신 대표는 정책적으로 보면 최근에 안철수 후보가 냈었던 노동 정책이나 심상정 후보가 말씀하시는 환경 정책이나 여성 정책 이런 것들이 그렇게 많이 상이하지 않다 ',
#  ' 연예 며느리 심상정은 어떤 모습 워맨스 출격 ',
#  '안 그래도 심상정 이번에 별로 뽑고 싶지 않은데 이런 식으로 안 뽑아야 할 이유를 하나씩 늘리고 있네 안철수랑 왜 만나 아예 갈 길이 다른 사람이구만',
#  '이제 심상정을 안뽑을 이유가 생긴 것 같다 참 대단하다 안철수랑 조건없이 만나자고 참 ',
#  '이렇게까지 심상정을 공격한다고 인두껍을 쓰고 너무하네 같은 진보를 표방하는 처지에 근데 심상정이 박빙으로 흐르면 또 양보하니까 저지랄들인것 김어준 방송 나온 심리학자 심상정  비판하는건 심리문제 ',
#  '심상정이나 신지예나 제지대 같은 소리 못 놓는구나 양당체제 종식시키자 심상정 안철수에 만남 제안  ',
#  '김어준은 왜 심상정에 집착 할까 ',
#  '심상정',
#  '심상정 페미니스트 대통령 내걸고 대 여성 표심 잡는다 ',
#  '안철수 그리고 허경영 만나세요 거기가 당신 수준이에요 안철수 조건없이 만나자 심상정 양당체제 종식 연대 제안 사진관 다음뉴스 ',
#  '모지리년 심상정 안철수 빠른 시일 내 조건 없이 만나자 다음 뉴스 ',
#  ' 류원실 의원실 선물로 들어온 대전 명물 심상정 ',
#  '김어준 방송 나온 심리학자 심상정  비판하는건 심리문제 ',
#  '심상정 안철수 조건 없이 만나자 제지대 공조 시동 출처  네이버 옴마나 거기까지 가겠다고 ',
#  '윤석열은 말 할 필요도 없으니까 패스 여돌은 이재명 뽑아도 말 많이 나올 거 같고 심상정 뽑아도 욕 먹을 거 같음 근데 남돌은 이재명 뽑아도 좋은 말 나올 거 같고 심상정 뽑으면 엄청난 페미년으로 둔갑 돼 잇을 거 가틈',
#  '심상정 안철수 조건 없이 만나자 제지대 공조 시동  한번 심상궁은 영원한 심상궁 만날 필요없다 ',
#  '갈때까지 갔구나 심상정 심상정 안철수 조건 없이 만나자 출처 국민일보 네이버 뉴스 ',
#  '심상정도 거기서 거기니까',
#  '  치매가 아니라 그냥 무식한거예요 토론 기대됩니다 심상정만 딴지 안걸면 ',
#  '이재명이 싫어도 윤석열은 아니지 차라리 안철수나 심상정이면 납득이라도 할 듯',
#  '난 이재명이 싫은데 이재명을 뽑아야 할 거 같아서 괴롭다 이게 아니라 심상정을 뽑고 싶어서 괴로움',
#  '  심상정 술이 아니거나 물탄 술 ',
#  ' 이재명 썩은 술 윤석열 덜 익은 술 안철수 섞은 술 그 와중이 심상정 언급 없음 ',
#  '시대를 관통하는 명의 거장들 그리고 윤석열의 용인술은 예술처럼 느껴진다 국민과 국가를 위한 윤석열호의 무한질주가 궁금하다 윤석열 대통령 후보 국민의힘 이재명 민주당 안철수 국민의당 심상정 정의당 ',
#  '시대를 관통하는 명의 거장들 그리고 윤석열의 용인술은 예술처럼 느껴진다 국민과 국가를 위한 윤석열호의 무한질주가 궁금하다 윤석열 대통령 후보 국민의힘 이재명 민주당 안철수 국민의당 심상정 정의당 ',
#  '시대를 관통하는 명의 거장들 그리고 윤석열의 용인술은 예술처럼 느껴진다 국민과 국가를 위한 윤석열호의 무한질주가 궁금하다 윤석열 대통령 후보 국민의힘 이재명 민주당 안철수 국민의당 심상정 정의당 ',
#  '정의당 심상정후보가 드디어 미쳤구나 갈수록 아리송한 정치성향을 보이는 안철수후보를 껴안고 싶어하는 걸 보니 제지대가 아니라 정의당의 정치성향과 당원들의 정치역량이 문제가 아닌지 ',
#  '한국사회여론연구소  이 후보   윤 후보  를 기록 이 후보는   포인트 상승하고 윤 후보가   포인트 하락하면서 지지율이 붙었다 심상정 정의당 후보는   안철수 국민의당 후보는  김동연 전 경제부총리는   였다 ',
#  ' 한국사회여론연구소  가 일부터 일까지 이틀 동안 차기 대선후보 지지도 를 물은 결과 윤석열 후보는   이재명 후보는   로 조사됐다 심상정 후보는   안철수 후보   김동연 후보는   의 지지율을 기록했다 ',
#  '  분토론 심상정 후보 전격 등장 일시 월 일 화   중계  진보정치 년의 내공으로 국민들과 만납니다 많은 시청 부탁드립니다  ',
#  ' 채용 제대 대통령 선거 선거대책위원회 채용 공지 정의당에서는 제대 대통령선거에서 심상정 정부를 함께 만들어갈 인재를 찾고 있습니다 정의당에 애정을 갖고 계시는 분들의 많은 지원을 바랍니다  링크  ',
#  ' 심상정 국민의당 찍고 국민의힘 간다 ',
#  '심상정  이 너  좀 만나자는데 ',
#  '이 여자가 심상정 안철수 빠른 시일 내 조건 없이 만나자 심상정 정의당 안철수 김동연 제지대 이경태 기자 ',
#  '심상정 정의당 대선후보가 안철수 후보에 조건 없는 만남을 제안했습니다 뜨겁게 환영합니다 심 후보는 오늘부터 제 지대의 공조를 시작하겠다 며 안철수 김동연 후보는 출마 선언을 통해 기득권 양당 정치의 틀을 깨야 한다고 했는데 뜨겁게 환영한다 고 말했다 ',
#  '무고죄 강화란 워딩만으로 여혐 운운하는 것도 코미디 윤석열 이수정이 실제 정책으로 만들어낼 변화나 시너지나 기대하시라 심상정의 득표율 올리면 압박이 될거라는 마이너한 순수도 좀 버리고 ',
#  '심상정 안철수 조건 없이 만나자 공조 제안 다음 뉴스 ',
#  '심상정 안철수 조건 없이 만나자 다음 뉴스 ',
#  '심상정 안철수 빠른 시일 내 조건 없이 만나자 다음 뉴스 ',
#  '심상정 이제 진짜 미쳐돌아가는 구나 안철수와 조건없이 만나 안찡이랑 잘 놀아봐라 정의당엔 일말의 기대도 없다 ',
#  '사회심리연구소 함께 소장 김태형 사회심리학자 심상정 후보가 남녀 막내딸이라 인정욕구가 강하다 성공욕 명예욕 인정욕구에 사로잡힌 인물 이재명 후보를 비판하는 건 사적 욕망 때문 김어준 방송에 나와서 이러고 있다 원희룡 부인에 대해 뭐라 할 자격이 있니 ',
#  '심상정 안철수 빠른 시일 내 조건 없이 만나자 심상정 제지대 김동연 정의당 안철수  이경태 기자',
#  '추미애  심상정 아니라 윤  이 구도 만든거에 한몫한 색기들 대선까지 내내 밥만처먹엇다하면 바로 체하게되길 ',
#  '다시 초박빙 윤석열   이재명      차 정례조사 대선후보 지지도 조사 일주일전   이던   격차   로 급감 심상정   안철수   김동연   정권교체   정권재창출   주 전보다 격차    줄어',
#  '아주 정확하던데 김어준 방송 나온 심리학자 심상정  비판하는건 심리문제 ',
#  '심상정 안철수 조건 없이 만나자 공조 제안 단일화에는 선을 그으며 양당 체제 종식과 시대 교체를 위해 어디까지 함께 하고 어떤 노력을 할지 적극적으로 대화를 시작해보자는 의미라고 설명 ',
#  '양당 쌍적폐 타도하자 심상정 안철수 조건 없이 만나자 공조 제안 출처  네이버 뉴스 ',
#  '  화이팅 ',
#  '  그래서 좃선과 친하고 공수처법에 기권하는 비례대표를 얻었지요 보가 아니기에 두 번은 속지 않아요 안녕',
#  '심상정은 양당제를 비판하지만 양당제 자체 때문에 한국정치가 엉망이된 근거는 제시하지 못한다 양당제 체제하에서서도 우리 시민은 박근혜를 탄핵시켰고 고졸 대통령을 당선시켰다 안철수나 정의당이 결정적 대안으로 부상못하는데는 다 이유가 있는 것이다 이걸 깊이 깨달아야 한다 ',
#  '셋째 세대와 함께하는 시대교체를 만들어주십시오 모든 대선 후보가 청년을 이야기하지만 정의당의 모든 비전과 정책은 그 자체로 청년들의 삶에 준거합니다 신노동법 주일제 한국형모병제 성폭력 원아웃 등 빼앗긴 청년의 미래를 확실히 되찾아올 후보라는 점을 적극적으로 알려주십시오 ',
#  '둘째 시민들이 체감할 수 있는 실질적인 성과를 만들어주십시오 특히 정의당의 심장에 녹색이 분명히 새겨져 있음을 시민들께 널리 알려야 합니다 정의당이 기후위기 극복을 위해 실천해가고 있지만 전국의 녹색시민들과 충분히 함께하지 못하고 있습니다 전당적인 행동을 요청드립니다 ',
#  '첫째  현장 속으로 선대위를 전면 배치해주십시오 시민의 삶 속에 답이 있습니다 현장이야말로 정의당이 살아있음을 증명하는 곳입니다 이번 주부터 투쟁현장 노동현장에 결합해주십시오 시민들의 삶 속에 정의당이 있고 시민들과 끈끈하게 손을 맞잡아야 정의당의 시간이 열릴 것입니다 ',
#  '시민 속에서 정의당의 사명을 복원해내겠습니다 정의당 대선 후보는 심상정과 정의당 둘입니다 모두가 심상정이라는 마음으로 시민들 속에서 정의당의 사명을 복원해내주시기를 당부하며 선대위에 다음과 같이 요청드렸습니다 ',
#  '지난 주말 심상찮은 선대위 워크숍을 가졌습니다 정의당은 지난 총선   로 창당 이래 최고 지지율을 얻었지만 당의 침체로 국민적 기대에 충분히 부응하지 못했습니다 다시 삶의 현장으로 달려가 시민들의 바람에 성실하게 응답하고 시대교체 열망을 결집해내야 한다는 말씀 드렸습니다 ',
#  '이번에 심상정 의원 꼭 대통령 당선되시면 좋겠다 그리고 언젠가 장혜영 의원도 꼭 청와대에서 뵙고 싶어요',
#  '김어준 싹바가지없는새끼는 엄마가 민주당지지자라 맨날 들어서 아는데 그냥 떼쟁이 음모론자 이상도 이하도 아님 심상정 언급하는 방송 내보낸것도 맨날 똑같은수준이라 별 감흥도 없음',
#  '심상정 찍는 의미를 모르는거임 ',
#  '심상정 안철수 조건 없이 만나자 제지대 뭉치나 ',
#  ' 노컷뉴스 다시 초박빙 윤석열   이재명      차 정례조사 대선후보 지지도 조사 일주일전   이던   격차   로 급감 심상정   안철수   김동연   ',
#  '  오늘 발 여론조사가 이야기하는 건 며칠전 어준이가 심상정을 정신병자로 몰던 것에 연장선상에 있단 느낌이 강하게 온다 딱 지지율 격차가 심상정 지지율임 이번 여론조사은 심상정 너 나가라는 지시 같은 역할을 해 민주당 청위병들이 심을 향해 미친듯이 날 뛸 듯 ',
#  '대선전환추진위 심상정 안철수 김동연 후보는 양당체제종식 공동선언하라 시사타임즈 탁경선 기자 대선전환추진위원회가 일 국회의사당 앞에서 발족식 및 기자회견을 갖고 우리에겐 제지대 후보들이 필요하다 며 심 ',
#  ' 시사타임즈 대선전환추진위 심상정 안철수 김동연 후보는 양당체제종식 공동선언하라 시사타임즈 탁경선 기자 대선전환추진위원회가 일 국회의사당 앞에서 발족식 및 기자회견을 갖고 우리에겐 제지대 후보들이 필요하다 며 심 ',
#  '한국사회여론연구소  대선 여론조사에서 윤석열   이재명   심상정   한주 사이에 윤은  이상 줄고 이는  이상 상승 못 믿을 조사네 고무줄 같이 진보 합이  이상이라 허수네 없는 지지율이 막나오고 김치국 잘 마시고 주중 조사 나오면 그때봐야 할듯',
#  '정의당이요 심상정한테 넥슨이랑 박가분 어떻게 생각하냐고 물어보고 싶다',
#  '여자분들 페미니스트분들 차악을 선택하지 마시고 최선을 선택하세요 여자들의 표 무시하는 여야당은 필요 없습니다 주일제에 약자를 위해 목소리내는 심상정 정의당 뽑읍시다 우리의 표도 존재한다는걸 보여줘야 할 때입니다 ',
#  '김어준 방송 나온 심리학자 심상정  비판하는건 심리문제 다음 뉴스 ',
#  '심상정도 아니고 윤석열 ',
#  '정의당 심상정 보고 있니 ',
#  '  안철수의 지지율이 심상정 보다 낮게 나온 것도 특이점 안 후보도 이재명 식 리셋 을 시도해 보는 것이 어떨지 ',
#  '그러니까 심상정 뽑자',
#  '최선이라 해도 심상정하고는 거리가 한참 먼 이번 대선이다 ',
#  '참고로 내 주위  회사원 여성들은 둘다 꼴보기 싫다고 심상정 찍을까 고민하더라 안하는 회사원 여성들임 원래 각각 민주당 국힘당 등 다양하게 지지했는데  여성들 눈에도 이것들의 여성혐오가 보통이 아니라 생각했겠지 ',
#  '이어 정의당 심상정 후보   국민의당 안철수 후보   김동연 전 경제부총리   순이었다 ',
#  '민주당은 여자들이 이재명을 찍을까 두려워서 어떻게 해서라도 안티페미 어필하고 국힘당은 민주당에 열받은 여자들이 행여나 윤석열을 찍을까봐 두려워서 또 기를 쓰고 안티페미 어필하고 그래서 우리가 심상정 뽑겠다고 여자표를 휴지 취급하는 놈들 안찍겠다고 ',
#  '현재 대입체제가 얼마나 비민주적이고 불합리한지에 대해 단 한번이라도 진지하게 고민해본 대선후보가 단 한명도 없다는 사실이 놀랍다 심상정조차도 말이다 ',
#  ' 한국사회여론연구소  가 일부터 일까지 이틀 동안 차기 대선후보 지지도 를 물은 결과 윤석열 후보는   이재명 후보는   로 조사됐다 심상정 후보는   안철수 후보   김동연 후보는   의 지지율을 기록했다 ',
#  '헉 대박 심상정이 안철수보다 높다',
#  '한국사회여론연구소  가 일부터 일까지 이틀 동안 차기 대선후보 지지도 를 물은 결과 윤석열 후보는   이재명 후보는   로 조사됐다 심상정 후보는   안철수 후보   김동연 후보는   의 지지율을 기록했다 ',
#  '불쾌함을 없애는 두 가지 방법  불쾌한 것에서 도망쳐 산다  불쾌한 것을 없앤다 저는 오늘 번을 택했구요 오늘 재명오빠와 식사자리를 가질 예정입니다 심상정 당선되게 해드릴게요 ',
#  '진보 라는 이름에 변형이 생기도록한 장본인 이제 진보 표현 그만 팔아먹기 바람 영상 심상정이 또 다시 대통령에 도전하는 이유 다음 뉴스 ',
#  '이영지님 슈스파 멤버 들 또 세상 모든 언니들이 심상정 지지 선언하고 도 쪼금 힘 보태면 판도가 어떻게 될지 너모 보고싶다 그 판도 ',
#  '대선후보들을 이해하는데에는 일방적인 연설보다 이런 차분한 인터뷰 방식이 나은 것같다 신동아는 후보들 간 비교를 위해서 윤석열만이 아니라 이재명 심상정 등 다른 주요들도 비슷한 포멧으로 인터뷰해주면 좋을 것같다 ',
#  '허경영 안철수 심상정의 출마가 도전이냐 지들 당원 쩐주 유지할 목적인거지 영상 심상정이 또 다시 대통령에 도전하는 이유 다음뉴스 ',
#  '여당 제야당 후보가 다 별로일 때 심상정이 딱 부상하면 좋을 텐데 프로구나 정치 세력은 정말 안 변하는 걸까 정의당이 그만큼 민심을 못 얻은 걸까 ',
#  '심상정이 말하는 책임연정 민주당은 착각 중 ',
#  '   하다못해 장 뭐시기 홈페이지를 가봐도 지가 유튜브에 썰푸는건 있어도 이 법안 발의 전문을 자료로 올려두지도 않았어요 심상정이 선거법때 처럼 국민은 디테일을 알 필요도 없다는 그런 태도 아닌가도 싶어서 영 꺼림칙 하고요 ',
#  '  대선지지도 윤석열 이재명  심상정  안철수 ',
#  '심상정 정의당 후보   안철수 국민의당 후보    오 심이 안을 이긴 설문조사가',
#  '다들 정신 차리고 심상정 뽑아라 ',
#  '뽑고 싶은 후보가 없는 여자라면 무효표보다는 심상정한테 주는 표가 더 의사표현이 잘 될 듯 ',
#  '아 주말 하루 더 있었으면 좋겠어 심상정 당신이 나의 원앤온리 대통령',
#  '근데 선거비  보전  고  가 절반 보전 아닌가 이대로면 심상정 선거비 하나도 못받는거 ',
#  '응 심상정 뽑을거야 ',
#  '심상정 뽑은거 보면 좀 알겠지 여자들이 얼마나 살고 싶어라는지',
#  '그 트윗 어디갔지 나도 심상정의 스탠스에  동의하거나 마음에 들어서 뽑는 게 아니라고 그런데 지금 남자후보들 꼴 이 명 윤 열 봐서라도 여성들 표를 무시하지 말라는 메세지를 보여주기 위해 심을 뽑아야 할 이유가 있다 이런내용이었는데',
#  '심상정 유시민 그들의 민낯 앞에선 정의로운척 하면서 뒤에선 온갖 더러운 짓을  진보당 이석기의원석방 진보당해산무효',
#  '심상정 유시민의 민낯 그리고 이정희의 진심  진보당 이석기의원석방 진보당해산무효',
#  '심상정을 뽑으란 것두 아니고 더민주 뽑지 말란 사람들은 국짐 뽑으란 소리임 정신 차리세',
#  '블서 현우 진짜 아기이재명 아기윤석열 아기심상정 이번대선픽 갓기좆기와꾸말랑콩떡이네',
#  '      ',
#  '심상정이될진모르겠지만 이영상만큼은 구구절절 맞다',
#  '이재명윤석열 안철수 심상정의 심리분석 쓰는중 출처 파주인문학 블로그 ',
#  '우리미래당 창당식에 정세균 심상정 노회찬 다 들러붙어서 축하했잖아 김종인 꼬봉인줄',
#  '진짜 이 병신글 계속 끌올되는데 이거 욕하는 애들은 심상정도 찢어 죽이는거 맞지 물론 저 글 올리고 억 후원금 받은 다음에 메갈코인 타고 오유 사이트 자체를 여성혐오하는 준 일베 사이트로 낙인 찍어버린 점도 다 까먹었겠지 ',
#  '   아시발 심상정이라고요 전 님 동네 국회의원이래서 시장인줄 알규 심상정 얘기안햇는데 심상정이라고하면 블락한다고하려고햇는데 하 정말어이없어',
#  '   심상정은 번이 아니라 번 아니면 번일껄',
#  '팩트 심상정도 했다',
#  '   엥 엥 번 심상정 아님 ',
#  '공약을 뭘 봤냐니 아무리 뜯어봐도 여성정책에서 이재명은 심상정 발끝도 못 따라온다 차별금지법 못해 이대남 눈치 보느라 여가부 명칭변경도 해야 해 이재명 지지할 수는 있는데 그 후보가 디씨 들락거리며 재명이형 이 되길 자처한다는 것도 인정해야지 무슨 페미니스트라도 되는 양 ',
#  '심상정  단독국회 소집 있을 수 없는 일 ',
#  '세월이 가니까 결국 군부 윤가 검찰 뇌물 영남당이 장기표 하태경 김한길 황장엽 김철 김종인 김병 이낙연 심상정 다들어가 완전 고물당으로 역사에서 퇴장 시키고 청소 패기물 만드는데 메타버스 최 첨단 과학 가상제국으로 영구적 사라진 페기물 군부 전두환이가 만든 영남당 박지원 안기부 잘한다 ',
#  '  ',
#  '인간들아 주일제를 원하면 심상정을',
#  '심상정 이재명 정체성 엘리트 주의자 노동자 김태형 심리분석 다스뵈이다  출처  ',
#  '심상정 드 대전 대소보루의 시대',
#  '심상정 뽑을 거임 내 손으로 한남 뽑을 일 죽어도 없음 ',
#  '박원순에게 붙어먹다보니 박원순 장례식때는 우왕좌왕 조문을 가네마네 정신나간 상태로 첩년처럼 지랄하던 정의당 지휘부가 왜 요즘 갑자기 시끄럽지요 오거돈이 옥바라지나 가세요 박원순처럼 조문으로 고민하기 전에 니네 미친 심상정년이 조문나댕기는거나 두들겨패서라도 말리지 그랬냐 ',
#  '심상정님이 대통령 됏음 좋겟다 대 여성 표를 버리겟다 요거지 아주 그냥 남자들만 지지고 볶고 니들 알아서 살어 걍 다 니들끼리 살다가 죽어',
#  '나 이준석 별로 안좋아하지만 장혜영 국회의원이 야당 당대표에게 뭐 그리 혓바닥이 깁니까 라고 말하는것은 이해불가다 어디 송영길이 한테나 한준호 혹은 이재명 문재인 심상정이 한테도 그렇게 말해봐라 그러면 인정해주께 ',
#  '  갑자기 남의 망한 소개팅 초대함',
#  '심상정은 유시민 진중권과 함께 서울대학가를 돌며 분수대 팟게를 하고 다닌적이있다 그때 느낌은 그냥 정치자영업자였다 실패란말이 맞을듯 ',
#  '윤석열이나 심상정 찍지 말자는 민주당러는 넘치는데 이재명 찍자는 민주당러는 정말 보기 힘든 신기한 선거 ',
#  ' 김어준의 다스뵈이다 회 심상정 심리분석 도이치모터스 최순실 어게인  출처 ',
#  '두둥 ',
#  '심상정 의원 주사일제 비롯 배치되는 측면 많지만 다가올 대선에선 문시 보다 더한 그거들 보단 나은 선택지라 본다',
#  '문재인이 제일 두려운 후보는 안철수네 이재명이 되든 심상정이 되든 윤석열이 되든 퇴임후 안전보장 확실하겠어 윤에게 문은 은인이고 문에게 윤은 공신이고 ',
#  '국짐당 후보인지 민주당 후보인지 문재인은 좋겠네 여당같은 야당 후보 윤석열과 심상정 그리고 여당후보 이재명이 있어서 든든하겠군 진짜 야당 후보는 안철수 뿐   싸움이네 정권교체 바라고 문재인 정권 심판 원한다면 윤석열은 절대 아니다 보수들 생각 잘하시길 김영삼때 이회창꼴 난다',
#  '심상정 후보가 백신 피해자들 손을 들어준게 비판 받을만한 행동이라고 보기는 하는함 실험 기간도 짧아서 불안한 백신이고 내 주변에도 이런 여론이 없지 않기는 하지만 그 전에도 안티 백서라는',
#  '심상정은 거리에서 맞아죽어도 싼 잡스러운 정치인 아니냐 ',
#  '심상정 뽑자',
#  '  심상정이 답이다',
#  '  허경영 심상정 전화 통 ',
#  '우월하지 못한자의 우월감은 우울감의 표현 열등감과 패배감까지 정의당의 전매특허가 되어서는 안됨 우울하면 심상정말고 허경영을 바라봐 ',
#  '  심상정도 그간 보여온 행보가 ',
#  '내가 말한 이 그림이 충분히 가능성 있지 않나 저 동영상이 충분히 말하잖아 저게 현실이라면 이것도 충분히 그려지는 최악의 시나리오 그 사태를 눈으로 보고 싶지 않다면 심상정을 뽑으십시오 나라의 절반인 여자가 모두 심상정을 뽑으면 심상정이 됩니다 남성의 표는 분할로 나뉘니까요',
#  '  난 온 탐라가 하도 심상정심상정하길래 심상정  예상햇는데 생각보다 윤석열 안철수 높아서 신기함',
#  '헐 트위터 여자애들 조사햇는데 이재명  윤석열 실화임 하긴 민주당 정의당쪽 성향이면 이재명 안 찍고 심상정으로 가긴 하겠다',
#  '이낙연 지지자들 이재명 죽이고 싶을 정도로 싫은 건 알겠는데 이낙연 후보가 이야기 했던 인권과 사람에 대해서 생각해 보세요 윤석열 심상정 다른 후보 찍던지 아님 이낙연 후보랑 다른 당 만드시든가요 정말 이렇게 까지 할 일인가요 사회가 퇴보되고 있어 ',
#  '  남자중에서는 심상정  도 안나오고 여자중에서도 심상정  도 안나올거같은디',
#  '  근데 이거 해봤자인게 어차피 우리나라 젊은이들은 심상정쪽 많이 미는데 나이 드신 분들이 이재명윤석열 쪽이라 어차피 둘 중에 한명 될 것 같음',
#  '야 장혜영 전 남편을 토막살인 하는 여자는 뭔데 살인자를 두고 왜 남자여자 따지고 지랄이니 니들 때문에 메갈심상정의당은 차기 총선에서 사라질 것이라는 데에 원 건다 원도 사치여 니들에겐 ',
#  '왜 심상정이 빵순이야 ',
#  '  근데 생각해보면 심상정이도 나오는데 정의당이 돈이 많은 당도 아니고 ',
#  '왜 자꾸 트럼프 트럼프라고 하냐고 심상정있다니까 후보아니냐고 내가 잘못알고있나 지금 아리까리 한 지경까지옴',
#  '이번에 진짜 누구뽑아야해 진짜 심상정밖에는 답이 없는건가 ',
#  ' 여성 지우는거 너무 괘씸하지않아 이준석 대표만든거에 이대남 역할큰거 알겠는데 여성들은 대선투표권 없는줄알겠다 그동안 진짜 민주당 찍어줬는데 이번에는 심상정찍는다 나중에 그표때문에 이재명 대통령 떨어졌다고 부랄발광하지말고 미리 잘해봐라',
#  '대통령 선거로 알티타는거 인용 보면 다 트럼프트럼프 라는데 심상정은 어디감 다 심상정 뽑으면 되는일이잖아 왜 똥개똥 이러고 있는데 트럼프트럼프심상정 쓰고 똥개똥심상정 이라고 쓰고 똥 개똥 누가 더 낫나 잴 시간에 심상정 뽑을 생각 한번 하고 나머지는 공부해서 탈조 생각',
#  ' 왜 대전 살기는 좋은데 특히 둔산동은 살기 매우 좋음 아 근데 이거 보고 결국 심상정 때문이잖아라고 함 성심당잉데 심상정바라기는 어쩔 수 없나바 이참에 대전 사람들 모두 심상정 뽑자 심상정을대통령으로 심상정대통령',
#  '걍 심상정 뽑으면 되잖어 ',
#  '정의당은 심상정부터 내치지 못하면 이제 그나마도 설 자리 없지 구시대 적폐 어쩌고 저쩌고 하면서 그걸 타파하겠다고 대선후보 세운 인물이 심상정 그냥 전국적인 지지도 제일 높은 사람 뽑은 인기투표 수준이지 무슨 알지도 못하는 친환경 에너지 정책이라고 민주당중대가 ',
#  ' 그러면서 김 소장은 무의식적으로 심 후보가 스스로를 노동자라고 생각 안 한다 라고도 했다 노동운동을 했으니까 의식적으로 노동자라고 생각하는 것 이라는 주장이다 심상정 대표 의원 세비 제한법 발의 원문보기 ',
#  '김어준류에겐 이재명에게 우호적인가 아닌가가 노동자 정체성을 가르는 잣대 가령 전태일이 살아돌아와 이재명 비판하면 전태일도 노동자 정체성이 부족하다고 할 놈들 진영논리에 미치면 사람이 이래 됨 심상정은 노동운동사의 산 증인 가운데 한 명임 ',
#  '짐이 임마 지금 무슨 심정으로 현 여당 지지해야 하는 지 알기나 하나 그래 나 심지어 두번이나 문재인 현 대통령 대신 심상정 찍은 사람이야 이번에도 그럴려도 했다만 상대가 상대인 만큼 그리고 내 나이도 나이인 만큼 우선은 적폐들 부터 완전히 청산하는 단계를 차근차근 밟아가려한다 ',
#  '  소홀히 공부했을지도요 그리고 심상정은 아마 학력고사세대가 아니라 예비고사 본고사 세대일 겁니다 학년도 대입부터가 학력고사일 거예요 ',
#  ' 심상정이 상당한 정치활동을 했는데도 지지층이 형성되지도 않았다 고도 했다 정의당 대선후보 번째인데 지지층이 형성되지도 않았다 는 건 인지부조화 상태 ',
#  '양자대결 윤석열   이재명   다자대결 윤석열   이재명   둘 다 똑같이 양자대결과 다자대결의 지지율 변화가   씩 빠진다 안철수가 윤석열 심상정이 점자지 한테서 가져가나는건가   부정선거 인천 연수을의 사전선거  대 이 떠오른다 요렇게 서서히 여론 조작 ',
#  '심상정을 찍어야 장혜영 의원이 대통령인 미래도 있을 거 아닙니까 제발 임의로 편생을 양당제 국가에서 살아오신 여성들은 민주당에서 눈을 돌려 심상정 후보를 선택합시다 한남충들하고 똑같이 정치공학적 수사학에 놀아나지 말고 여성으로서 나은 미래를 선택할 권리를 실질적으로 행사합시다 ',
#  '이번대선  여성으로서 정의당 뽑는다 심상정픽 가보자고',
#  ' 김어준씨는 어른이 된다는 건 과감하게 남의 기대를 저버리는 과정 이라며 심 후보는 노동운동을 본인이 선택하긴 했지만 부모님 기대를 저버리지 못했다는 말씀이네요 라고 맞장구 년 위장취업 노조결성 전두환 정권 하 최초 구로동맹 파업 실행 한 게 심상정 부모의 기대였다는건가 ',
#  '차라리 모든 여성국민들이 심상정 몰아서 트럼프들 경각심 주는게 나을지도',
#  '정의당 지지자들이 민주당이랑 민정당이랑 합당하라고 비아냥대는거처럼 심상정도 딱히 저 둘이랑 통합 못할만큼 차이가 있는것도 아닌데 뭐 ',
#  '안철수 심상정 후보 및 정의당과 함께 풀어갈 수 있기를 기대합니다 아직 협의가 끝난 게 아닌데여 암튼 두 정당 중 먼저 이 제안을 거부하거나 토를 달고 수작을 걸어 오는 것들이 범인이겄죠 크게 기대는 안 합니다 두 당이 특검을 가지고 싸우는데  로 싸움이 확대된다는 걸 뿐 ',
#  '여성신문이 국힘 기관지라 계획대로 되구 있구나 윤 당선 미리 축하해야하나 선택은 자유지만 팩트로는 폐지는 국힘의 당론이고 이재명과 심상정은 이름을 성평등으로 바꾸자함 폐지 아님 실제 이재명 윤석렬 여성 정책은 아래같은데 윤석렬되면 성폭행 당해도 확실한 증거 없으면 감옥행 확정 ',
#  '근데 난 이거 응원하는 입장인데 저 셋이 단일화하면 가장 유의미한 지지율을 보이는 안철수가 단일화를 안한다는 의미고 난 어차피 심상정의 지금 포지션에 별 불만이 없음 그양반들은 심상정 없어지면 투표포기나 민정당뽑을거라서 ',
#  ' 심상정 사적 욕망에  비판 인정욕구 강해 김어준 방송 심리분석 출처 조선일보 네이버 뉴스 ',
#  '  김어준   이재명론 공동저자인 김태형 사회심리학자와 심상정 심리분석 심상정 사적 욕망에  비판 인정욕구 강해 색안경을 끼고 사이비 심리분석을 하니 돼지 눈에 돼지만 보인다는 자기고백이 되버림 ',
#  ' 심상정 인터뷰 차악을 고민하지 말고 최선을 선택하시라 ',
#  '  지금 이재명을 지지하는 분들은 대다수의 범촛불세력 또는 민주당 권당들입니다 경기동부   있어봤자  도 안될겁니다 이들은 김대중 노무현 문재인을 지우려고 한적도 없고 심상정 이정희도 아니고 이재명을 극좌라고 한 것은 정치감각의 문제라 봅니다 사사오입 정당한 경선이었고요',
#  '심상정과 정의당도 살판 났고 ',
#  '박원순 때 여성계 기울어진 운동장 너무 심각 심상정 제대로 된 여성공약도 없는 정체성 정치에나 낚이고 진짜 필요한 공약 민주당 여성의원이 힘들게 만들어 올리면 반응 안 하고 ',
#  '엄마가 성심당 사주는 것 보다 심상정 사주는게 더 빠를 것 같은데',
#  '비상이다 나는 솔직히 이번에  여자들의 저력을 투표로 보여주면 분명 새 모이만큼이라도 무언가 압박이 되고 발톱만한 변화라도 있을 거라고 믿어 차악보다 최선을 뽑는 투표를 하자 여러분 어대심 어차피 대통령은 심상정 가보자고',
#  '진짜 간 단 심상정 인터뷰 차악을 고민하지 말고 최선을 선택하시라 시사 ',
#  ' 김어준의 다스뵈이다 회 심상정 심리분석 도이치모터스 최순실 어게인   대통령은 한 시대를 선택하는 일이라는 김어준의말 너무 멋있다 완전 공감 ',
#  '  허구위선당 사짜 심상정 ',
#  '개허접좌파 포퓰리스트 이재명을 메시아로 띄우면서 심상정이 사적욕망에 사로잡혔다는 김어준 정의당이 이재명을 밀면 해방 이후 진보운동 역사를 통째 말아먹는 건데 뭔 하찮은 사적욕망 따위를 들이밀어 진보판에서 대중선동으로 이익 취하는 니놈의 사적욕망이 더 문제 ',
#  ' 김어준의 다스뵈이다 회 심상정 심리분석 도이치모터스 최순실 어게인   ',
#  '딱히 심상정의 당이 뭘 잘할거라는 기대는 엄청나게없어요 근데 까놓고보면 민주당이랑 하는짓이 고만고만할거란 정도 이쪽으로 바뀌어도 세상은 무너지지않고 오히려 여성이슈나 노동이슈에 대해서 걍 무시하고 부동산이나 해쳐먹자고 이런 태도는 안나오겠거니 하는 부분 ',
#  '우리에게 남은 선택지는 심상정뿐이라니까 진짜',
#  '심상정후보도 마찬가지고  만족하는 후보는 이세상에 없음 그럴거면 본인이 대선에 나가야 하는거고 심후보 존재자체만으로도 굉장한 도움이 되는데 난 독일총리처럼 여자도 계속 탑의 자리에 있을수 있는거 그런거 보고 싶다 그래서 여성정치인이 투표에 후보로 나오면 무조건 지지함',
#  ' 심상정 사적 욕망에  비판 인정욕구 강해 김어준 방송 심리분석 김어준이 사적 욕망이 심해서 판단능력을 상실 또는 알면서도 거짓말을 하는거겠지 그래서 좌적폐 라고 부르는데 골때리는건 윤석열도 빨아줌 ',
#  '양당제가 아닌 우리나라서 년 묵은 두당정치 란 의미는 정의당 니들이 그간 국민들이 외면할 정도로 무능하단 의미다 그리고 점점 더 무능해지고 있다 라디오 나와서 심상정이 양당제 어쩌고 말하는데 패널들 넌지시 비웃는 거 정말 안쓰러울 지경 ',
#  '심상정 이재명과의 단일화 가당치 않다 발언 등 분석 ',
#  '난 걍 되든 안 되든 심상정 찍을꺼야 저딴 똥에 내 투표권 행사할 순 없어 트위터리안들아 주일제 하자 힘을 보태줘',
#  '나도 심씨 싫어하지만 여니께 하던 짓거리를 똑같이 하고 있네 이것들은 정말 악마다 심상정 사적 욕망에  비판 인정욕구 강해 김어준 방송 심리분석 다음뉴스 ']

# %%
for k in range(len(result)):
  result[k]=result[k].replace('\n',' ')
  result[k]=result[k].replace('\t',' ')

# %% [markdown]
# # 불필요한 내용 제거

# %%
#result_split = result.split('포스팅 내용')
#result_split[1]
#result_split
result[0]
# Out:
# '이번투표는 남자는 안뽑을것같다 심상정이 다른 정치인들보다 클 린하다 옳은사람이다 이런말은 못하겠는데 적어도 대놓고 쌉소리는 않하잖여 '

# %%
file = open('/content/drive/MyDrive/Colab Notebooks/NEWS_split_crawling_data.txt',"w", encoding='utf-8')
file.write(str(result))
file.close()

# %% [markdown]
# # 형태소 분석

# %%
data_split = open('/content/drive/MyDrive/Colab Notebooks/NEWS_split_crawling_data.txt', 'r', encoding='utf-8').read()
data_split = [[data_split,1]]
print(data_split)
# Out:
# [["['이번투표는 남자는 안뽑을것같다 심상정이 다른 정치인들보다 클 린하다 옳은사람이다 이런말은 못하겠는데 적어도 대놓고 쌉소리는 않하잖여 ', '심상정 안철수에 빠른 시일 내 조건 없이 만나자 양당체제 종식 기자회견서 안철수 김동연에 회동 제안 노회찬 없는 정의당 참 안쓰럽다 페미들만 잔뜩 모아 놓은 이상한 모습에 사욕 가득한 심상정 ', '단지 소수자인 자신을 심상정이 언급해주는 것만으로 감동받아 지지해주는 분들이 있는가 하면 그저 겉멋에 들어 대학교 학술동아리를 졸업 후에도 꾸준히 하고 있는 머저리들도 있고 ', '심상정이 안철수의 제안을 긍정적으로 수용한 듯한데 트위터 좌파 의 일부의 부정적 반응을 보니 역시', '  몇몇 철 안든 어린 의원들 치기나 미성숙이라고 생각했는데 정의당 지도부의 총체적 난국이네요 그 내용을 다 들은 사람으로 심상정 후보 이해하는데 도움이 됐지 네가티브 아니라고 생각했는데 정의당엔 지도자가 없네요 ', '외부인사 추천 허경영 안철수 심상정', '사회심리연구소 함께 의 김태형 소장 년도 심상정 후보측의 요청으로 심상정이라는 인물에 대한 책을 공저함 그때 심리분석도 함께 씀 다큰 어른은 크게 변하지 않는다 는 얘기와 함께 년전 책내용 그대로 말한건데 왜 이제와서 딴지야 정의당은 니들도 이 책 안봤냐 ', '이재명 윤석열이 저렇게 멍청하게 하는데도 말 잘하고 정책 잘내는 심상정이 밀린다는게 안 믿김', '한국인분들 심상정 의원을 청와대로 보내 주길 바랍니다 ', '투자의 입장에서 봐도 이재명은 오너만 해먹는 자본잠식 부실기업 윤석열은 대가리 빈 페이퍼컴퍼니 심상정은 평타정도 치는 강소기업인데 주식이고 코인이고 투자 광풍이 분 나라치고 망하지는 않을 강소기업에는 절대 투자를 안하려는 꼬라지가 너무나 한국 수준에 딱 맞는 상황인듯 ', '민주당 이명박과 남자 박근혜가 대선후보라는 초유의 사태에서 둘 다 최악의 선택지임에도 굳이 심상정은 고려조차 안한다는거 이성적으로 생각할 때 이재명과 윤석열은 진짜 좆되는 선택이지만 심상정은 최소한 최악은 피할 수 있는데도 선택을 안함 그게 한국 국민 수준을 보여주는 방증임 ', '  심상정아줌 치매', '이런 절호의 기회조차도 안철수 따위와 연대를 한다며 똥볼을 차고있는 정의당에 한심한 애도를 표한다 목마르다고 바닷물을 마시는 미련함  ', '정의당은 지들 밥그릇을 걷어차는구나 심상정이 이제 페미당으로 만들어서 국힘당에 갖다바치냐 노회찬 살아계셨음 어쩔뻔 했니', '과거 전두환이 정의사회 구현이라는 표어를 사용했는데 심상정의 정의당이 전두환의 정의사회를 닮았다', '심상정 안철수에 빠른 시일 내 조건 없이 만나자 민주당에 기생하며 다른 군소정당 죽이는데 앞장서더니 이제 와서 ', '심상정은 아무말 대진치 해도 책임질 일이 없으께 얼마나 좋냐 암껏 시 부러도 되고 ', '아니 진짜 여자들 직장인들만 심상정 찍어도 심상정 될 것 같은데 빨강파랑이 둘 다 최악인데 마음에 안 들지언정 차악인 사람을 뽑는 게 낫지 않겠냐고', '성심당축제도햇겟다 심상정 가보자고', '어제  스트레이트 지난주랑 같은   이고 이번주는 걸그룹 오디션 프로 땜에 결방하고 다음주에 한댄다 폐지각인데 그리고 피디수첩 내일은 위드코로나 편이고 분토론은 심상정 특집이고 패널은 심상정 장하나 성한용 김종혁이란다 노잼 될듯 ', '   노회찬은 심상정이아니까요 어쩌면 노회찬은 정의당의 막가파에 걸림돌이었을까 ', '  심상정은 왜 윤석열에게 러브콜을 했는가 이런거 주제로 하는데 배진교가 나올리 있나 심상정 흑화 그것이 알고 싶다 배진교는 빼엑 ', '  심상정 심리분석을 문제삼았나보네요 분석이 정확해서 찔렸나보네 욕구를 숨기던 사람이 속마음 틀키면 이럴수 있겠다 싶네요 ', '심상정 나왔어봐 대본보다 더 잘했을듯 ', '안철수와 심상정이 친구도 아니고 심지어 정치성도 판이하게 다른데 다른 편끼리 가끔은 협력했다가 떨어지는 건 기본적인게 아닌가요 ', '아니 징짜 다뵈 심상정 인물 비평땜에 그런거야 우와 밴뎅이 소갈딱지네 푸하하하하', '  빗나간 종부세 전망 대상자 만 명 육박에도 여전히 일부만 해당  국민을 속이는 데만 도가튼 문재인 사기꾼 정부 문재인은 진즉에 탄핵을 당했어야        ', '음 윤석열이 될 거 같아 음 그냥 원래 트위터 여론이 남한 전체의 여론은 아니었잖아 그냥 음 윤석열이 될 거 같아 안되었으면 좋겠다 심상정씨가 되면 좋겠다 ', '  문재인정부 시작할 때 새누리는 역사속으로 사라지고 민주당과 정의당 두 정당체제로 갈 거라고 하는 사람 정말 많았는데 정의당이 경선을 날로 해먹으면서 정의당은 아웃 오브 안중되버림 좀 잘 하던가 ', '꿈은 꾸는게 당연하지요 그리고 꿈을 나눠줘야하는데 노회찬 사후 정의당의 색깔이 너무 많이 퇴색되었다 영상 심상정이 또 다시 대통령에 도전하는 이유 출처 시사 네이버 뉴스 ', '뭘 고민해 심상정 있잖아', '와아 쉴드칠껄 쳐라 심상정에 표 분산 막겠다고 스토커처럼 하는 것도 웃기지만 비판 자체가 딸 어쩌고 완전 코미디 이재명이 뭐라고 다들 왜 이러지', '시발 진짜 비참한 포인트는 저런 새끼가 정말 대통령이 될지도 모른다는 거지 심상정 안철수는 가능성이라도 없는데 저새끼는 세상에 시발 ', '근데 이건맞지 심상정가자니까', '  몇 년째 심상정후보에게 투표했늨데요 계속 지지할거고요 여튼 소형원자로건에 대한 심상정씨의 주장에는 동의하기 힘듭니다 다시 알아보셨으면 합니다 ', '  후보님 답답합니다 역사의 서구민주국가도 아닌 한국 땅에서 진보당이 뻗을다리가 있나요 계란으로 바위치기 이해합니다만 답답합니다 백성은 진보당보다는 힘있는 진보세력을 더 원할듯 당합당해서 가 권력을 얻은것처럼 민주 열린 정의로 합쳐서 미래권력을 잡으세요 당원을 설득하세요', ' 할머니 할아버지 윤석열 뽑지 마세요 이재명 뽑지 마세요 심상정 뽑아주세요 윤석열이나 이재명 둘 중 하나가 대통령 당선되면 그때부터 손녀 죽어간다 손녀 인생 망해요', '  써글 심상정이 한티 전화오면 나 그 상품에 관심읍따 라고 할 꺼임 광고성 전화는 딱 싫어 ', '월 주차 여론조사 지난 주에  넘게 벌어진 걸 보고 대중과 나의 판단은 이렇게나 벌어졌나 싶었는데 이번에 그 간격이  로 줄어들어서 월 주차가 기다려진다 심상정 아주머니는 페미니스트 대통령 야심차게 꺼내들었는데   빠짐 그걸로 외연확장 안된다니까 골목대장 하고 싶은 모양 ', '심상정이 젤나은데', '신지예씨가 안철수의 노동정책이 심상정과 가깝다고 해서 찾아봤다 제일 위에 뜨는 기사다 저는 지난 대선 때 노동시장의 양극화를 줄이려면 비정규직의 정규직화보다는 비정규직의 직업 안정성과 보수를 높이는 쪽으로 노동개혁을 해야 한다고 했다 ', '원전이 안되면 대안을 제시하는 게 정당이지 무조건 나빠요 쟤네 뭐 모르고 떠들어요 아시죠 위험한거 이런 선동뿐임 도대체 심상정은 컨텐츠도 없이 얼마나 오래 해먹는거임 ', '  심상정 심리분석 땜에 삐진건가요 ', ' 현장영상 심상정 안철수 조건 없이 만나자 제지대 공조 시동     덜나쁜사람을 뽑는 차악선거보다 더 나은 대안이 되지 않을까 싶지만 가능할는지 ', '  심상정 전화통 오지않았어요 ', '종인이가 상정이랑 만나면되겠군 김종인 심상정 허경영 안철수 환상의 듀오다 ', '  감각이 많이 떨어졌다 노회찬없는 정의당 저물어 간다 ', '심상정 안철수에게 만나자 제지대 공조 제안  심상정은좌파인데 좌파하고 왜손잡아 안철수가 좌파당후보하고 손잡으면안되는거야', '심상정이 돼도 당연히 여가부가 없어지지 똥꼬충트랜스정신병들무지개법썩흐응딱련들도 정의로운세상을위해 보살펴줘야하니까', '안티백서 지방차별질하는 심상정을 왜 올려치나요 ', '해묵은 생존법 파트너 바꿔가며 다 해봤고 정당이념 다른 물리적 합당도 안된다는거 알았고 유시민은 이것저것 다해보고 더이상 할게없다고 정치안하는 거고 심상정은 자기가 하는게 진보의 역사라며 남아있는거고 ', '방송사고 왜 실트인가 했네 근데 윤석열이 멍청이인걸 이재명을 올려친다고 심상정을 뽑으세요 님들아 왜 고만고만한 놈들 두고 고민하고있어', '심상정 안철수 빠른 시일 내 조건 없이 만나자 이 윤에 쏠린 대선판 깨기 위한 제지대 연쇄 회동 오마이뉴스 사주팔자 에 무슨 살 이 끼 ...

# %%
pip install konlpy
# Out:
# Collecting konlpy
#   Downloading konlpy-0.5.2-py2.py3-none-any.whl (19.4 MB)
#      |████████████████████████████████| 19.4 MB 54.0 MB/s
# Collecting colorama
#   Downloading colorama-0.4.4-py2.py3-none-any.whl (16 kB)
# Collecting beautifulsoup4==4.6.0
#   Downloading beautifulsoup4-4.6.0-py3-none-any.whl (86 kB)
#      |████████████████████████████████| 86 kB 6.0 MB/s
# Requirement already satisfied: tweepy>=3.7.0 in /usr/local/lib/python3.7/dist-packages (from konlpy) (3.10.0)
# Requirement already satisfied: lxml>=4.1.0 in /usr/local/lib/python3.7/dist-packages (from konlpy) (4.2.6)
# Requirement already satisfied: numpy>=1.6 in /usr/local/lib/python3.7/dist-packages (from konlpy) (1.19.5)
# Collecting JPype1>=0.7.0
#   Downloading JPype1-1.3.0-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.whl (448 kB)
#      |████████████████████████████████| 448 kB 59.4 MB/s
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.7/dist-packages (from JPype1>=0.7.0->konlpy) (3.10.0.2)
# Requirement already satisfied: six>=1.10.0 in /usr/local/lib/python3.7/dist-packages (from tweepy>=3.7.0->konlpy) (1.15.0)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.7/dist-packages (from tweepy>=3.7.0->konlpy) (1.3.0)
# Requirement already satisfied: requests[socks]>=2.11.1 in /usr/local/lib/python3.7/dist-packages (from tweepy>=3.7.0->konlpy) (2.23.0)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.7/dist-packages (from requests-oauthlib>=0.7.0->tweepy>=3.7.0->konlpy) (3.1.1)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests[socks]>=2.11.1->tweepy>=3.7.0->konlpy) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests[socks]>=2.11.1->tweepy>=3.7.0->konlpy) (2021.10.8)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests[socks]>=2.11.1->tweepy>=3.7.0->konlpy) (1.24.3)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests[socks]>=2.11.1->tweepy>=3.7.0->konlpy) (3.0.4)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6 in /usr/local/lib/python3.7/dist-packages (from requests[socks]>=2.11.1->tweepy>=3.7.0->konlpy) (1.7.1)
# Installing collected packages: JPype1, colorama, beautifulsoup4, konlpy
#   Attempting uninstall: beautifulsoup4
#     Found existing installation: beautifulsoup4 4.6.3
#     Uninstalling beautifulsoup4-4.6.3:
#       Successfully uninstalled beautifulsoup4-4.6.3
# Successfully installed JPype1-1.3.0 beautifulsoup4-4.6.0 colorama-0.4.4 konlpy-0.5.2

# %%
from konlpy.tag import Okt

okt = Okt()

def tokenize(doc):
    return [t for t in okt.pos(doc, norm=True, stem=True)]      # norm은 정규화, stem은 근어로 표시

tokenize_docs = [(tokenize(row[0]), row[1]) for row in data_split]

with open('/content/drive/MyDrive/Colab Notebooks/tokenized_data', 'w', encoding="utf-8") as make_file:     # JSON 파일로 저장
    json.dump(tokenize_docs, make_file, ensure_ascii=False, indent="\t")
tokenize_docs[0]
# Out:
# ([("['", 'Punctuation'),
#   ('이번', 'Noun'),
#   ('투표', 'Noun'),
#   ('는', 'Josa'),
#   ('남자', 'Noun'),
#   ('는', 'Josa'),
#   ('안', 'VerbPrefix'),
#   ('뽑다', 'Verb'),
#   ('같다', 'Adjective'),
#   ('심상정', 'Noun'),
#   ('이', 'Josa'),
#   ('다른', 'Noun'),
#   ('정치인', 'Noun'),
#   ('들', 'Suffix'),
#   ('보다', 'Josa'),
#   ('크다', 'Verb'),
#   ('린', 'Noun'),
#   ('하다', 'Verb'),
#   ('옳다', 'Adjective'),
#   ('사람', 'Noun'),
#   ('이다', 'Josa'),
#   ('이런', 'Modifier'),
#   ('말', 'Noun'),
#   ('은', 'Josa'),
#   ('못', 'VerbPrefix'),
#   ('하다', 'Verb'),
#   ('적어도', 'Adverb'),
#   ('대놓고', 'Adverb'),
#   ('싸다', 'Verb'),
#   ('소리', 'Noun'),
#   ('는', 'Josa'),
#   ('않다', 'Verb'),
#   ("',", 'Punctuation'),
#   ("'", 'Punctuation'),
#   ('심상정', 'Noun'),
#   ('안철수', 'Noun'),
#   ('에', 'Josa'),
#   ('빠르다', 'Adjective'),
#   ('시일', 'Noun'),
#   ('내', 'Noun'),
#   ('조건', 'Noun'),
#   ('없이', 'Adverb'),
#   ('만나다', 'Verb'),
#   ('양', 'Modifier'),
#   ('당', 'Modifier'),
#   ('체제', 'Noun'),
#   ('종식', 'Noun'),
#   ('기자회견', 'Noun'),
#   ('서', 'Josa'),
#   ('안철수', 'Noun'),
#   ('김동연', 'Noun'),
#   ('에', 'Josa'),
#   ('회', 'Noun'),
#   ('동', 'Modifier'),
#   ('제안', 'Noun'),
#   ('노회찬', 'Noun'),
#   ('없다', 'Adjective'),
#   ('정의당', 'Noun'),
#   ('차다', 'Verb'),
#   ('안쓰럽다', 'Adjective'),
#   ('페미', 'Noun'),
#   ('들', 'Suffix'),
#   ('만', 'Josa'),
#   ('잔뜩', 'Noun'),
#   ('모으다', 'Verb'),
#   ('놓다', 'Verb'),
#   ('이상하다', 'Adjective'),
#   ('모습', 'Noun'),
#   ('에', 'Josa'),
#   ('사욕', 'Noun'),
#   ('가득하다', 'Adjective'),
#   ('심상정', 'Noun'),
#   ("',", 'Punctuation'),
#   ("'", 'Punctuation'),
#   ('단지', 'Noun'),
#   ('소수자', 'Noun'),
#   ('인', 'Josa'),
#   ('자신', 'Noun'),
#   ('을', 'Josa'),
#   ('심상정', 'Noun'),
#   ('이', 'Josa'),
#   ('언급', 'Noun'),
#   ('해주다', 'Verb'),
#   ('것', 'Noun'),
#   ('만으로', 'Josa'),
#   ('감동', 'Noun'),
#   ('받다', 'Verb'),
#   ('지지', 'Noun'),
#   ('해주다', 'Verb'),
#   ('분', 'Noun'),
#   ('들', 'Suffix'),
#   ('이', 'Josa'),
#   ('있다', 'Adjective'),
#   ('하다', 'Verb'),
#   ('그저', 'Adverb'),
#   ('겉멋', 'Noun'),
#   ('에', 'Josa'),
#   ('들다', 'Verb'),
#   ('대학교', 'Noun'),
#   ('학술', 'Noun'),
#   ('동아리', 'Noun'),
#   ('를', 'Josa'),
#   ('졸업', 'Noun'),
#   ('후', 'Noun'),
#   ('에도', 'Josa'),
#   ('꾸준하다', 'Adjective'),
#   ('하다', 'Verb'),
#   ('있다', 'Adjective'),
#   ('머', 'Noun'),
#   ('저리', 'Noun'),
#   ('들', 'Suffix'),
#   ('도', 'Josa'),
#   ('있다', 'Adjective'),
#   ("',", 'Punctuation'),
#   ("'", 'Punctuation'),
#   ('심상정', 'Noun'),
#   ('이', 'Josa'),
#   ('안철수', 'Noun'),
#   ('의', 'Josa'),
#   ('제안', 'Noun'),
#   ('을', 'Josa'),
#   ('긍정', 'Noun'),
#   ('적', 'Suffix'),
#   ('으로', 'Josa'),
#   ('수용', 'Noun'),
#   ('한', 'Josa'),
#   ('듯', 'Noun'),
#   ('한', 'Determiner'),
#   ('데', 'Noun'),
#   ('트위터', 'Noun'),
#   ('좌파', 'Noun'),
#   ('의', 'Noun'),
#   ('일부', 'Noun'),
#   ('의', 'Josa'),
#   ('부정', 'Noun'),
#   ('적', 'Suffix'),
#   ('반응', 'Noun'),
#   ('을', 'Josa'),
#   ('보다', 'Verb'),
#   ('역시', 'Noun'),
#   ("',", 'Punctuation'),
#   ("'", 'Punctuation'),
#   ('몇몇', 'Noun'),
#   ('철', 'Noun'),
#   ('안다', 'Verb'),
#   ('어리다', 'Verb'),
#   ('의원', 'Noun'),
#   ('들', 'Suffix'),
#   ('치기', 'Noun'),
#   ('나', 'Josa'),
#   ('밉다', 'Adjective'),
#   ('성숙', 'Noun'),
#   ('이라고', 'Josa'),
#   ('생각', 'Noun'),
#   ('하다', 'Verb'),
#   ('정의당', 'Noun'),
#   ('지', 'Modifier'),
#   ('도부', 'Noun'),
#   ('의', 'Josa'),
#   ('총', 'Modifier'),
#   ('체적', 'Noun'),
#   ('난국', 'Noun'),
#   ('이네', 'Josa'),
#   ('요', 'Noun'),
#   ('그', 'Noun'),
#   ('내용', 'Noun'),
#   ('을', 'Josa'),
#   ('다', 'Adverb'),
#   ('들다', 'Verb'),
#   ('사람', 'Noun'),
#   ('으로', 'Josa'),
#   ('심상정', 'Noun'),
#   ('후보', 'Noun'),
#   ('이해', 'Noun'),
#   ('하다', 'Verb'),
#   ('도움', 'Noun'),
#   ('이', 'Josa'),
#   ('돼다', 'Verb'),
#   ('네', 'Determiner'),
#   ('가티', 'Noun'),
#   ('브', 'Noun'),
#   ('아니다', 'Adjective'),
#   ('생각', 'Noun'),
#   ('하다', 'Verb'),
#   ('정의당', 'Noun'),
#   ('엔', 'Josa'),
#   ('지도자', 'Noun'),
#   ('가', 'Josa'),
#   ('없다', 'Adjective'),
#   ("',", 'Punctuation'),
#   ("'", 'Punctuation'),
#   ('외부', 'Noun'),
#   ('인사', 'Noun'),
#   ('추천', 'Noun'),
#   ('허경영', 'Noun'),
#   ('안철수', 'Noun'),
#   ('심상정', 'Noun'),
#   ("',", 'Punctuation'),
#   ("'", 'Punctuation'),
#   ('사회', 'Noun'),
#   ('심리', 'Noun'),
#   ('연구소', 'Noun'),
#   ('함께', 'Adverb'),
#   ('의', 'Noun'),
#   ('김태형', 'Noun'),
#   ('소장', 'Noun'),
#   ('년도', 'Noun'),
#   ('심상정', 'Noun'),
#   ('후보', 'Noun'),
#   ('측', 'Suffix'),
#   ('의', 'Josa'),
#   ('요청', 'Noun'),
#   ('으로', 'Josa'),
#   ('심상정', 'Noun'),
#   ('이라는', 'Josa'),
#   ('인물', 'Noun'),
#   ('에', 'Josa'),
#   ('대한', 'Noun'),
#   ('책', 'Noun'),
#   ('을', 'Josa'),
#   ('공', 'Modifier'),
#   ('저', 'Modifier'),
#   ('함', 'Noun'),
#   ('그때', 'Noun'),
#   ('심리', 'Noun'),
#   ('분석', 'Noun'),
#   ('도', 'Josa'),
#   ('함께', 'Adverb'),
#   ('쓰다', 'Verb'),
#   ('다', 'Adverb'),
#   ('크다', 'Verb'),
#   ('어른', 'Noun'),
#   ('은', 'Josa'),
#   ('크게', 'Noun'),
#   ('변하다', 'Adjective'),
#   ('않다', 'Verb'),
#   ('늘다', 'Verb'),
#   ('얘기', 'Noun'),
#   ('와', 'Josa'),
#   ('함께', 'Adverb'),
#   ('년전', 'Noun'),
#   ('책', 'Noun'),
#   ('내용', 'Noun'),
#   ('그대로', 'Noun'),
#   ('말', 'Noun'),
#   ('한', 'Determiner'),
#   ('것', 'Noun'),
#   ('인데', 'Josa'),
#   ('왜', 'Noun'),
#   ('이제', 'Noun'),
#   ('와', 'Josa'),
#   ('서다', 'Verb'),
#   ('딴지', 'Noun'),
#   ('야', 'Josa'),
#   ('정의당', 'Noun'),
#   ('은', 'Josa'),
#   ('니', 'Noun'),
#   ('들', 'Suffix'),
#   ('도', 'Josa'),
#   ('이', 'Noun'),
#   ('책', 'Noun'),
#   ('안', 'VerbPrefix'),
#   ('보다', 'Verb'),
#   ("',", 'Punctuation'),
#   ("'", 'Punctuation'),
#   ('이재명', 'Noun'),
#   ('윤석열', 'Noun'),
#   ('이', 'Josa'),
#   ('저렇게', 'Adverb'),
#   ('멍청하다', 'Adjective'),
#   ('하다', 'Verb'),
#   ('말', 'Noun'),
#   ('잘', 'VerbPrefix'),
#   ('하다', 'Verb'),
#   ('정책', 'Noun'),
#   ('잘', 'VerbPrefix'),
#   ('내다', 'Verb'),
#   ('심상정', 'Noun'),
#   ('이', 'Josa'),
#   ('밀리다', 'Verb'),
#   ('안', 'Noun'),
#   ('믿다', 'Verb'),
#   ('김', 'Noun'),
#   ("',", 'Punctuation'),
#   ("'", 'Punctuation'),
#   ('한국인', 'Noun'),
#   ('분들', 'Suffix'),
#   ('심상정', 'Noun'),
#   ('의원', 'Noun'),
#   ('을', 'Josa'),
#   ('청와대로', 'Noun'),
#   ('보내다', 'Verb'),
#   ('주다', 'Verb'),
#   ('바라다', 'Verb'),
#   ("',", 'Punctuation'),
#   ("'", 'Punctuation'),
#   ('투자', 'Noun'),
#   ('의', 'Josa'),
#   ('입장', 'Noun'),
#   ('에서', 'Josa'),
#   ('보다', 'Verb'),
#   ('이재명', 'Noun'),
#   ('은', 'Josa'),
#   ('오', 'Modifier'),
#   ('너', 'Noun'),
#   ('만', 'Josa'),
#   ('해먹', 'Noun'),
#   ('늘다', 'Verb'),
#   ('자본잠식', 'Noun'),
#   ('부실', 'Noun'),
#   ('기업', 'Noun'),
#   ('윤석열', 'Noun'),
#   ('은', 'Josa'),
#   ('대가리', 'Noun'),
#   ('빈', 'Noun'),
#   ('페이퍼', 'Noun'),
#   ('컴퍼니', 'Noun'),
#   ('심상정', 'Noun'),
#   ('은', 'Josa'),
#   ('평타', 'Noun'),
#   ('정도', 'Noun'),
#   ('치다', 'Verb'),
#   ('강소기업', 'Noun'),
#   ('인데', 'Josa'),
#   ('주식', 'Noun'),
#   ('이고', 'Josa'),
#   ('코인', 'Noun'),
#   ('이고', 'Josa'),
#   ('투자', 'Noun'),
#   ('광풍', 'Noun'),
#   ('이', 'Josa'),
#   ('분', 'Noun'),
#   ('나라', 'Noun'),
#   ('치고', 'Josa'),
#   ('망하다', 'Adjective'),
#   ('않다', 'Verb'),
#   ('강소기업', 'Noun'),
#   ('에는', 'Josa'),
#   ('절대', 'Noun'),
#   ('투자', 'Noun'),
#   ('를', 'Josa'),
#   ('안', 'VerbPrefix'),
#   ('하다', 'Verb'),
#   ('꼬', 'Noun'),
#   ('라지', 'Noun'),
#   ('가', 'Josa'),
#   ('너무나', 'Adverb'),
#   ('한국', 'Noun'),
#   ('수준', 'Noun'),
#   ('에', 'Josa'),
#   ('딱', 'Adverb'),
#   ('맞다', 'Verb'),
#   ('상황', 'Noun'),
#   ('인', 'Josa'),
#   ('듯', 'Noun'),
#   ("',", 'Punctuation'),
#   ("'", 'Punctuation'),
#   ('민주당', 'Noun'),
#   ('이명박', 'Noun'),
#   ('과', 'Josa'),
#   ('남자', 'Noun'),
#   ('박근혜', 'Noun'),
#   ('가', 'Josa'),
#   ('대선', 'Noun'),
#   ('후보', 'Noun'),
#   ('라는', 'Josa'),
#   ('초유', 'Noun'),
#   ('의', 'Josa'),
#   ('사태', 'Noun'),
#   ('에서', 'Josa'),
#   ('둘', 'Noun'),
#   ('다', 'Adverb'),
#   ('최악', 'Noun'),
#   ('의', 'Josa'),
#   ('선택', 'Noun'),
#   ('지', 'Josa'),
#   ('임', 'Noun'),
#   ('에도', 'Josa'),
#   ('굳이', 'Noun'),
#   ('심상정', 'Noun'),
#   ('은', 'Josa'),
#   ('고려', 'Noun'),
#   ('조차', 'Josa'),
#   ('안', 'Noun'),
#   ('한다는', 'Modifier'),
#   ('거', 'Noun'),
#   ('이', 'Determiner'),
#   ('성적', 'Noun'),
#   ('으로', 'Josa'),
#   ('생각', 'Noun'),
#   ('하다', 'Verb'),
#   ('때', 'Noun'),
#   ('이재명', 'Noun'),
#   ('과', 'Josa'),
#   ('윤석열', 'Noun'),
#   ('은', 'Josa'),
#   ('진짜', 'Noun'),
#   ('좆', 'Noun'),
#   ('되다', 'Verb'),
#   ('선택', 'Noun'),
#   ('이지만', 'Josa'),
#   ('심상정', 'Noun'),
#   ('은', 'Josa'),
#   ('최소한', 'Noun'),
#   ('최악', 'Noun'),
#   ('은', 'Josa'),
#   ('피', 'Noun'),
#   ('하다', 'Verb'),
#   ('수', 'Noun'),
#   ('있다', 'Adjective'),
#   ('선택', 'Noun'),
#   ('을', 'Josa'),
#   ('안함', 'Noun'),
#   ('그게', 'Noun'),
#   ('한국', 'Noun'),
#   ('국민', 'Noun'),
#   ('수준', 'Noun'),
#   ('을', 'Josa'),
#   ('보여주다', 'Verb'),
#   ('방증임', 'Noun'),
#   ("',", 'Punctuation'),
#   ("'", 'Punctuation'),
#   ('심상정', 'Noun'),
#   ('아', 'Josa'),
#   ('줌', 'Noun'),
#   ('치매', 'Noun'),
#   ("',", 'Punctuation'),
#   ("'", 'Punctuation'),
#   ('이렇다', 'Adjective'),
#   ('절호', 'Noun'),
#   ('의', 'Josa'),
#   ('기회', 'Noun'),
#   ('조차도', 'Josa'),
#   ('안철수', 'Noun'),
#   ('따위', 'Noun'),
#   ('와', 'Josa'),
#   ('연대', 'Noun'),
#   ('를', 'Josa'),
#   ('하다', 'Verb'),
#   ('똥볼', 'Noun'),
#   ('을', 'Josa'),
#   ('차다', 'Verb'),
#   ('정의당', 'Noun'),
#   ('에', 'Josa'),
#   ('한심하다', 'Adjective'),
#   ('애도', 'Noun'),
#   ('를', 'Josa'),
#   ('표', 'Noun'),
#   ('하다', 'Verb'),
#   ('목마르다', 'Noun'),
#   ('고', 'Josa'),
#   ('바닷물', 'Noun'),
#   ('을', 'Josa'),
#   ('마시다', 'Verb'),
#   ('미련', 'Noun'),
#   ('함', 'Noun'),
#   ("',", 'Punctuation'),
#   ("'", 'Punctuation'),
#   ('정의당', 'Noun'),
#   ('은', 'Josa'),
#   ('지다', 'Verb'),
#   ('들다', 'Verb'),
#   ('밥그릇', 'Noun'),
#   ('을', 'Josa'),
#   ('걷어차다', 'Verb'),
#   ('심상정', 'Noun'),
#   ('이', 'Josa'),
#   ('이제', 'Noun'),
#   ('페미', 'Noun'),
#   ('당', 'Suffix'),
#   ('으로', 'Josa'),
#   ('만들다', 'Verb'),
#   ('국힘', 'Noun'),
#   ('당', 'Suffix'),
#   ('에', 'Josa'),
#   ('갖다', 'Verb'),
#   ('바치다', 'Verb'),
#   ('노회찬', 'Noun'),
#   ('살다', 'Verb'),
#   ('어쩔', 'Modifier'),
#   ('뻔', 'Noun'),
#   ('하다', 'Verb'),
#   ("',", 'Punctuation'),
#   ("'", 'Punctuation'),
#   ('과거', 'Noun'),
#   ('전두환', 'Noun'),
#   ('이', 'Josa'),
#   ('정의', 'Noun'),
#   ('사회', 'Noun'),
#   ('구현', 'Noun'),
#   ('이라는', 'Josa'),
#   ('표어', 'Noun'),
#   ('를', 'Josa'),
#   ('사용', 'Noun'),
#   ('하다', 'Verb'),
#   ('심상정', 'Noun'),
#   ('의', 'Josa'),
#   ('정의당', 'Noun'),
#   ('이', 'Josa'),
#   ('전두환', 'Noun'),
#   ('의', 'Josa'),
#   ('정의', 'Noun'),
#   ('사회', 'Noun'),
#   ('를', 'Josa'),
#   ('닮다', 'Verb'),
#   ("',", 'Punctuation'),
#   ("'", 'Punctuation'),
#   ('심상정', 'Noun'),
#   ('안철수', 'Noun'),
#   ('에', 'Josa'),
#   ('빠르다', 'Adjective'),
#   ('시일', 'Noun'),
#   ('내', 'Noun'),
#   ('조건', 'Noun'),
#   ('없이', 'Adverb'),
#   ('만나다', 'Verb'),
#   ('민주당', 'Noun'),
#   ('에', 'Josa'),
#   ('기생', 'Noun'),
#   ('하다', 'Verb'),
#   ('다른', 'Noun'),
#   ('군소', 'Noun'),
#   ('정당', 'Noun'),
#   ('죽이다', 'Verb'),
#   ('앞장서다', 'Verb'),
#   ('이제', 'Noun'),
#   ('오다', 'Verb'),
#   ("',", 'Punctuation'),
#   ("'", 'Punctuation'),
#   ('심상정', 'Noun'),
#   ('은', 'Josa'),
#   ('아무', 'Modifier'),
#   ('말', 'Noun'),
#   ('대다', 'Verb'),
#   ('해도', 'Noun'),
#   ('책임지다', 'Verb'),
#   ('일이', 'Modifier'),
#   ('없다', 'Adjective'),
#   ('얼마나', 'Noun'),
#   ('좋다', 'Adjective'),
#   ('암', 'Modifier'),
#   ('껏', 'Noun'),
#   ('시', 'Noun'),
#   ('부러', 'Noun'),
#   ('도', 'Josa'),
#   ('되다', 'Verb'),
#   ("',", 'Punctuation'),
#   ("'", 'Punctuation'),
#   ('아니다', 'Adjective'),
#   ('진짜', 'Noun'),
#   ('여자', 'Noun'),
#   ('들', 'Suffix'),
#   ('직장인', 'Noun'),
#   ('들', 'Suffix'),
#   ('만', 'Josa'),
#   ('심상정', 'Noun'),
#   ('찍다', 'Verb'),
#   ('심상정', 'Noun'),
#   ('되다', 'Verb'),
#   ('것', 'Noun'),
#   ('같다', 'Adjective'),
#   ('빨강', 'Noun'),
#   ('파랑', 'Noun'),
#   ('이', 'Josa'),
#   ('둘', 'Noun'),
#   ('다', 'Adverb'),
#   ('최악', 'Noun'),
#   ('인데', 'Josa'),
#   ('마음', 'Noun'),
#   ('에', 'Josa'),
#   ('안', 'Noun'),
#   ('들다', 'Verb'),
#   ('차', 'Noun'),
#   ('악인', 'Noun'),
#   ('사람', 'Noun'),
#   ('을', 'Josa'),
#   ('뽑다', 'Verb'),
#   ('게', 'Noun'),
#   ('낫', 'Noun'),
#   ('지', 'Josa'),
#   ('않다', 'Verb'),
#   ("',", 'Punctuation'),
#   ("'", 'Punctuation'),
#   ('성심당', 'Noun'),
#   ('축제', 'Noun'),
#   ('도', 'Josa'),
#   ('햇겟', 'Noun'),
#   ('다', 'Adverb'),
#   ('심상정', 'Noun'),
#   ('가보다', 'Verb'),
#   ("',", 'Punctuation'),
#   ("'", 'Punctuation'),
#   ('어제', 'Noun'),
#   ('스트레이트', 'Noun'),
#   ('지난주', 'Noun'),
#   ('랑', 'Josa'),
#   ('같다', 'Adjective'),
#   ('이고', 'Josa'),
#   ('이번', 'Noun'),
#   ('주다', 'Verb'),
#   ('걸그룹', 'Noun'),
#   ('오디션', 'Noun'),
#   ('프로', 'Noun'),
#   ('땜', 'Noun'),
#   ('에', 'Josa'),
#   ('결방', 'Noun'),
#   ('하고', 'Josa'),
#   ('다음주', 'Noun'),
#   ('에', 'Josa'),
#   ('하다', 'Verb'),
#   ('대다', 'Verb'),
#   ('폐', 'Noun'),
#   ('지각', 'Noun'),
#   ('인데', 'Josa'),
#   ('그리고', 'Conjunction'),
#   ('피디수첩', 'Noun'),
#   ('내일', 'Noun'),
#   ('은', 'Josa'),
#   ('위드', 'Noun'),
#   ('코로나', 'Noun'),
#   ('편이', 'Noun'),
#   ('고', 'Josa'),
#   ('분', 'Noun'),
#   ('토론', 'Noun'),
#   ('은', 'Josa'),
#   ('심상정', 'Noun'),
#   ('특집', 'Noun'),
#   ('이고', 'Josa'),
#   ('패널', 'Noun'),
#   ('은', 'Josa'),
#   ('심상정', 'Noun'),
#   ('장하나', 'Noun'),
#   ('성하다', 'Adjective'),
#   ('김종', 'Noun'),
#   ('혁', 'Noun'),
#   ('이란', 'Josa'),
#   ('다', 'Adverb'),
#   ('노잼', 'Noun'),
#   ('되다', 'Verb'),
#   ("',", 'Punctuation'),
#   ("'", 'Punctuation'),
#   ('노회찬', 'Noun'),
#   ('은', 'Josa'),
#   ('심상정', 'Noun'),
#   ('이아', 'Noun'),
#   ('니까', 'Josa'),
#   ('요', 'Noun'),
#   ('어쩌면', 'Noun'),
#   ('노회찬', 'Noun'),
#   ('은', 'Josa'),
#   ('정의당', 'Noun'),
#   ('의', 'Josa'),
#   ('막', 'Noun'),
#   ('가', 'Josa'),
#   ('파', 'Noun'),
#   ('에', 'Josa'),
#   ('걸리다', 'Verb'),
#   ('돌', 'Noun'),
#   ('이다', 'Verb'),
#   ("',", 'Punctuation'),
#   ("'", 'Punctuation'),
#   ('심상정', 'Noun'),
#   ('은', 'Josa'),
#   ('왜', 'Noun'),
#   ('윤석열', 'Noun'),
#   ('에게', 'Josa'),
#   ('러브콜', 'Noun'),
#   ('을', 'Josa'),
#   ('하다', 'Verb'),
#   ('이렇다', 'Adjective'),
#   ('주제', 'Noun'),
#   ('로', 'Josa'),
#   ('하다', 'Verb'),
#   ('배진교', 'Noun'),
#   ('가', 'Josa'),
#   ('나오다', 'Verb'),
#   ('있다', 'Adjective'),
#   ('심상정', 'Noun'),
#   ('흑화', 'Noun'),
#   ('그것', 'Noun'),
#   ('이', 'Josa'),
#   ('알', 'Noun'),
#   ('고', 'Josa'),
#   ('싶다', 'Verb'),
#   ('배진교', 'Noun'),
#   ('는', 'Josa'),
#   ('빼', 'Noun'),
#   ('엑', 'Exclamation'),
#   ("',", 'Punctuation'),
#   ("'", 'Punctuation'),
#   ('심상정', 'Noun'),
#   ('심리', 'Noun'),
#   ('분석', 'Noun'),
#   ('을', 'Josa'),
#   ('문제', 'Noun'),
#   ('삼다', 'Verb'),
#   ('보다', 'Verb'),
#   ('분석', 'Noun'),
#   ('이', 'Josa'),
#   ('정확하다', 'Adjective'),
#   ('찔리다', 'Verb'),
#   ('보다', 'Verb'),
#   ('욕구', 'Noun'),
#   ('를', 'Josa'),
#   ('숨다', 'Verb'),
#   ('사람', 'Noun'),
#   ('이', 'Josa'),
#   ('속마음', 'Noun'),
#   ('틀키', 'Noun'),
#   ('면', 'Josa'),
#   ('이렇다', 'Adjective'),
#   ('있다', 'Adjective'),
#   ('싶다', 'Verb'),
#   ("',", 'Punctuation'),
#   ("'", 'Punctuation'),
#   ('심상정', 'Noun'),
#   ('나오다', 'Verb'),
#   ('보다', 'Verb'),
#   ('대본', 'Noun'),
#   ('보다', 'Josa'),
#   ('더', 'Noun'),
#   ('잘', 'VerbPrefix'),
#   ('하다', 'Verb'),
#   ("',", 'Punctuation'),
#   ("'", 'Punctuation'),
#   ('안철수', 'Noun'),
#   ('와', 'Josa'),
#   ('심상정', 'Noun'),
#   ('이', 'Josa'),
#   ('친구', 'Noun'),
#   ('도', 'Josa'),
#   ('아니다', 'Adjective'),
#   ('심지어', 'Noun'),
#   ('정치', 'Noun'),
#   ('성도', 'Noun'),
#   ('판이하다', 'Adjective'),
#   ('다르다', 'Adjective'),
#   ('다른', 'Noun'),
#   ('편', 'Noun'),
#   ('끼리', 'Noun'),
#   ('가끔', 'Noun'),
#   ('은', 'Josa'),
#   ('협력', 'Noun'),
#   ('하다', 'Verb'),
#   ('떨어지다', 'Verb'),
#   ('건', 'Noun'),
#   ('기본', 'Noun'),
#   ('적', 'Suffix'),
#   ('인게', 'Josa'),
#   ('아니다', 'Adjective'),
#   ("',", 'Punctuation'),
#   ("'", 'Punctuation'),
#   ('아니다', 'Adjective'),
#   ('징', 'Noun'),
#   ('짜다', 'Verb'),
#   ('다', 'Adverb'),
#   ('뵈다', 'Verb'),
#   ('심상정', 'Noun'),
#   ('인물', 'Noun'),
#   ('비평', 'Noun'),
#   ('땜', 'Noun'),
#   ('에', 'Josa'),
#   ('그렇다', 'Adjective'),
#   ('우와', 'Exclamation'),
#   ('배다', 'Verb'),
#   ('뎅', 'Noun'),
#   ('이', 'Josa'),
#   ('소', 'Noun'),
#   ('갈다', 'Verb'),
#   ('딱', 'Modifier'),
#   ('지네', 'Noun'),
#   ('푸하하하', 'Noun'),
#   ("',", 'Punctuation'),
#   ("'", 'Punctuation'),
#   ('빗나가다', 'Verb'),
#   ('종부세', 'Noun'),
#   ('전망', 'Noun'),
#   ('대상자', 'Noun'),
#   ('만', 'Noun'),
#   ('명', 'Noun'),
#   ('육박', 'Noun'),
#   ('에도', 'Josa'),
#   ('여전하다', 'Adjective'),
#   ('일부', 'Noun'),
#   ('만', 'Josa'),
#   ('해당', 'Noun'),
#   ('국민', 'Noun'),
#   ('을', 'Josa'),
#   ('속이다', 'Verb'),
#   ('데', 'Noun'),
#   ('만', 'Josa'),
#   ('도', 'Noun'),
#   ('가', 'Josa'),
#   ('틀다', 'Verb'),
#   ('문재인', 'Noun'),
#   ('사기꾼', 'Noun'),
#   ('정부', 'Noun'),
#   ('문재인', 'Noun'),
#   ('은', 'Josa'),
#   ('진즉', 'Noun'),
#   ('에', 'Josa'),
#   ('탄핵', 'Noun'),
#   ('을', 'Josa'),
#   ('당하다', 'Adjective'),
#   ("',", 'Punctuation'),
#   ("'", 'Punctuation'),
#   ('음', 'Noun'),
#   ('윤석열', 'Noun'),
#   ('이', 'Josa'),
#   ('되다', 'Verb'),
#   ('거', 'Noun'),
#   ('같다', 'Adjective'),
#   ('음', 'Noun'),
#   ('그냥', 'Noun'),
#   ('원래', 'Noun'),
#   ('트위터', 'Noun'),
#   ('여론', 'Noun'),
#   ('이', 'Josa'),
#   ('남한', 'Noun'),
#   ('전체', 'Noun'),
#   ('의', 'Josa'),
#   ('여론', 'Noun'),
#   ('은', 'Josa'),
#   ('아니다', 'Adjective'),
#   ('그냥', 'Noun'),
#   ('음', 'Noun'),
#   ('윤석열', 'Noun'),
#   ('이', 'Josa'),
#   ('되다', 'Verb'),
#   ('거', 'Noun'),
#   ('같다', 'Adjective'),
#   ('안되다', 'Adjective'),
#   ('좋다', 'Adjective'),
#   ('심상정', 'Noun'),
#   ('씨', 'Suffix'),
#   ('가', 'Josa'),
#   ('되다', 'Verb'),
#   ('좋다', 'Adjective'),
#   ("',", 'Punctuation'),
#   ("'", 'Punctuation'),
#   ('문재인', 'Noun'),
#   ('정부', 'Noun'),
#   ('시작', 'Noun'),
#   ('하다', 'Verb'),
#   ('때', 'Noun'),
#   ('새누리', 'Noun'),
#   ('는', 'Josa'),
#   ('역사', 'Noun'),
#   ('속', 'Noun'),
#   ('으로', 'Josa'),
#   ('사라지다', 'Verb'),
#   ('민주당', 'Noun'),
#   ('과', 'Josa'),
#   ('정의당', 'Noun'),
#   ('두', 'Noun'),
#   ('정당', 'Noun'),
#   ('체제', 'Noun'),
#   ('로', 'Josa'),
#   ('갈다', 'Verb'),
#   ('거', 'Noun'),
#   ('라고', 'Josa'),
#   ('하다', 'Verb'),
#   ('사람', 'Noun'),
#   ('정말', 'Noun'),
#   ('많다', 'Adjective'),
#   ('정의당', 'Noun'),
#   ('이', 'Josa'),
#   ('경선', 'Noun'),
#   ('을', 'Josa'),
#   ('날로', 'Noun'),
#   ('해', 'Noun'),
#   ('먹다', 'Verb'),
#   ('정의당', 'Noun'),
#   ('은', 'Josa'),
#   ('아웃', 'Noun'),
#   ('오브', 'Noun'),
#   ('안중', 'Noun'),
#   ('되다', 'Verb'),
#   ('버리다', 'Verb'),
#   ('좀', 'Noun'),
#   ('자다', 'Verb'),
#   ('하다', 'Verb'),
#   ("',", 'Punctuation'),
#   ("'", 'Punctuation'),
#   ('꿈', 'Noun'),
#   ('은', 'Josa'),
#   ('꾸다', 'Verb'),
#   ('당연하다', 'Adjective'),
#   ('그리고', 'Conjunction'),
#   ('꿈', 'Noun'),
#   ('을', 'Josa'),
#   ('나누다', 'Verb'),
#   ('노회찬', 'Noun'),
#   ('사후', 'Noun'),
#   ('정의당', 'Noun'),
#   ('의', 'Josa'),
#   ('색깔', 'Noun'),
#   ('이', 'Josa'),
#   ('너무', 'Adverb'),
#   ('많이', 'Adverb'),
#   ('퇴색', 'Noun'),
#   ('되어다', 'Verb'),
#   ('영상', 'Noun'),
#   ('심상정', 'Noun'),
#   ('이', 'Josa'),
#   ('또', 'Noun'),
#   ('다시', 'Noun'),
#   ('대통령', 'Noun'),
#   ('에', 'Josa'),
#   ('도전', 'Noun'),
#   ('하다', 'Verb'),
#   ('이유', 'Noun'),
#   ('출처', 'Noun'),
#   ('시사', 'Noun'),
#   ('네이버', 'Noun'),
#   ('뉴스', 'Noun'),
#   ("',", 'Punctuation'),
#   ("'", 'Punctuation'),
#   ('뭘', 'Noun'),
#   ('고민', 'Noun'),
#   ('하다', 'Verb'),
#   ('심상정', 'Noun'),
#   ('있다', 'Adjective'),
#   ("',", 'Punctuation'),
#   ("'", 'Punctuation'),
#   ('와아', 'Exclamation'),
#   ('쉴드치다', 'Verb'),
#   ('껄', 'Noun'),
#   ('치다', 'Verb'),
#   ('심상정', 'Noun'),
#   ('에', 'Josa'),
#   ('표', 'Noun'),
#   ('분산', 'Noun'),
#   ('막다', 'Verb'),
#   ('스토커', 'Noun'),
#   ('처럼', 'Josa'),
#   ('하다', 'Verb'),
#   ('것', 'Noun'),
#   ('도', 'Josa'),
#   ('웃기', 'Noun'),
#   ('지만', 'Josa'),
#   ('비판', 'Noun'),
#   ('자체', 'Noun'),
#   ('가', 'Josa'),
#   ('딸', 'Noun'),
#   ('어쩌', 'Noun'),
#   ('고', 'Josa'),
#   ('완전', 'Noun'),
#   ('코미디', 'Noun'),
#   ('이재명', 'Noun'),
#   ('이', 'Josa'),
#   ('뭐라다', 'Verb'),
#   ('다', 'Adverb'),
#   ('들다', 'Verb'),
#   ('왜', 'Noun'),
#   ('이르다', 'Verb'),
#   ("',", 'Punctuation'),
#   ("'", 'Punctuation'),
#   ('시발', 'Noun'),
#   ('진짜', 'Noun'),
#   ('비참하다', 'Adjective'),
#   ('포인트', 'Noun'),
#   ('는', 'Josa'),
#   ('저런', 'Noun'),
#   ('새끼', 'Noun'),
#   ('가', 'Josa'),
#   ('정말', 'Noun'),
#   ('대통령', 'Noun'),
#   ('이', 'Josa'),
#   ('되다', 'Verb'),
#   ('모르다', 'Verb'),
#   ('거지', 'Noun'),
#   ('심상정', 'Noun'),
#   ('안철수', 'Noun'),
#   ('는', 'Josa'),
#   ('가능성', 'Noun'),
#   ('이라도', 'Josa'),
#   ('없다', 'Adjective'),
#   ('저', 'Determiner'),
#   ('새끼', 'Noun'),
#   ('는', 'Josa'),
#   ('세상', 'Noun'),
#   ('에', 'Josa'),
#   ('시발', 'Noun'),
#   ("',", 'Punctuation'),
#   ("'", 'Punctuation'),
#   ('근데', 'Adverb'),
#   ('이', 'Determiner'),
#   ('것', 'Noun'),
#   ('은', 'Josa'),
#   ('맞다', 'Verb'),
#   ('심상정', 'Noun'),
#   ('가다', 'Verb'),
#   ("',", 'Punctuation'),
#   ("'", 'Punctuation'),
#   ('몇', 'Noun'),
#   ('년', 'Noun'),
#   ('째', 'Suffix'),
#   ('심상정', 'Noun'),
#   ('후보', 'Noun'),
#   ...],
#  1)

# %% [markdown]
# # 워드클라우드

# %%
# 빈도수 세기

from collections import Counter
counter = Counter(tokenize_docs[0][0])
count_words = sorted(counter.items(), key=lambda x:-x[1])
count_words
# Out:
# [(('심상정', 'Noun'), 371),
#  (("',", 'Punctuation'), 337),
#  (("'", 'Punctuation'), 337),
#  (('하다', 'Verb'), 292),
#  (('이', 'Josa'), 211),
#  (('을', 'Josa'), 159),
#  (('은', 'Josa'), 119),
#  (('에', 'Josa'), 119),
#  (('의', 'Josa'), 116),
#  (('안철수', 'Noun'), 110),
#  (('가', 'Josa'), 108),
#  (('후보', 'Noun'), 105),
#  (('들', 'Suffix'), 104),
#  (('를', 'Josa'), 93),
#  (('는', 'Josa'), 76),
#  (('이재명', 'Noun'), 71),
#  (('정의당', 'Noun'), 66),
#  (('도', 'Josa'), 65),
#  (('되다', 'Verb'), 62),
#  (('있다', 'Adjective'), 57),
#  (('윤석열', 'Noun'), 57),
#  (('뽑다', 'Verb'), 55),
#  (('아니다', 'Adjective'), 51),
#  (('으로', 'Josa'), 47),
#  (('것', 'Noun'), 46),
#  (('없다', 'Adjective'), 44),
#  (('만나다', 'Verb'), 40),
#  (('보다', 'Verb'), 39),
#  (('대선', 'Noun'), 39),
#  (('없이', 'Adverb'), 32),
#  (('과', 'Josa'), 32),
#  (('조건', 'Noun'), 31),
#  (('적', 'Suffix'), 31),
#  (('같다', 'Adjective'), 29),
#  (('에서', 'Josa'), 29),
#  (('민주당', 'Noun'), 29),
#  (('이', 'Noun'), 28),
#  (('로', 'Josa'), 28),
#  (('말', 'Noun'), 27),
#  (('양', 'Modifier'), 26),
#  (('다', 'Adverb'), 26),
#  (('지대', 'Noun'), 26),
#  (('김어준', 'Noun'), 26),
#  (('한', 'Josa'), 25),
#  (('심리', 'Noun'), 25),
#  (('대통령', 'Noun'), 25),
#  (('제', 'Modifier'), 25),
#  (('찍다', 'Verb'), 24),
#  (('않다', 'Verb'), 23),
#  (('왜', 'Noun'), 23),
#  (('고', 'Josa'), 23),
#  (('나오다', 'Verb'), 23),
#  (('당', 'Modifier'), 22),
#  (('체제', 'Noun'), 22),
#  (('정치', 'Noun'), 22),
#  (('이', 'Determiner'), 21),
#  (('좋다', 'Adjective'), 21),
#  (('그렇다', 'Adjective'), 21),
#  (('뉴스', 'Noun'), 21),
#  (('당', 'Noun'), 21),
#  (('방송', 'Noun'), 21),
#  (('제안', 'Noun'), 20),
#  (('그', 'Noun'), 20),
#  (('분석', 'Noun'), 20),
#  (('와', 'Josa'), 20),
#  (('거', 'Noun'), 20),
#  (('진짜', 'Noun'), 20),
#  (('이번', 'Noun'), 19),
#  (('안', 'VerbPrefix'), 19),
#  (('만', 'Josa'), 19),
#  (('국민', 'Noun'), 19),
#  (('내', 'Noun'), 18),
#  (('김동연', 'Noun'), 18),
#  (('나', 'Josa'), 18),
#  (('에게', 'Josa'), 18),
#  (('싶다', 'Verb'), 18),
#  (('가다', 'Verb'), 18),
#  (('일', 'Noun'), 18),
#  (('종식', 'Noun'), 17),
#  (('생각', 'Noun'), 17),
#  (('안', 'Noun'), 17),
#  (('여자', 'Noun'), 17),
#  (('비판', 'Noun'), 17),
#  (('근데', 'Adverb'), 17),
#  (('진보', 'Noun'), 17),
#  (('인', 'Josa'), 16),
#  (('못', 'VerbPrefix'), 15),
#  (('들다', 'Verb'), 15),
#  (('의원', 'Noun'), 15),
#  (('사회', 'Noun'), 15),
#  (('이고', 'Josa'), 15),
#  (('선택', 'Noun'), 15),
#  (('당', 'Suffix'), 15),
#  (('라고', 'Josa'), 15),
#  (('공조', 'Noun'), 15),
#  (('까지', 'Josa'), 15),
#  (('다음', 'Noun'), 15),
#  (('여성', 'Noun'), 15),
#  (('이제', 'Noun'), 14),
#  (('정책', 'Noun'), 14),
#  (('연대', 'Noun'), 14),
#  (('표', 'Noun'), 14),
#  (('그리고', 'Conjunction'), 14),
#  (('알다', 'Verb'), 14),
#  (('인데', 'Josa'), 13),
#  (('이렇다', 'Adjective'), 13),
#  (('출처', 'Noun'), 13),
#  (('나', 'Noun'), 13),
#  (('사람', 'Noun'), 12),
#  (('지지', 'Noun'), 12),
#  (('잘', 'VerbPrefix'), 12),
#  (('때', 'Noun'), 12),
#  (('하고', 'Josa'), 12),
#  (('더', 'Noun'), 12),
#  (('무슨', 'Noun'), 12),
#  (('지지율', 'Noun'), 12),
#  (('하', 'Suffix'), 12),
#  (('이다', 'Josa'), 11),
#  (('서', 'Josa'), 11),
#  (('돼다', 'Verb'), 11),
#  (('함께', 'Adverb'), 11),
#  (('한국', 'Noun'), 11),
#  (('정당', 'Noun'), 11),
#  (('이다', 'Verb'), 11),
#  (('문제', 'Noun'), 11),
#  (('힘', 'Noun'), 11),
#  (('중', 'Noun'), 11),
#  (('부터', 'Josa'), 11),
#  (('위', 'Noun'), 11),
#  (('저', 'Noun'), 11),
#  (('미치다', 'Adjective'), 11),
#  (('심', 'Noun'), 11),
#  (('심리학자', 'Noun'), 11),
#  (('투표', 'Noun'), 10),
#  (('빠르다', 'Adjective'), 10),
#  (('회', 'Noun'), 10),
#  (('해주다', 'Verb'), 10),
#  (('한', 'Determiner'), 10),
#  (('함', 'Noun'), 10),
#  (('맞다', 'Verb'), 10),
#  (('만들다', 'Verb'), 10),
#  (('문재인', 'Noun'), 10),
#  (('여론', 'Noun'), 10),
#  (('안되다', 'Adjective'), 10),
#  (('두', 'Noun'), 10),
#  (('정말', 'Noun'), 10),
#  (('이유', 'Noun'), 10),
#  (('년', 'Noun'), 10),
#  (('진보당', 'Noun'), 10),
#  (('이나', 'Josa'), 10),
#  (('시민', 'Noun'), 10),
#  (('다른', 'Noun'), 9),
#  (('보다', 'Josa'), 9),
#  (('시일', 'Noun'), 9),
#  (('수', 'Noun'), 9),
#  (('아', 'Josa'), 9),
#  (('지다', 'Verb'), 9),
#  (('랑', 'Josa'), 9),
#  (('건', 'Noun'), 9),
#  (('좀', 'Noun'), 9),
#  (('로', 'Noun'), 9),
#  (('선거', 'Noun'), 9),
#  (('위해', 'Noun'), 9),
#  (('윤', 'Noun'), 9),
#  (('손', 'Noun'), 9),
#  (('이랑', 'Josa'), 9),
#  (('국민의당', 'Noun'), 9),
#  (('여', 'Modifier'), 9),
#  (('성', 'Modifier'), 9),
#  (('조사', 'Noun'), 9),
#  (('사적', 'Noun'), 9),
#  (('욕망', 'Noun'), 9),
#  (('정치인', 'Noun'), 8),
#  (('동', 'Modifier'), 8),
#  (('분', 'Noun'), 8),
#  (('에도', 'Josa'), 8),
#  (('허경영', 'Noun'), 8),
#  (('책', 'Noun'), 8),
#  (('늘다', 'Verb'), 8),
#  (('니', 'Noun'), 8),
#  (('내다', 'Verb'), 8),
#  (('둘', 'Noun'), 8),
#  (('국힘', 'Noun'), 8),
#  (('정의', 'Noun'), 8),
#  (('뵈다', 'Verb'), 8),
#  (('시작', 'Noun'), 8),
#  (('속', 'Noun'), 8),
#  (('버리다', 'Verb'), 8),
#  (('네이버', 'Noun'), 8),
#  (('고민', 'Noun'), 8),
#  (('말다', 'Verb'), 8),
#  (('걸', 'Noun'), 8),
#  (('다', 'Josa'), 8),
#  (('놈', 'Noun'), 8),
#  (('전', 'Noun'), 8),
#  (('시대', 'Noun'), 8),
#  (('술', 'Noun'), 8),
#  (('인정', 'Noun'), 8),
#  (('노회찬', 'Noun'), 7),
#  (('차다', 'Verb'), 7),
#  (('받다', 'Verb'), 7),
#  (('듯', 'Noun'), 7),
#  (('연구소', 'Noun'), 7),
#  (('공', 'Modifier'), 7),
#  (('쓰다', 'Verb'), 7),
#  (('주다', 'Verb'), 7),
#  (('라는', 'Josa'), 7),
#  (('임', 'Noun'), 7),
#  (('오다', 'Verb'), 7),
#  (('대다', 'Verb'), 7),
#  (('욕구', 'Noun'), 7),
#  (('면', 'Josa'), 7),
#  (('갈다', 'Verb'), 7),
#  (('그냥', 'Noun'), 7),
#  (('먹다', 'Verb'), 7),
#  (('또', 'Noun'), 7),
#  (('다시', 'Noun'), 7),
#  (('처럼', 'Josa'), 7),
#  (('님', 'Suffix'), 7),
#  (('싫다', 'Adjective'), 7),
#  (('보고', 'Noun'), 7),
#  (('지금', 'Noun'), 7),
#  (('를', 'Noun'), 7),
#  (('난', 'Noun'), 7),
#  (('이야기', 'Noun'), 7),
#  (('앞', 'Noun'), 7),
#  (('필요하다', 'Adjective'), 7),
#  (('이라', 'Josa'), 7),
#  (('대표', 'Noun'), 7),
#  (('다스', 'Noun'), 7),
#  (('어떻다', 'Adjective'), 7),
#  (('의미', 'Noun'), 7),
#  (('지지도', 'Noun'), 7),
#  (('우리', 'Noun'), 7),
#  (('트럼프', 'Noun'), 7),
#  (('남자', 'Noun'), 6),
#  (('크다', 'Verb'), 6),
#  (('이라고', 'Josa'), 6),
#  (('요', 'Noun'), 6),
#  (('이라는', 'Josa'), 6),
#  (('수준', 'Noun'), 6),
#  (('지', 'Josa'), 6),
#  (('살다', 'Verb'), 6),
#  (('게', 'Noun'), 6),
#  (('성심당', 'Noun'), 6),
#  (('도', 'Noun'), 6),
#  (('많다', 'Adjective'), 6),
#  (('모르다', 'Verb'), 6),
#  (('요', 'Josa'), 6),
#  (('미래', 'Noun'), 6),
#  (('노동', 'Noun'), 6),
#  (('쪽', 'Noun'), 6),
#  (('이지', 'Josa'), 6),
#  (('네', 'Josa'), 6),
#  (('뭐', 'Noun'), 6),
#  (('이', 'Suffix'), 6),
#  (('올리다', 'Verb'), 6),
#  (('유시민', 'Noun'), 6),
#  (('자기', 'Noun'), 6),
#  (('만남', 'Noun'), 6),
#  (('오늘', 'Noun'), 6),
#  (('워맨스', 'Noun'), 6),
#  (('노동자', 'Noun'), 6),
#  (('에선', 'Josa'), 6),
#  (('해보다', 'Verb'), 6),
#  (('대해', 'Noun'), 6),
#  (('때문', 'Noun'), 6),
#  (('보기', 'Noun'), 6),
#  (('정권', 'Noun'), 6),
#  (('교체', 'Noun'), 6),
#  (('스', 'Noun'), 6),
#  (('실', 'Noun'), 6),
#  (('나다', 'Verb'), 6),
#  (('선언', 'Noun'), 6),
#  (('장', 'Noun'), 6),
#  (('못', 'Noun'), 6),
#  (('강하다', 'Adjective'), 6),
#  (('양당제', 'Noun'), 6),
#  (('번', 'Noun'), 6),
#  (('소리', 'Noun'), 5),
#  (('페미', 'Noun'), 5),
#  (('데', 'Noun'), 5),
#  (('의', 'Noun'), 5),
#  (('지', 'Modifier'), 5),
#  (('내용', 'Noun'), 5),
#  (('이해', 'Noun'), 5),
#  (('김태형', 'Noun'), 5),
#  (('인물', 'Noun'), 5),
#  (('서다', 'Verb'), 5),
#  (('믿다', 'Verb'), 5),
#  (('너', 'Noun'), 5),
#  (('정도', 'Noun'), 5),
#  (('나라', 'Noun'), 5),
#  (('에는', 'Josa'), 5),
#  (('딱', 'Adverb'), 5),
#  (('최악', 'Noun'), 5),
#  (('한다는', 'Modifier'), 5),
#  (('보여주다', 'Verb'), 5),
#  (('얼마나', 'Noun'), 5),
#  (('폐', 'Noun'), 5),
#  (('니까', 'Josa'), 5),
#  (('명', 'Noun'), 5),
#  (('당하다', 'Adjective'), 5),
#  (('음', 'Noun'), 5),
#  (('역사', 'Noun'), 5),
#  (('너무', 'Adverb'), 5),
#  (('많이', 'Adverb'), 5),
#  (('영상', 'Noun'), 5),
#  (('시사', 'Noun'), 5),
#  (('자체', 'Noun'), 5),
#  (('이라도', 'Josa'), 5),
#  (('세상', 'Noun'), 5),
#  (('국가', 'Noun'), 5),
#  (('세력', 'Noun'), 5),
#  (('얻다', 'Verb'), 5),
#  (('당선', 'Noun'), 5),
#  (('성', 'Suffix'), 5),
#  (('페미니스트', 'Noun'), 5),
#  (('현장', 'Noun'), 5),
#  (('안티', 'Noun'), 5),
#  (('바꾸다', 'Verb'), 5),
#  (('이상', 'Noun'), 5),
#  (('두다', 'Verb'), 5),
#  (('걸다', 'Verb'), 5),
#  (('욕', 'Noun'), 5),
#  (('어디', 'Noun'), 5),
#  (('온', 'Noun'), 5),
#  (('그래서', 'Adverb'), 5),
#  (('등', 'Noun'), 5),
#  (('결과', 'Noun'), 5),
#  (('말고', 'Josa'), 5),
#  (('두', 'Determiner'), 5),
#  (('고', 'Noun'), 5),
#  (('게', 'Josa'), 5),
#  (('삶', 'Noun'), 5),
#  (('결국', 'Adverb'), 5),
#  (('똥', 'Noun'), 5),
#  (('높다', 'Adjective'), 5),
#  (('선', 'Noun'), 5),
#  (('청년', 'Noun'), 5),
#  (('눈', 'Noun'), 5),
#  (('최', 'Noun'), 5),
#  (('정신', 'Noun'), 5),
#  (('한번', 'Noun'), 5),
#  (('남', 'Noun'), 5),
#  (('일제', 'Noun'), 5),
#  (('충분하다', 'Adjective'), 5),
#  (('이다', 'Adjective'), 5),
#  (('라', 'Josa'), 5),
#  (('최선', 'Noun'), 5),
#  (('야당', 'Noun'), 5),
#  (('후', 'Noun'), 4),
#  (('좌파', 'Noun'), 4),
#  (('밉다', 'Adjective'), 4),
#  (('이네', 'Josa'), 4),
#  (('그때', 'Noun'), 4),
#  (('바라다', 'Verb'), 4),
#  (('입장', 'Noun'), 4),
#  (('치다', 'Verb'), 4),
#  (('절대', 'Noun'), 4),
#  (('갖다', 'Verb'), 4),
#  (('전두환', 'Noun'), 4),
#  (('마음', 'Noun'), 4),
#  (('차', 'Noun'), 4),
#  (('가보다', 'Verb'), 4),
#  (('프로', 'Noun'), 4),
#  (('원래', 'Noun'), 4),
#  (('씨', 'Suffix'), 4),
#  (('사라지다', 'Verb'), 4),
#  (('경선', 'Noun'), 4),
#  (('자다', 'Verb'), 4),
#  (('되어다', 'Verb'), 4),
#  (('도전', 'Noun'), 4),
#  (('완전', 'Noun'), 4),
#  (('이르다', 'Verb'), 4),
#  (('시발', 'Noun'), 4),
#  (('새끼', 'Noun'), 4),
#  (('가능성', 'Noun'), 4),
#  (('저', 'Determiner'), 4),
#  (('민주', 'Noun'), 4),
#  (('원하다', 'Adjective'), 4),
#  (('권력', 'Noun'), 4),
#  (('잡다', 'Verb'), 4),
#  (('하나', 'Noun'), 4),
#  (('죽다', 'Verb'), 4),
#  (('써다', 'Verb'), 4),
#  (('글', 'Noun'), 4),
#  (('월', 'Noun'), 4),
#  (('여론조사', 'Noun'), 4),
#  (('지난', 'Noun'), 4),
#  (('뿐이다', 'Adjective'), 4),
#  (('시동', 'Noun'), 4),
#  (('차악', 'Noun'), 4),
#  (('나은', 'Noun'), 4),
#  (('로운', 'Josa'), 4),
#  (('인가', 'Josa'), 4),
#  (('살', 'Noun'), 4),
#  (('뒤', 'Noun'), 4),
#  (('의당', 'Noun'), 4),
#  (('본인', 'Noun'), 4),
#  (('나이', 'Noun'), 4),
#  (('씨발', 'Noun'), 4),
#  (('하', 'Exclamation'), 4),
#  (('홍준표', 'Noun'), 4),
#  (('출연', 'Noun'), 4),
#  (('며느리', 'Noun'), 4),
#  (('곳', 'Noun'), 4),
#  (('이던', 'Josa'), 4),
#  (('궁금하다', 'Adjective'), 4),
#  (('들어가다', 'Verb'), 4),
#  (('답', 'Noun'), 4),
#  (('누가', 'Noun'), 4),
#  (('음식', 'Noun'), 4),
#  (('짓', 'Noun'), 4),
#  (('공약', 'Noun'), 4),
#  (('및', 'Noun'), 4),
#  (('민낯', 'Noun'), 4),
#  (('이석기', 'Noun'), 4),
#  (('석방', 'Noun'), 4),
#  (('해산', 'Noun'), 4),
#  (('무효', 'Noun'), 4),
#  (('가지', 'Noun'), 4),
#  (('대위', 'Noun'), 4),
#  (('대남', 'Noun'), 4),
#  (('거나', 'Noun'), 4),
#  (('제발', 'Noun'), 4),
#  (('도이치', 'Noun'), 4),
#  (('모터', 'Noun'), 4),
#  (('순', 'Modifier'), 4),
#  (('어게인', 'Noun'), 4),
#  (('감', 'Noun'), 4),
#  (('지랄', 'Noun'), 4),
#  (('대가', 'Noun'), 4),
#  (('지지자', 'Noun'), 4),
#  (('들이다', 'Verb'), 4),
#  (('동안', 'Noun'), 4),
#  (('대', 'Modifier'), 4),
#  (('꼴', 'Noun'), 4),
#  (('단', 'Modifier'), 4),
#  (('일화', 'Noun'), 4),
#  (('시키다', 'Verb'), 4),
#  (('거기', 'Noun'), 4),
#  (('대전', 'Noun'), 4),
#  (('기대', 'Noun'), 4),
#  (('보이다', 'Verb'), 4),
#  (('기록', 'Noun'), 4),
#  (('차기', 'Noun'), 4),
#  (('물', 'Noun'), 4),
#  (('기자', 'Noun'), 4),
#  (('기대다', 'Verb'), 4),
#  (('격차', 'Noun'), 4),
#  (('모든', 'Noun'), 4),
#  (('비', 'Noun'), 4),
#  (('주', 'Modifier'), 4),
#  (('혜영', 'Noun'), 4),
#  (('전환', 'Noun'), 4),
#  (('추진', 'Noun'), 4),
#  (('에겐', 'Josa'), 4),
#  (('인터뷰', 'Noun'), 4),
#  (('여당', 'Noun'), 4),
#  (('이낙연', 'Noun'), 4),
#  (('정체', 'Noun'), 4),
#  (('박원순', 'Noun'), 4),
#  (('걍', 'Adverb'), 4),
#  (('어차피', 'Noun'), 4),
#  (('기자회견', 'Noun'), 3),
#  (('놓다', 'Verb'), 3),
#  (('모습', 'Noun'), 3),
#  (('언급', 'Noun'), 3),
#  (('트위터', 'Noun'), 3),
#  (('역시', 'Noun'), 3),
#  (('엔', 'Josa'), 3),
#  (('소장', 'Noun'), 3),
#  (('측', 'Suffix'), 3),
#  (('요청', 'Noun'), 3),
#  (('얘기', 'Noun'), 3),
#  (('분들', 'Suffix'), 3),
#  (('투자', 'Noun'), 3),
#  (('망하다', 'Adjective'), 3),
#  (('꼬', 'Noun'), 3),
#  (('사태', 'Noun'), 3),
#  (('좆', 'Noun'), 3),
#  (('땜', 'Noun'), 3),
#  (('토론', 'Noun'), 3),
#  (('이란', 'Josa'), 3),
#  (('돌', 'Noun'), 3),
#  (('배진교', 'Noun'), 3),
#  (('그것', 'Noun'), 3),
#  (('정확하다', 'Adjective'), 3),
#  (('떨어지다', 'Verb'), 3),
#  (('짜다', 'Verb'), 3),
#  (('정부', 'Noun'), 3),
#  (('해', 'Noun'), 3),
#  (('나누다', 'Verb'), 3),
#  (('뭘', 'Noun'), 3),
#  (('막다', 'Verb'), 3),
#  (('어쩌', 'Noun'), 3),
#  (('뭐라다', 'Verb'), 3),
#  (('포인트', 'Noun'), 3),
#  (('거지', 'Noun'), 3),
#  (('계속', 'Noun'), 3),
#  (('답답하다', 'Adjective'), 3),
#  (('구', 'Modifier'), 3),
#  (('보다는', 'Josa'), 3),
#  (('당원', 'Noun'), 3),
#  (('간다', 'Noun'), 3),
#  (('전화', 'Noun'), 3),
#  (('따다', 'Verb'), 3),
#  (('주', 'Noun'), 3),
#  (('꺼내다', 'Verb'), 3),
#  (('빠지다', 'Verb'), 3),
#  (('연', 'Modifier'), 3),
#  (('신지', 'Noun'), 3),
#  (('제일', 'Noun'), 3),
#  (('보수', 'Noun'), 3),
#  (('대안', 'Noun'), 3),
#  (('가요', 'Noun'), 3),
#  (('겠다', 'Verb'), 3),
#  (('김종인', 'Noun'), 3),
#  (('손잡다', 'Verb'), 3),
#  (('백서', 'Noun'), 3),
#  (('법', 'Noun'), 3),
#  (('남다', 'Verb'), 3),
#  (('판', 'Noun'), 3),
#  (('오마이', 'Noun'), 3),
#  (('귀인', 'Noun'), 3),
#  (('먼저', 'Noun'), 3),
#  (('과의', 'Josa'), 3),
#  (('상대', 'Noun'), 3),
#  (('내미다', 'Verb'), 3),
#  (('내', 'Determiner'), 3),
#  (('더럽다', 'Adjective'), 3),
#  (('개', 'Noun'), 3),
#  (('짓거리', 'Noun'), 3),
#  (('소', 'Modifier'), 3),
#  (('뿐', 'Noun'), 3),
#  (('심상', 'Noun'), 3),
#  (('새', 'Noun'), 3),
#  (('그리다', 'Verb'), 3),
#  (('일이', 'Noun'), 3),
#  (('와중', 'Noun'), 3),
#  (('붙다', 'Verb'), 3),
#  (('란', 'Noun'), 3),
#  (('에서만', 'Josa'), 3),
#  (('맛', 'Noun'), 3),
#  (('윤석렬', 'Noun'), 3),
#  (('첫', 'Noun'), 3),
#  (('길', 'Noun'), 3),
#  (('먹기', 'Noun'), 3),
#  (('제', 'Noun'), 3),
#  (('가장', 'Noun'), 3),
#  (('은', 'Noun'), 3),
#  (('인지', 'Josa'), 3),
#  (('아', 'Exclamation'), 3),
#  (('공영', 'Noun'), 3),
#  (('온갖', 'Noun'), 3),
#  (('연예', 'Noun'), 3),
#  (('이정희', 'Noun'), 3),
#  (('같이', 'Adverb'), 3),
#  (('특히', 'Adverb'), 3),
#  (('없애다', 'Verb'), 3),
#  (('차리다', 'Verb'), 3),
#  (('사진관', 'Noun'), 3),
#  (('주말', 'Noun'), 3),
#  (('바라보다', 'Verb'), 3),
#  (('꼭', 'Noun'), 3),
#  (('겁니다', 'Verb'), 3),
#  (('아직', 'Adverb'), 3),
#  (('아주', 'Noun'), 3),
#  (('나가다', 'Verb'), 3),
#  (('통합', 'Noun'), 3),
#  (('차라리', 'Noun'), 3),
#  (('그렇게', 'Adverb'), 3),
#  (('류', 'Noun'), 3),
#  (('말씀', 'Noun'), 3),
#  (('별로', 'Noun'), 3),
#  (('식', 'Noun'), 3),
#  (('박빙', 'Noun'), 3),
#  (('필요', 'Noun'), 3),
#  (('관통', 'Noun'), 3),
#  (('명의', 'Noun'), 3),
#  (('거장', 'Noun'), 3),
#  (('용인', 'Noun'), 3),
#  (('예술', 'Noun'), 3),
#  (('느껴지다', 'Verb'), 3),
#  (('호의', 'Noun'), 3),
#  (('무한', 'Noun'), 3),
#  (('질주', 'Noun'), 3),
#  (('이틀', 'Noun'), 3),
#  (('위원회', 'Noun'), 3),
#  (('며', 'Noun'), 3),
#  (('변화', 'Noun'), 3),
#  (('며', 'Josa'), 3),
#  (('확실하다', 'Adjective'), 3),
#  (('드리다', 'Verb'), 3),
#  (('해내다', 'Verb'), 3),
#  (('모두', 'Noun'), 3),
#  (('타임즈', 'Noun'), 3),
#  (('줄', 'Noun'), 3),
#  (('무시', 'Noun'), 3),
#  (('두렵다', 'Adjective'), 3),
#  (('단', 'Noun'), 3),
#  (('불쾌하다', 'Adjective'), 3),
#  (('표현', 'Noun'), 3),
#  (('아기', 'Noun'), 3),
#  (('햇', 'Noun'), 3),
#  (('라도', 'Josa'), 3),
#  (('조문', 'Noun'), 3),
#  (('테', 'Noun'), 3),
#  (('중', 'Suffix'), 3),
#  (('건가', 'Noun'), 3),
#  (('그', 'Determiner'), 3),
#  (('노동운동', 'Noun'), 3),
#  (('대결', 'Noun'), 3),
#  (('똑같이', 'Adverb'), 3),
#  (('옳다', 'Adjective'), 2),
#  (('이런', 'Modifier'), 2),
#  (('적어도', 'Adverb'), 2),
#  (('싸다', 'Verb'), 2),
#  (('안쓰럽다', 'Adjective'), 2),
#  (('사욕', 'Noun'), 2),
#  (('자신', 'Noun'), 2),
#  (('만으로', 'Josa'), 2),
#  (('일부', 'Noun'), 2),
#  (('반응', 'Noun'), 2),
#  (('치기', 'Noun'), 2),
#  (('총', 'Modifier'), 2),
#  (('도움', 'Noun'), 2),
#  (('대한', 'Noun'), 2),
#  (('어른', 'Noun'), 2),
#  (('크게', 'Noun'), 2),
#  (('변하다', 'Adjective'), 2),
#  (('딴지', 'Noun'), 2),
#  (('야', 'Josa'), 2),
#  (('저렇게', 'Adverb'), 2),
#  (('김', 'Noun'), 2),
#  (('해먹', 'Noun'), 2),
#  (('대가리', 'Noun'), 2),
#  (('강소기업', 'Noun'), 2),
#  (('코인', 'Noun'), 2),
#  (('박근혜', 'Noun'), 2),
#  (('그게', 'Noun'), 2),
#  (('줌', 'Noun'), 2),
#  (('치매', 'Noun'), 2),
#  (('조차도', 'Josa'), 2),
#  (('따위', 'Noun'), 2),
#  (('밥그릇', 'Noun'), 2),
#  (('과거', 'Noun'), 2),
#  (('죽이다', 'Verb'), 2),
#  (('해도', 'Noun'), 2),
#  (('일이', 'Modifier'), 2),
#  (('시', 'Noun'), 2),
#  (('낫', 'Noun'), 2),
#  (('패널', 'Noun'), 2),
#  (('막', 'Noun'), 2),
#  (('주제', 'Noun'), 2),
#  (('알', 'Noun'), 2),
#  (('심지어', 'Noun'), 2),
#  (('다르다', 'Adjective'), 2),
#  (('편', 'Noun'), 2),
#  (('끼리', 'Noun'), 2),
#  (('만', 'Noun'), 2),
#  (('틀다', 'Verb'), 2),
#  (('탄핵', 'Noun'), 2),
#  (('꿈', 'Noun'), 2),
#  (('꾸다', 'Verb'), 2),
#  (('당연하다', 'Adjective'), 2),
#  (('웃기', 'Noun'), 2),
#  (('지만', 'Josa'), 2),
#  (('코미디', 'Noun'), 2),
#  (('몇', 'Noun'), 2),
#  (('째', 'Suffix'), 2),
#  (('주장', 'Noun'), 2),
#  (('동의', 'Noun'), 2),
#  (('힘드다', 'Adjective'), 2),
#  (('서', 'Modifier'), 2),
#  (('열리다', 'Verb'), 2),
#  (('합치다', 'Verb'), 2),
#  (('손녀', 'Noun'), 2),
#  (('인생', 'Noun'), 2),
#  (('관심', 'Noun'), 2),
#  (('끄다', 'Verb'), 2),
#  (('주차', 'Noun'), 2),
#  (('벌어지다', 'Verb'), 2),
#  (('대중', 'Noun'), 2),
#  (('판단', 'Noun'), 2),
#  (('외', 'Noun'), 2),
#  (('모양', 'Noun'), 2),
#  (('씨', 'Noun'), 2),
#  (('뜨다', 'Verb'), 2),
#  (('비정규직', 'Noun'), 2),
#  (('성과', 'Noun'), 2),
#  (('제시', 'Noun'), 2),
#  (('무조건', 'Noun'), 2),
#  (('떠들다', 'Verb'), 2),
#  (('아시', 'Noun'), 2),
#  (('죠', 'Josa'), 2),
#  (('선동', 'Noun'), 2),
#  (('덜', 'Noun'), 2),
#  (('전', 'Modifier'), 2),
#  (('감각', 'Noun'), 2),
#  (('여가부', 'Noun'), 2),
#  (('없어지다', 'Verb'), 2),
#  (('정신병', 'Noun'), 2),
#  (('차별', 'Noun'), 2),
#  (('해묵', 'Noun'), 2),
#  (('해봤다', 'Verb'), 2),
#  (('물리', 'Noun'), 2),
#  (('합당', 'Noun'), 2),
#  (('라며', 'Noun'), 2),
#  (('고만고만하다', 'Adjective'), 2),
#  (('깨다', 'Verb'), 2),
#  (('끼', 'Noun'), 2),
#  (('상당하다', 'Adjective'), 2),
#  (('완주', 'Noun'), 2),
#  (('연합', 'Noun'), 2),
#  (('아무', 'Noun'), 2),
#  (('기준', 'Noun'), 2),
#  (('타파', 'Noun'), 2),
#  (('드디어', 'Adverb'), 2),
#  (('이냐', 'Josa'), 2),
#  (('대한민국', 'Noun'), 2),
#  (('여러', 'Modifier'), 2),
#  (('잡', 'Noun'), 2),
#  (('우선', 'Noun'), 2),
#  (('예상', 'Noun'), 2),
#  (('시도', 'Noun'), 2),
#  (('일보', 'Noun'), 2),
#  (('계정', 'Noun'), 2),
#  (('요즘', 'Noun'), 2),
#  (('하지만', 'Conjunction'), 2),
#  (('잇다', 'Verb'), 2),
#  (('누구', 'Noun'), 2),
#  (('간담', 'Noun'), 2),
#  (('인간', 'Noun'), 2),
#  (('바쁘다', 'Adjective'), 2),
#  (('영광', 'Noun'), 2),
#  (('최대한', 'Noun'), 2),
#  (('나발', 'Noun'), 2),
#  (('접', 'Noun'), 2),
#  (('달라', 'Noun'), 2),
#  (('불안하다', 'Adjective'), 2),
#  (('그래도', 'Adverb'), 2),
#  (('모병제', 'Noun'), 2),
#  (('고', 'Modifier'), 2),
#  (('도리', 'Noun'), 2),
#  (('공개', 'Noun'), 2),
#  (('필요없다', 'Adjective'), 2),
#  (('개다', 'Verb'), 2),
#  (('숙명', 'Noun'), 2),
#  (('세월', 'Noun'), 2),
#  (('사표', 'Noun'), 2),
#  (('매우', 'Noun'), 2),
#  (('이에요', 'Josa'), 2),
#  (('카레', 'Noun'), 2),
#  (('그만', 'Adverb'), 2),
#  (('대통', 'Noun'), 2),
#  (('팔', 'Noun'), 2),
#  (('점', 'Noun'), 2),
#  (('행보', 'Noun'), 2),
#  (('안타깝다', 'Adjective'), 2),
#  (('난리', 'Noun'), 2),
#  (('현실', 'Noun'), 2),
#  (('인터넷', 'Noun'), 2),
#  (('자료', 'Noun'), 2),
#  (('내보내다', 'Verb'), 2),
#  (('보이콧', 'Noun'), 2),
#  (('난민', 'Noun'), 2),
#  (('민영화', 'Noun'), 2),
#  (('언론', 'Noun'), 2),
#  (('척', 'Noun'), 2),
#  (('수가', 'Noun'), 2),
#  (('적다', 'Verb'), 2),
#  (('부분', 'Noun'), 2),
#  (('자격', 'Noun'), 2),
#  (('조작', 'Noun'), 2),
#  (('사건', 'Noun'), 2),
#  (('거대', 'Noun'), 2),
#  (('인재', 'Noun'), 2),
#  (('합', 'Noun'), 2),
#  (('건지다', 'Verb'), 2),
#  (('떠나다', 'Verb'), 2),
#  (('려', 'Noun'), 2),
#  (('해결', 'Noun'), 2),
#  (('기후', 'Noun'), 2),
#  (('위기', 'Noun'), 2),
#  (('주자', 'Noun'), 2),
#  (('표심', 'Noun'), 2),
#  (('세대', 'Noun'), 2),
#  (('차별금지법', 'Noun'), 2),
#  (('구애', 'Noun'), 2),
#  (('진심', 'Noun'), 2),
#  (('우주', 'Noun'), 2),
#  (('뽑히다', 'Verb'), 2),
#  (('차이', 'Noun'), 2),
#  (('가져가다', 'Verb'), 2),
#  (('여혐', 'Noun'), 2),
#  (('포토', 'Noun'), 2),
#  (('김영삼', 'Noun'), 2),
#  (('전격', 'Noun'), 2),
#  (('워', 'Noun'), 2),
#  (('맨', 'Modifier'), 2),
#  (('포지션', 'Noun'), 2),
#  (('좌측', 'Noun'), 2),
#  (('위치', 'Noun'), 2),
#  (('완전하다', 'Adjective'), 2),
#  (('공신', 'Noun'), 2),
#  (('찾다', 'Verb'), 2),
#  (('야', 'Exclamation'), 2),
#  (('아무리', 'Adverb'), 2),
#  (('사이', 'Noun'), 2),
#  (('론', 'Noun'), 2),
#  (('제지', 'Noun'), 2),
#  (('이야', 'Josa'), 2),
#  (('텐데', 'Eomi'), 2),
#  (('대화', 'Noun'), 2),
#  (('이수정', 'Noun'), 2),
#  (('때리다', 'Verb'), 2),
#  (('비슷하다', 'Adjective'), 2),
#  (('나서다', 'Verb'), 2),
#  (('찌다', 'Verb'), 2),
#  (('들어주다', 'Verb'), 2),
#  (('싸우다', 'Verb'), 2),
#  (('끌다', 'Verb'), 2),
#  (('너', 'Modifier'), 2),
#  (('쌍', 'Noun'), 2),
#  (('특검', 'Noun'), 2),
#  (('원희룡', 'Noun'), 2),
#  (('부인', 'Noun'), 2),
#  (('밖에', 'Josa'), 2),
#  (('반문', 'Noun'), 2),
#  (('푸다', 'Verb'), 2),
#  (('단일', 'Noun'), 2),
#  (('아들', 'Noun'), 2),
#  (('심씨', 'Noun'), 2),
#  (('처럼', 'Noun'), 2),
#  (('장', 'Suffix'), 2),
#  (('디씨', 'Noun'), 2),
#  (('침체', 'Noun'), 2),
#  (('영', 'Noun'), 2),
#  (('부터', 'Noun'), 2),
#  (('정치가', 'Noun'), 2),
#  (('이렇게', 'Adverb'), 2),
#  (('당신', 'Noun'), 2),
#  (('원', 'Modifier'), 2),
#  (('옴', 'Noun'), 2),
#  (('엄청나다', 'Adjective'), 2),
#  (('궁', 'Noun'), 2),
#  (('정치성향', 'Noun'), 2),
#  (('상승', 'Noun'), 2),
#  (('경제부총리', 'Noun'), 2),
#  (('채용', 'Noun'), 2),
#  (('제대', 'Noun'), 2),
#  (('에서는', 'Josa'), 2),
#  (('이경태', 'Noun'), 2),
#  (('뜨겁다', 'Adjective'), 2),
#  (('환영', 'Noun'), 2),
#  (('출마', 'Noun'), 2),
#  (('실제', 'Noun'), 2),
#  (('기대하다', 'Adjective'), 2),
#  (('압박', 'Noun'), 2),
#  (('구나', 'Noun'), 2),
#  (('놀다', 'Verb'), 2),
#  (('사로잡히다', 'Verb'), 2),
#  (('초', 'Noun'), 2),
#  (('정례', 'Noun'), 2),
#  (('일주', 'Noun'), 2),
#  (('일전', 'Noun'), 2),
#  (('급감', 'Noun'), 2),
#  (('적극', 'Noun'), 2),
#  (('수', 'Modifier'), 2),
#  (('부상', 'Noun'), 2),
#  (('실질', 'Noun'), 2),
#  (('녹색', 'Noun'), 2),
#  (('께', 'Josa'), 2),
#  (('전국', 'Noun'), 2),
#  (('행동', 'Noun'), 2),
#  (('배치', 'Noun'), 2),
#  (('시간', 'Noun'), 2),
#  (('사명', 'Noun'), 2),
#  (('복원', 'Noun'), 2),
#  (('가지다', 'Verb'), 2),
#  (('총선', 'Noun'), 2),
#  (('창', 'Noun'), 2),
#  (('바람', 'Noun'), 2),
#  (('엄마', 'Noun'), 2),
#  (('맨날', 'Adverb'), 2),
#  (('들어서다', 'Verb'), 2),
#  (('별', 'Noun'), 2),
#  (('발', 'Noun'), 2),
#  (('느낌', 'Noun'), 2),
#  (('역할', 'Noun'), 2),
#  (('탁', 'Noun'), 2),
#  (('국회의사당', 'Noun'), 2),
#  (('발족', 'Noun'), 2),
#  (('식', 'Suffix'), 2),
#  (('국', 'Noun'), 2),
#  (('한테', 'Josa'), 2),
#  (('존재', 'Noun'), 2),
#  (('거리', 'Noun'), 2),
#  (('회사원', 'Noun'), 2),
#  (('여성혐오', 'Noun'), 2),
#  (('순', 'Noun'), 2),
#  (('어필', 'Noun'), 2),
#  (('열', 'Noun'), 2),
#  (('대입', 'Noun'), 2),
#  (('재', 'Noun'), 2),
#  (('명', 'Suffix'), 2),
#  (('이름', 'Noun'), 2),
#  (('보태', 'Noun'), 2),
#  (('판도', 'Noun'), 2),
#  (('간', 'Noun'), 2),
#  (('발의', 'Noun'), 2),
#  (('태도', 'Noun'), 2),
#  (('라면', 'Noun'), 2),
#  (('보전', 'Noun'), 2),
#  (('절반', 'Noun'), 2),
#  (('픽', 'Noun'), 2),
#  (('축하', 'Noun'), 2),
#  (('메', 'Noun'), 2),
#  (('사이트', 'Noun'), 2),
#  (('국회의원', 'Noun'), 2),
#  (('팩트', 'Noun'), 2),
#  (('엥', 'Exclamation'), 2),
#  (('군부', 'Noun'), 2),
#  (('영남', 'Noun'), 2),
#  (('상태', 'Noun'), 2),
#  (('갑자기', 'Noun'), 2),
#  (('이준석', 'Noun'), 2),
#  (('대', 'Suffix'), 2),
#  (('러', 'Noun'), 2),
#  (('신기하다', 'Adjective'), 2),
#  (('문', 'Noun'), 2),
#  (('싸움', 'Noun'), 2),
#  (('백신', 'Noun'), 2),
#  (('그간', 'Noun'), 2),
#  (('우리나라', 'Noun'), 2),
#  (('지경', 'Noun'), 2),
#  (('지우다', 'Verb'), 2),
#  (('권', 'Suffix'), 2),
#  (('미리', 'Noun'), 2),
#  (('잖다', 'Verb'), 2),
#  (('똥개', 'Noun'), 2),
#  (('공부', 'Noun'), 2),
#  (('살기', 'Noun'), 2),
#  (('치', 'Noun'), 2),
#  (('자리', 'Noun'), 2),
#  (('적폐', 'Noun'), 2),
#  (('전태일', 'Noun'), 2),
#  (('현', 'Noun'), 2),
#  (('만큼', 'Noun'), 2),
#  (('학력고사', 'Noun'), 2),
#  (('세', 'Modifier'), 2),
#  (('지층', 'Noun'), 2),
#  (('형성', 'Noun'), 2),
#  (('양자', 'Noun'), 2),
#  (('다자', 'Noun'), 2),
#  (('으로서', 'Josa'), 2),
#  (('행사', 'Noun'), 2),
#  (('민정당', 'Noun'), 2),
#  (('딱하다', 'Adjective'), 2),
#  (('폐지', 'Noun'), 2),
#  (('돼지', 'Noun'), 2),
#  (('또는', 'Adverb'), 2),
#  (('사주다', 'Verb'), 2),
#  (('하자', 'Noun'), 2),
#  (('이슈', 'Noun'), 2),
#  (('무능하다', 'Adjective'), 2),
#  (("['", 'Punctuation'), 1),
#  (('린', 'Noun'), 1),
#  (('대놓고', 'Adverb'), 1),
#  (('잔뜩', 'Noun'), 1),
#  (('모으다', 'Verb'), 1),
#  (('이상하다', 'Adjective'), 1),
#  (('가득하다', 'Adjective'), 1),
#  (('단지', 'Noun'), 1),
#  (('소수자', 'Noun'), 1),
#  (('감동', 'Noun'), 1),
#  (('그저', 'Adverb'), 1),
#  (('겉멋', 'Noun'), 1),
#  (('대학교', 'Noun'), 1),
#  (('학술', 'Noun'), 1),
#  (('동아리', 'Noun'), 1),
#  (('졸업', 'Noun'), 1),
#  (('꾸준하다', 'Adjective'), 1),
#  (('머', 'Noun'), 1),
#  (('저리', 'Noun'), 1),
#  (('긍정', 'Noun'), 1),
#  (('수용', 'Noun'), 1),
#  (('부정', 'Noun'), 1),
#  (('몇몇', 'Noun'), 1),
#  (('철', 'Noun'), 1),
#  (('안다', 'Verb'), 1),
#  (('어리다', 'Verb'), 1),
#  (('성숙', 'Noun'), 1),
#  (('도부', 'Noun'), 1),
#  (('체적', 'Noun'), 1),
#  (('난국', 'Noun'), 1),
#  (('네', 'Determiner'), 1),
#  (('가티', 'Noun'), 1),
#  ...]

# %%
# 명사만 추출
noun_count = {x[0][0]:x[1] for x in count_words if x[0][1]=='Noun' and len(x[0][0])>=2 and '동덕' not in x[0][0]}
noun_count
# Out:
# {'심상정': 371,
#  '안철수': 110,
#  '후보': 105,
#  '이재명': 71,
#  '정의당': 66,
#  '윤석열': 57,
#  '대선': 39,
#  '조건': 31,
#  '민주당': 29,
#  '지대': 26,
#  '김어준': 26,
#  '심리': 25,
#  '대통령': 25,
#  '체제': 22,
#  '정치': 22,
#  '뉴스': 21,
#  '방송': 21,
#  '제안': 20,
#  '분석': 20,
#  '진짜': 20,
#  '이번': 19,
#  '국민': 19,
#  '김동연': 18,
#  '종식': 17,
#  '생각': 17,
#  '여자': 17,
#  '비판': 17,
#  '진보': 17,
#  '의원': 15,
#  '사회': 15,
#  '선택': 15,
#  '공조': 15,
#  '다음': 15,
#  '여성': 15,
#  '이제': 14,
#  '정책': 14,
#  '연대': 14,
#  '출처': 13,
#  '사람': 12,
#  '지지': 12,
#  '무슨': 12,
#  '지지율': 12,
#  '한국': 11,
#  '정당': 11,
#  '문제': 11,
#  '심리학자': 11,
#  '투표': 10,
#  '문재인': 10,
#  '여론': 10,
#  '정말': 10,
#  '이유': 10,
#  '진보당': 10,
#  '시민': 10,
#  '다른': 9,
#  '시일': 9,
#  '선거': 9,
#  '위해': 9,
#  '국민의당': 9,
#  '조사': 9,
#  '사적': 9,
#  '욕망': 9,
#  '정치인': 8,
#  '허경영': 8,
#  '국힘': 8,
#  '정의': 8,
#  '시작': 8,
#  '네이버': 8,
#  '고민': 8,
#  '시대': 8,
#  '인정': 8,
#  '노회찬': 7,
#  '연구소': 7,
#  '욕구': 7,
#  '그냥': 7,
#  '다시': 7,
#  '보고': 7,
#  '지금': 7,
#  '이야기': 7,
#  '대표': 7,
#  '다스': 7,
#  '의미': 7,
#  '지지도': 7,
#  '우리': 7,
#  '트럼프': 7,
#  '남자': 6,
#  '수준': 6,
#  '성심당': 6,
#  '미래': 6,
#  '노동': 6,
#  '유시민': 6,
#  '자기': 6,
#  '만남': 6,
#  '오늘': 6,
#  '워맨스': 6,
#  '노동자': 6,
#  '대해': 6,
#  '때문': 6,
#  '보기': 6,
#  '정권': 6,
#  '교체': 6,
#  '선언': 6,
#  '양당제': 6,
#  '소리': 5,
#  '페미': 5,
#  '내용': 5,
#  '이해': 5,
#  '김태형': 5,
#  '인물': 5,
#  '정도': 5,
#  '나라': 5,
#  '최악': 5,
#  '얼마나': 5,
#  '역사': 5,
#  '영상': 5,
#  '시사': 5,
#  '자체': 5,
#  '세상': 5,
#  '국가': 5,
#  '세력': 5,
#  '당선': 5,
#  '페미니스트': 5,
#  '현장': 5,
#  '안티': 5,
#  '이상': 5,
#  '어디': 5,
#  '결과': 5,
#  '청년': 5,
#  '정신': 5,
#  '한번': 5,
#  '일제': 5,
#  '최선': 5,
#  '야당': 5,
#  '좌파': 4,
#  '그때': 4,
#  '입장': 4,
#  '절대': 4,
#  '전두환': 4,
#  '마음': 4,
#  '프로': 4,
#  '원래': 4,
#  '경선': 4,
#  '도전': 4,
#  '완전': 4,
#  '시발': 4,
#  '새끼': 4,
#  '가능성': 4,
#  '민주': 4,
#  '권력': 4,
#  '하나': 4,
#  '여론조사': 4,
#  '지난': 4,
#  '시동': 4,
#  '차악': 4,
#  '나은': 4,
#  '의당': 4,
#  '본인': 4,
#  '나이': 4,
#  '씨발': 4,
#  '홍준표': 4,
#  '출연': 4,
#  '며느리': 4,
#  '누가': 4,
#  '음식': 4,
#  '공약': 4,
#  '민낯': 4,
#  '이석기': 4,
#  '석방': 4,
#  '해산': 4,
#  '무효': 4,
#  '가지': 4,
#  '대위': 4,
#  '대남': 4,
#  '거나': 4,
#  '제발': 4,
#  '도이치': 4,
#  '모터': 4,
#  '어게인': 4,
#  '지랄': 4,
#  '대가': 4,
#  '지지자': 4,
#  '동안': 4,
#  '일화': 4,
#  '거기': 4,
#  '대전': 4,
#  '기대': 4,
#  '기록': 4,
#  '차기': 4,
#  '기자': 4,
#  '격차': 4,
#  '모든': 4,
#  '혜영': 4,
#  '전환': 4,
#  '추진': 4,
#  '인터뷰': 4,
#  '여당': 4,
#  '이낙연': 4,
#  '정체': 4,
#  '박원순': 4,
#  '어차피': 4,
#  '기자회견': 3,
#  '모습': 3,
#  '언급': 3,
#  '트위터': 3,
#  '역시': 3,
#  '소장': 3,
#  '요청': 3,
#  '얘기': 3,
#  '투자': 3,
#  '사태': 3,
#  '토론': 3,
#  '배진교': 3,
#  '그것': 3,
#  '정부': 3,
#  '어쩌': 3,
#  '포인트': 3,
#  '거지': 3,
#  '계속': 3,
#  '당원': 3,
#  '간다': 3,
#  '전화': 3,
#  '신지': 3,
#  '제일': 3,
#  '보수': 3,
#  '대안': 3,
#  '가요': 3,
#  '김종인': 3,
#  '백서': 3,
#  '오마이': 3,
#  '귀인': 3,
#  '먼저': 3,
#  '상대': 3,
#  '짓거리': 3,
#  '심상': 3,
#  '일이': 3,
#  '와중': 3,
#  '윤석렬': 3,
#  '먹기': 3,
#  '가장': 3,
#  '공영': 3,
#  '온갖': 3,
#  '연예': 3,
#  '이정희': 3,
#  '사진관': 3,
#  '주말': 3,
#  '아주': 3,
#  '통합': 3,
#  '차라리': 3,
#  '말씀': 3,
#  '별로': 3,
#  '박빙': 3,
#  '필요': 3,
#  '관통': 3,
#  '명의': 3,
#  '거장': 3,
#  '용인': 3,
#  '예술': 3,
#  '호의': 3,
#  '무한': 3,
#  '질주': 3,
#  '이틀': 3,
#  '위원회': 3,
#  '변화': 3,
#  '모두': 3,
#  '타임즈': 3,
#  '무시': 3,
#  '표현': 3,
#  '아기': 3,
#  '조문': 3,
#  '건가': 3,
#  '노동운동': 3,
#  '대결': 3,
#  '사욕': 2,
#  '자신': 2,
#  '일부': 2,
#  '반응': 2,
#  '치기': 2,
#  '도움': 2,
#  '대한': 2,
#  '어른': 2,
#  '크게': 2,
#  '딴지': 2,
#  '해먹': 2,
#  '대가리': 2,
#  '강소기업': 2,
#  '코인': 2,
#  '박근혜': 2,
#  '그게': 2,
#  '치매': 2,
#  '따위': 2,
#  '밥그릇': 2,
#  '과거': 2,
#  '해도': 2,
#  '패널': 2,
#  '주제': 2,
#  '심지어': 2,
#  '끼리': 2,
#  '탄핵': 2,
#  '웃기': 2,
#  '코미디': 2,
#  '주장': 2,
#  '동의': 2,
#  '손녀': 2,
#  '인생': 2,
#  '관심': 2,
#  '주차': 2,
#  '대중': 2,
#  '판단': 2,
#  '모양': 2,
#  '비정규직': 2,
#  '성과': 2,
#  '제시': 2,
#  '무조건': 2,
#  '아시': 2,
#  '선동': 2,
#  '감각': 2,
#  '여가부': 2,
#  '정신병': 2,
#  '차별': 2,
#  '해묵': 2,
#  '물리': 2,
#  '합당': 2,
#  '라며': 2,
#  '완주': 2,
#  '연합': 2,
#  '아무': 2,
#  '기준': 2,
#  '타파': 2,
#  '대한민국': 2,
#  '우선': 2,
#  '예상': 2,
#  '시도': 2,
#  '일보': 2,
#  '계정': 2,
#  '요즘': 2,
#  '누구': 2,
#  '간담': 2,
#  '인간': 2,
#  '영광': 2,
#  '최대한': 2,
#  '나발': 2,
#  '달라': 2,
#  '모병제': 2,
#  '도리': 2,
#  '공개': 2,
#  '숙명': 2,
#  '세월': 2,
#  '사표': 2,
#  '매우': 2,
#  '카레': 2,
#  '대통': 2,
#  '행보': 2,
#  '난리': 2,
#  '현실': 2,
#  '인터넷': 2,
#  '자료': 2,
#  '보이콧': 2,
#  '난민': 2,
#  '민영화': 2,
#  '언론': 2,
#  '수가': 2,
#  '부분': 2,
#  '자격': 2,
#  '조작': 2,
#  '사건': 2,
#  '거대': 2,
#  '인재': 2,
#  '해결': 2,
#  '기후': 2,
#  '위기': 2,
#  '주자': 2,
#  '표심': 2,
#  '세대': 2,
#  '차별금지법': 2,
#  '구애': 2,
#  '진심': 2,
#  '우주': 2,
#  '차이': 2,
#  '여혐': 2,
#  '포토': 2,
#  '김영삼': 2,
#  '전격': 2,
#  '포지션': 2,
#  '좌측': 2,
#  '위치': 2,
#  '공신': 2,
#  '사이': 2,
#  '제지': 2,
#  '대화': 2,
#  '이수정': 2,
#  '특검': 2,
#  '원희룡': 2,
#  '부인': 2,
#  '반문': 2,
#  '단일': 2,
#  '아들': 2,
#  '심씨': 2,
#  '처럼': 2,
#  '디씨': 2,
#  '침체': 2,
#  '부터': 2,
#  '정치가': 2,
#  '당신': 2,
#  '정치성향': 2,
#  '상승': 2,
#  '경제부총리': 2,
#  '채용': 2,
#  '제대': 2,
#  '이경태': 2,
#  '환영': 2,
#  '출마': 2,
#  '실제': 2,
#  '압박': 2,
#  '구나': 2,
#  '정례': 2,
#  '일주': 2,
#  '일전': 2,
#  '급감': 2,
#  '적극': 2,
#  '부상': 2,
#  '실질': 2,
#  '녹색': 2,
#  '전국': 2,
#  '행동': 2,
#  '배치': 2,
#  '시간': 2,
#  '사명': 2,
#  '복원': 2,
#  '총선': 2,
#  '바람': 2,
#  '엄마': 2,
#  '느낌': 2,
#  '역할': 2,
#  '국회의사당': 2,
#  '발족': 2,
#  '존재': 2,
#  '거리': 2,
#  '회사원': 2,
#  '여성혐오': 2,
#  '어필': 2,
#  '대입': 2,
#  '이름': 2,
#  '보태': 2,
#  '판도': 2,
#  '발의': 2,
#  '태도': 2,
#  '라면': 2,
#  '보전': 2,
#  '절반': 2,
#  '축하': 2,
#  '사이트': 2,
#  '국회의원': 2,
#  '팩트': 2,
#  '군부': 2,
#  '영남': 2,
#  '상태': 2,
#  '갑자기': 2,
#  '이준석': 2,
#  '싸움': 2,
#  '백신': 2,
#  '그간': 2,
#  '우리나라': 2,
#  '지경': 2,
#  '미리': 2,
#  '똥개': 2,
#  '공부': 2,
#  '살기': 2,
#  '자리': 2,
#  '적폐': 2,
#  '전태일': 2,
#  '만큼': 2,
#  '학력고사': 2,
#  '지층': 2,
#  '형성': 2,
#  '양자': 2,
#  '다자': 2,
#  '행사': 2,
#  '민정당': 2,
#  '폐지': 2,
#  '돼지': 2,
#  '하자': 2,
#  '이슈': 2,
#  '잔뜩': 1,
#  '단지': 1,
#  '소수자': 1,
#  '감동': 1,
#  '겉멋': 1,
#  '대학교': 1,
#  '학술': 1,
#  '동아리': 1,
#  '졸업': 1,
#  '저리': 1,
#  '긍정': 1,
#  '수용': 1,
#  '부정': 1,
#  '몇몇': 1,
#  '성숙': 1,
#  '도부': 1,
#  '체적': 1,
#  '난국': 1,
#  '가티': 1,
#  '지도자': 1,
#  '외부': 1,
#  '인사': 1,
#  '추천': 1,
#  '년도': 1,
#  '년전': 1,
#  '그대로': 1,
#  '한국인': 1,
#  '청와대로': 1,
#  '자본잠식': 1,
#  '부실': 1,
#  '기업': 1,
#  '페이퍼': 1,
#  '컴퍼니': 1,
#  '평타': 1,
#  '주식': 1,
#  '광풍': 1,
#  '라지': 1,
#  '상황': 1,
#  '이명박': 1,
#  '초유': 1,
#  '굳이': 1,
#  '고려': 1,
#  '성적': 1,
#  '최소한': 1,
#  '안함': 1,
#  '방증임': 1,
#  '절호': 1,
#  '기회': 1,
#  '똥볼': 1,
#  '애도': 1,
#  '목마르다': 1,
#  '바닷물': 1,
#  '미련': 1,
#  '구현': 1,
#  '표어': 1,
#  '사용': 1,
#  '기생': 1,
#  '군소': 1,
#  '부러': 1,
#  '직장인': 1,
#  '빨강': 1,
#  '파랑': 1,
#  '악인': 1,
#  '축제': 1,
#  '햇겟': 1,
#  '어제': 1,
#  '스트레이트': 1,
#  '지난주': 1,
#  '걸그룹': 1,
#  '오디션': 1,
#  '결방': 1,
#  '다음주': 1,
#  '지각': 1,
#  '피디수첩': 1,
#  '내일': 1,
#  '위드': 1,
#  '코로나': 1,
#  '편이': 1,
#  '특집': 1,
#  '장하나': 1,
#  '김종': 1,
#  '노잼': 1,
#  '이아': 1,
#  '어쩌면': 1,
#  '러브콜': 1,
#  '흑화': 1,
#  '속마음': 1,
#  '틀키': 1,
#  '대본': 1,
#  '친구': 1,
#  '성도': 1,
#  '가끔': 1,
#  '협력': 1,
#  '기본': 1,
#  '비평': 1,
#  '지네': 1,
#  '푸하하하': 1,
#  '종부세': 1,
#  '전망': 1,
#  '대상자': 1,
#  '육박': 1,
#  '해당': 1,
#  '사기꾼': 1,
#  '진즉': 1,
#  '남한': 1,
#  '전체': 1,
#  '새누리': 1,
#  '날로': 1,
#  '아웃': 1,
#  '오브': 1,
#  '안중': 1,
#  '사후': 1,
#  '색깔': 1,
#  '퇴색': 1,
#  '분산': 1,
#  '스토커': 1,
#  '저런': 1,
#  '투표했늨데': 1,
#  '소형': 1,
#  '원자': 1,
#  '로건': 1,
#  '다리': 1,
#  '계란': 1,
#  '바위': 1,
#  '백성은': 1,
#  '설득': 1,
#  '할머니': 1,
#  '할아버지': 1,
#  '상품': 1,
#  '광고': 1,
#  '간격': 1,
#  '아주머니': 1,
#  '야심': 1,
#  '확장': 1,
#  '골목': 1,
#  '대장': 1,
#  '기사': 1,
#  '노동시장': 1,
#  '양극화': 1,
#  '정규직': 1,
#  '직업': 1,
#  '안정': 1,
#  '개혁': 1,
#  '원전': 1,
#  '도대체': 1,
#  '컨텐츠': 1,
#  '나쁜사람': 1,
#  '화통': 1,
#  '오지': 1,
#  '종인': 1,
#  '상정이': 1,
#  '환상': 1,
#  '듀오': 1,
#  '좌파당': 1,
#  '똥꼬': 1,
#  '트랜스': 1,
#  '무지개': 1,
#  '법썩': 1,
#  '흐응딱련': 1,
#  '지방': 1,
#  '생존': 1,
#  '파트너': 1,
#  '이념': 1,
#  '다해': 1,
#  '방송사고': 1,
#  '실트': 1,
#  '멍청이': 1,
#  '님들': 1,
#  '연쇄': 1,
#  '사주팔자': 1,
#  '리학': 1,
#  '셀프': 1,
#  '사주': 1,
#  '깜놀': 1,
#  '전략': 1,
#  '전술': 1,
#  '통일': 1,
#  '생태': 1,
#  '기초': 1,
#  '모색': 1,
#  '한겨레': 1,
#  '민단': 1,
#  '매경': 1,
#  '장씨': 1,
#  '조합': 1,
#  '어쩌다가': 1,
#  '유아': 1,
#  '독존': 1,
#  '소아': 1,
#  '안띨수': 1,
#  '수정': 1,
#  '시민사회': 1,
#  '구상': 1,
#  '미만': 1,
#  '가치': 1,
#  '세계': 1,
#  '존나': 1,
#  '정무': 1,
#  '바카': 1,
#  '스루하': 1,
#  '한치': 1,
#  '대접': 1,
#  '기분': 1,
#  '랜선': 1,
#  '싸인': 1,
#  '사진': 1,
#  '직전': 1,
#  '분다': 1,
#  '문죄인': 1,
#  '패거리': 1,
#  '예외': 1,
#  '죄인': 1,
#  '방향성': 1,
#  '흥미': 1,
#  '모름': 1,
#  '쯧쯧': 1,
#  '지인': 1,
#  '사감': 1,
#  '김부선': 1,
#  '불리': 1,
#  '보편': 1,
#  '조오오오': 1,
#  '인성': 1,
#  '참새': 1,
#  '메추라기': 1,
#  '기반': 1,
#  '허송': 1,
#  '올해': 1,
#  '작작': 1,
#  '가라': 1,
#  '똥맛': 1,
#  '비유': 1,
#  '발효': 1,
#  '와우': 1,
#  '철수': 1,
#  '왜봐': 1,
#  '혐오': 1,
#  '지세': 1,
#  '참으로': 1,
#  '짝꿍': 1,
#  '아작': 1,
#  '일조해': 1,
#  '낯짝': 1,
#  '기생충': 1,
#  '부탁': 1,
#  '로라': 1,
#  '모자': 1,
#  '걸이': 1,
#  '오케이': 1,
#  '확률': 1,
#  '지상파': 1,
#  '예전': 1,
#  '명비': 1,
#  '아프가니스탄': 1,
#  '통폐합': 1,
#  '반대': 1,
#  '찬성': 1,
#  '중재법': 1,
#  '캠프': 1,
#  '레즈비언': 1,
#  '간판': 1,
#  '백성': 1,
#  '비난': 1,
#  '언제': 1,
#  '심리학': 1,
#  '개개인': 1,
#  '추측': 1,
#  '궁예': 1,
#  '학문': 1,
#  '대모': 1,
#  '성소수자': 1,
#  '격리': 1,
#  '의제': 1,
#  '고집': 1,
#  '제보': 1,
#  '프레임': 1,
#  '리도': 1,
#  '누굴': 1,
#  '범죄': 1,
#  '밥알': 1,
#  '대변': 1,
#  '집권': 1,
#  '메뉴': 1,
#  '강요': 1,
#  '딜레마': 1,
#  '불평등': 1,
#  '누적': 1,
#  '제외': 1,
#  '잡기': 1,
#  '단어': 1,
#  '오염': 1,
#  '주일': 1,
#  '제도': 1,
#  '포괄': 1,
#  '무엇': 1,
#  '구속': 1,
#  '포르투갈': 1,
#  '본상': 1,
#  '마치': 1,
#  '인양': 1,
#  '전부': 1,
#  '시합': 1,
#  '처리': 1,
#  '출동': 1,
#  '전대통령': 1,
#  '추모식': 1,
#  '리얼': 1,
#  '나인': 1,
#  '스타즈': 1,
#  '포스트': 1,
#  '예능': 1,
#  '구체': 1,
#  '수직선': 1,
#  '우측': 1,
#  '작용': 1,
#  '사퇴': 1,
#  '일등': 1,
#  '공통점': 1,
#  '고기': 1,
#  '뷔페': 1,
#  '결론': 1,
#  '후식': 1,
#  '딸기': 1,
#  '케익': 1,
#  '의원님': 1,
#  '기본소득': 1,
#  '겨우': 1,
#  '녀석': 1,
#  '옛날': 1,
#  '노동계': 1,
#  '자괴': 1,
#  '노욕': 1,
#  '거울': 1,
#  '해달': 1,
#  '래서': 1,
#  '독해': 1,
#  '굴린': 1,
#  '원인': 1,
#  '컨벤션': 1,
#  '효과': 1,
#  '스코어': 1,
#  '바탕': 1,
#  '본격': 1,
#  '풍경': 1,
#  '최대': 1,
#  '실책': 1,
#  '윤가놈': 1,
#  '라이': 1,
#  '의견': 1,
#  '교환': 1,
#  '정색': 1,
#  '결말': 1,
#  '부고': 1,
#  '무관심': 1,
#  '작가': 1,
#  '피해': 1,
#  '인식': 1,
#  '농락': 1,
#  '화답': 1,
#  '서로': 1,
#  '출발': 1,
#  '중앙': 1,
#  '제목': 1,
#  '두고두고': 1,
#  '중대': 1,
#  '포부': 1,
#  '과연': 1,
#  '도통': 1,
#  '변혁': 1,
#  '은퇴': 1,
#  '수나': 1,
#  '방법론': 1,
#  '김재연': 1,
#  '화면': 1,
#  '명분': 1,
#  '동아일보': 1,
#  '구경이': 1,
#  '용국': 1,
#  '용씨': 1,
#  '콜라보': 1,
#  '근본': 1,
#  '츠윗': 1,
#  '인증': 1,
#  '소신': 1,
#  '뜬구름': 1,
#  '잡고': 1,
#  '역대': 1,
#  '비호감': 1,
#  '내부': 1,
#  '일례': 1,
#  '철부지': 1,
#  '소꿉장난': 1,
#  '놀이터': 1,
#  '팬덤': 1,
#  '어디가': 1,
#  '중도': 1,
#  '로그': 1,
#  '헛소리': 1,
#  '개악': 1,
#  '최근': 1,
#  '환경': 1,
#  '상이': 1,
#  '출격': 1,
#  '아예': 1,
#  '길이': 1,
#  '공격': 1,
#  '표방': 1,
#  '처지': 1,
#  '양보': 1,
#  '예나': 1,
#  '집착': 1,
#  '지리': 1,
#  '선물': 1,
#  '명물': 1,
#  '마나': 1,
#  '패스': 1,
#  '둔갑': 1,
#  '만날': 1,
#  '국민일보': 1,
#  '납득': 1,
#  '괴로움': 1,
#  '물탄': 1,
#  '갈수록': 1,
#  '역량': 1,
#  '하락': 1,
#  '등장': 1,
#  '일시': 1,
#  '중계': 1,
#  '내공': 1,
#  '시청': 1,
#  '대책': 1,
#  '공지': 1,
#  '대통령선거': 1,
#  '애정': 1,
#  '지원': 1,
#  '링크': 1,
#  '통해': 1,
#  '기득권': 1,
#  '무고죄': 1,
#  '강화': 1,
#  '워딩': 1,
#  '시너지': 1,
#  '득표율': 1,
#  '마이너': 1,
#  '순수': 1,
#  '안찡': 1,
#  '일말': 1,
#  '남녀': 1,
#  '막내딸': 1,
#  '성공': 1,
#  '명예욕': 1,
#  '추미애': 1,
#  '구도': 1,
#  '한몫': 1,
#  '색기': 1,
#  '내내': 1,
#  '바로': 1,
#  '재창': 1,
#  '전보': 1,
#  '그으': 1,
#  '노력': 1,
#  '설명': 1,
#  '타도': 1,
#  '화이팅': 1,
#  '좃선': 1,
#  '처법': 1,
#  '기권': 1,
#  '비례대표': 1,
#  '보가': 1,
#  '번은': 1,
#  '속지': 1,
#  '안녕': 1,
#  '엉망': 1,
#  '근거': 1,
#  '서도': 1,
#  '결정': 1,
#  '깊이': 1,
#  '전과': 1,
#  '노동법': 1,
#  '성폭력': 1,
#  '원아웃': 1,
#  '둘째': 1,
#  '체감': 1,
#  '심장': 1,
#  '널리': 1,
#  '극복': 1,
#  '실천': 1,
#  '전당': 1,
#  '첫째': 1,
#  '전면': 1,
#  '증명': 1,
#  '투쟁': 1,
#  '노동현': 1,
#  '결합': 1,
#  '시기': 1,
#  '당부': 1,
#  '심상찮': 1,
#  '워크숍': 1,
#  '최고': 1,
#  '부응': 1,
#  '응답': 1,
#  '열망': 1,
#  '결집': 1,
#  '청와대': 1,
#  '바가지': 1,
#  '떼쟁이': 1,
#  '음모론자': 1,
#  '이하': 1,
#  '감흥': 1,
#  '뭉치': 1,
#  '노컷뉴스': 1,
#  '며칠': 1,
#  '어준이': 1,
#  '몰던': 1,
#  '장선': 1,
#  '지시': 1,
#  '위병': 1,
#  '한주': 1,
#  '고무줄': 1,
#  ...}

# %%
from wordcloud import WordCloud
import seaborn as sns
import matplotlib.pyplot as plt

# 폰트설정
# !apt-get update -qq
# !apt-get install fonts-nanum* -qq
import matplotlib.font_manager as fm
fm._rebuild()
for fontInfo in fm.fontManager.ttflist:
    if 'Nanum' in fontInfo.name:
        print(fontInfo.name+" = " + fontInfo.fname)
# Out:
# Selecting previously unselected package fonts-nanum.
# (Reading database ... 155222 files and directories currently installed.)
# Preparing to unpack .../fonts-nanum_20170925-1_all.deb ...
# Unpacking fonts-nanum (20170925-1) ...
# Selecting previously unselected package fonts-nanum-eco.
# Preparing to unpack .../fonts-nanum-eco_1.000-6_all.deb ...
# Unpacking fonts-nanum-eco (1.000-6) ...
# Selecting previously unselected package fonts-nanum-extra.
# Preparing to unpack .../fonts-nanum-extra_20170925-1_all.deb ...
# Unpacking fonts-nanum-extra (20170925-1) ...
# Selecting previously unselected package fonts-nanum-coding.
# Preparing to unpack .../fonts-nanum-coding_2.5-1_all.deb ...
# Unpacking fonts-nanum-coding (2.5-1) ...
# Setting up fonts-nanum-extra (20170925-1) ...
# Setting up fonts-nanum (20170925-1) ...
# Setting up fonts-nanum-coding (2.5-1) ...
# Setting up fonts-nanum-eco (1.000-6) ...
# Processing triggers for fontconfig (2.12.6-0ubuntu2) ...
# NanumSquareRound = /usr/share/fonts/truetype/nanum/NanumSquareRoundR.ttf
# NanumSquareRound = /usr/share/fonts/truetype/nanum/NanumSquareRoundEB.ttf
# NanumSquareRound = /usr/share/fonts/truetype/nanum/NanumSquareRoundB.ttf
# NanumGothic = /usr/share/fonts/truetype/nanum/NanumGothicLight.ttf
# NanumGothic Eco = /usr/share/fonts/truetype/nanum/NanumGothicEcoBold.ttf
# NanumMyeongjo Eco = /usr/share/fonts/truetype/nanum/NanumMyeongjoEcoBold.ttf
# NanumMyeongjo = /usr/share/fonts/truetype/nanum/NanumMyeongjoExtraBold.ttf
# NanumGothic = /usr/share/fonts/truetype/nanum/NanumGothic.ttf
# NanumBarunGothic = /usr/share/fonts/truetype/nanum/NanumBarunGothicLight.ttf
# Nanum Pen Script = /usr/share/fonts/truetype/nanum/NanumPen.ttf
# NanumSquare = /usr/share/fonts/truetype/nanum/NanumSquareR.ttf
# NanumBarunGothic = /usr/share/fonts/truetype/nanum/NanumBarunGothicBold.ttf
# NanumMyeongjo Eco = /usr/share/fonts/truetype/nanum/NanumMyeongjoEco.ttf
# NanumMyeongjo Eco = /usr/share/fonts/truetype/nanum/NanumMyeongjoEcoExtraBold.ttf
# NanumGothic = /usr/share/fonts/truetype/nanum/NanumGothicBold.ttf
# NanumBarunpen = /usr/share/fonts/truetype/nanum/NanumBarunpenB.ttf
# NanumGothic = /usr/share/fonts/truetype/nanum/NanumGothicExtraBold.ttf
# NanumGothicCoding = /usr/share/fonts/truetype/nanum/NanumGothicCoding.ttf
# NanumBarunGothic = /usr/share/fonts/truetype/nanum/NanumBarunGothic.ttf
# Nanum Brush Script = /usr/share/fonts/truetype/nanum/NanumBrush.ttf
# NanumBarunGothic = /usr/share/fonts/truetype/nanum/NanumBarunGothicUltraLight.ttf
# NanumGothicCoding = /usr/share/fonts/truetype/nanum/NanumGothicCoding-Bold.ttf
# NanumGothic Eco = /usr/share/fonts/truetype/nanum/NanumGothicEcoExtraBold.ttf
# NanumMyeongjo = /usr/share/fonts/truetype/nanum/NanumMyeongjo.ttf
# NanumGothic Eco = /usr/share/fonts/truetype/nanum/NanumGothicEco.ttf
# NanumMyeongjo = /usr/share/fonts/truetype/nanum/NanumMyeongjoBold.ttf
# NanumBarunpen = /usr/share/fonts/truetype/nanum/NanumBarunpenR.ttf
# NanumSquareRound = /usr/share/fonts/truetype/nanum/NanumSquareRoundL.ttf
# NanumSquare = /usr/share/fonts/truetype/nanum/NanumSquareB.ttf
# NanumSquare = /usr/share/fonts/truetype/nanum/NanumSquareEB.ttf
# NanumSquare = /usr/share/fonts/truetype/nanum/NanumSquareL.ttf

# %%
font_path = '/usr/share/fonts/truetype/nanum/NanumGothicBold.ttf'   # 원하는 폰트 지정

wordcloud = WordCloud(
    max_words=200, #최대 수용 단어 갯수
    background_color='black', #배경색상
    font_path=font_path,
    width = 800, #넓이
    height = 800, #길이
    colormap='Accent_r')
    
wordcloud.generate_from_frequencies(dict(noun_count))

fig =  plt.figure(figsize=(6,6))
plt.imshow(wordcloud)
plt.axis("off")
plt.show()
fig.savefig('/content/drive/MyDrive/Colab Notebooks/word_cloud.jpg')
