# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
import numpy as np

# %%
data=pd.read_csv("/content/drive/MyDrive/outlier/심상정.csv")
data.head()
# Out:
#                                                tweet  ...                                               link
# 0  이번투표는 남자는 안뽑을것같다 심상정이 다른 정치인들보다 클 린하다 옳은사람이다 이...  ...  https://twitter.com/ppappapdirara/status/14627...
# 1  심상정 안철수에 빠른 시일 내 조건 없이 만나자 양당체제 종식 기자회견서 안철수 김...  ...  https://twitter.com/no1nmh/status/146277465092...
# 2  단지 소수자인 자신을 심상정이 언급해주는 것만으로 감동받아 지지해주는 분들이 있는가...  ...  https://twitter.com/escrimeurk/status/14627742...
# 3  심상정이 안철수의 제안을 긍정적으로 수용한 듯한데 트위터 좌파 의 일부의 부정적 반...  ...  https://twitter.com/escrimeurk/status/14627735...
# 4   histopian 몇몇 철 안든 어린 의원들 치기나 미성숙이라고 생각했는데 정의당...  ...  https://twitter.com/EunieShin/status/146277347...
#
# [5 rows x 4 columns]

# %%
range(len(data["tweet"])) #338개 데이터
# Out:
# range(0, 338)

# %% [markdown]
# # 정수 인코딩과 단어 집합 만들기

# %%
# !pip install konlpy
from konlpy.tag import Kkma  
kkma = Kkma()
tokenized_doc=[]
for n in range(len(data["tweet"])):
    text = data["tweet"][n]
    tokenized_doc.append(list(kkma.nouns(str(text))))
print(tokenized_doc[:5]) #상위 5개 댓글 토큰화
# Out:
# Collecting konlpy
#   Downloading konlpy-0.5.2-py2.py3-none-any.whl (19.4 MB)
#      |████████████████████████████████| 19.4 MB 51.3 MB/s
# Collecting colorama
#   Downloading colorama-0.4.4-py2.py3-none-any.whl (16 kB)
# Requirement already satisfied: numpy>=1.6 in /usr/local/lib/python3.7/dist-packages (from konlpy) (1.19.5)
# Requirement already satisfied: lxml>=4.1.0 in /usr/local/lib/python3.7/dist-packages (from konlpy) (4.2.6)
# Requirement already satisfied: tweepy>=3.7.0 in /usr/local/lib/python3.7/dist-packages (from konlpy) (3.10.0)
# Collecting beautifulsoup4==4.6.0
#   Downloading beautifulsoup4-4.6.0-py3-none-any.whl (86 kB)
#      |████████████████████████████████| 86 kB 5.2 MB/s
# Collecting JPype1>=0.7.0
#   Downloading JPype1-1.3.0-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.whl (448 kB)
#      |████████████████████████████████| 448 kB 71.2 MB/s
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.7/dist-packages (from JPype1>=0.7.0->konlpy) (3.10.0.2)
# Requirement already satisfied: six>=1.10.0 in /usr/local/lib/python3.7/dist-packages (from tweepy>=3.7.0->konlpy) (1.15.0)
# Requirement already satisfied: requests[socks]>=2.11.1 in /usr/local/lib/python3.7/dist-packages (from tweepy>=3.7.0->konlpy) (2.23.0)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.7/dist-packages (from tweepy>=3.7.0->konlpy) (1.3.0)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.7/dist-packages (from requests-oauthlib>=0.7.0->tweepy>=3.7.0->konlpy) (3.1.1)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests[socks]>=2.11.1->tweepy>=3.7.0->konlpy) (2.10)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests[socks]>=2.11.1->tweepy>=3.7.0->konlpy) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests[socks]>=2.11.1->tweepy>=3.7.0->konlpy) (1.24.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests[socks]>=2.11.1->tweepy>=3.7.0->konlpy) (2021.10.8)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6 in /usr/local/lib/python3.7/dist-packages (from requests[socks]>=2.11.1->tweepy>=3.7.0->konlpy) (1.7.1)
# Installing collected packages: JPype1, colorama, beautifulsoup4, konlpy
#   Attempting uninstall: beautifulsoup4
#     Found existing installation: beautifulsoup4 4.6.3
#     Uninstalling beautifulsoup4-4.6.3:
#       Successfully uninstalled beautifulsoup4-4.6.3
# Successfully installed JPype1-1.3.0 beautifulsoup4-4.6.0 colorama-0.4.4 konlpy-0.5.2
# [['이번', '이번투표', '투표', '남자', '심상', '심상정', '정', '정치인', '린', '린하다', '하다', '사람', '말', '쌉소리', '하', '하잖', '잖'], ['심상', '심상정', '정', '안', '안철수', '철수', '시일', '내', '조건', '양당', '양당체제', '체제', '종식', '기자', '기자회견', '회견', '김', '김동연', '동연', '회동', '제안', '노회', '노회찬', '찬', '정의', '정의당', '당', '페미들', '이상', '모습', '사욕', '0', '7', '8'], ['소수', '소수자인', '자인', '자신', '심상', '심상정이', '정이', '언급', '감동', '지지', '분', '겉멋', '대학교', '학술', '학술동아리', '동아리', '졸업', '후', '머저리'], ['심상', '심상정이', '정이', '안', '안철수', '철수', '제안', '긍정적', '수용', '트위터', '좌파', '의', '일부', '부정적', '반응'], ['철', '안', '어린', '의원', '치기', '미성숙', '생각', '정의', '정의당', '당', '지도부', '총체적', '난국', '내용', '사람', '심상', '심상정', '정', '후보', '이해', '도움', '가티브', '티브', '지도자']]

# %%
print(tokenized_doc[2])
# Out:
# ['소수', '소수자인', '자인', '자신', '심상', '심상정이', '정이', '언급', '감동', '지지', '분', '겉멋', '대학교', '학술', '학술동아리', '동아리', '졸업', '후', '머저리']

# %%
kkma.nouns(data["tweet"][2])
# Out:
# ['소수',
#  '소수자인',
#  '자인',
#  '자신',
#  '심상',
#  '심상정이',
#  '정이',
#  '언급',
#  '감동',
#  '지지',
#  '분',
#  '겉멋',
#  '대학교',
#  '학술',
#  '학술동아리',
#  '동아리',
#  '졸업',
#  '후',
#  '머저리']

# %% [markdown]
# 이제 각 단어에 정수 인코딩을 하는 동시에, 각 뉴스에서의 단어의 빈도수를 기록. 여기서는 각 단어를 (word_id, word_frequency)의 형태로 바꾸고자 합니다. word_id는 단어가 정수 인코딩된 값이고, word_frequency는 해당 뉴스에서의 해당 단어의 빈도수를 의미합니다. 이는 gensim의 corpora.Dictionary()를 사용하여 손쉽게 구할 수 있습니다. 전체 뉴스에 대해서 정수 인코딩을 수행하고, 세번째 댓글을 추출합니다.

# %%
from gensim import corpora
dictionary = corpora.Dictionary(tokenized_doc)
corpus = [dictionary.doc2bow(text) for text in tokenized_doc]
print(corpus[2])#세번째 댓글 출력
# Out:
# [(5, 1), (48, 1), (49, 1), (50, 1), (51, 1), (52, 1), (53, 1), (54, 1), (55, 1), (56, 1), (57, 1), (58, 1), (59, 1), (60, 1), (61, 1), (62, 1), (63, 1), (64, 1), (65, 1)]

# %%
corpus[2][0]
# Out:
# (5, 1)

# %%
tokenized_doc[:10]
# Out:
# [['이번',
#   '이번투표',
#   '투표',
#   '남자',
#   '심상',
#   '심상정',
#   '정',
#   '정치인',
#   '린',
#   '린하다',
#   '하다',
#   '사람',
#   '말',
#   '쌉소리',
#   '하',
#   '하잖',
#   '잖'],
#  ['심상',
#   '심상정',
#   '정',
#   '안',
#   '안철수',
#   '철수',
#   '시일',
#   '내',
#   '조건',
#   '양당',
#   '양당체제',
#   '체제',
#   '종식',
#   '기자',
#   '기자회견',
#   '회견',
#   '김',
#   '김동연',
#   '동연',
#   '회동',
#   '제안',
#   '노회',
#   '노회찬',
#   '찬',
#   '정의',
#   '정의당',
#   '당',
#   '페미들',
#   '이상',
#   '모습',
#   '사욕',
#   '0',
#   '7',
#   '8'],
#  ['소수',
#   '소수자인',
#   '자인',
#   '자신',
#   '심상',
#   '심상정이',
#   '정이',
#   '언급',
#   '감동',
#   '지지',
#   '분',
#   '겉멋',
#   '대학교',
#   '학술',
#   '학술동아리',
#   '동아리',
#   '졸업',
#   '후',
#   '머저리'],
#  ['심상',
#   '심상정이',
#   '정이',
#   '안',
#   '안철수',
#   '철수',
#   '제안',
#   '긍정적',
#   '수용',
#   '트위터',
#   '좌파',
#   '의',
#   '일부',
#   '부정적',
#   '반응'],
#  ['철',
#   '안',
#   '어린',
#   '의원',
#   '치기',
#   '미성숙',
#   '생각',
#   '정의',
#   '정의당',
#   '당',
#   '지도부',
#   '총체적',
#   '난국',
#   '내용',
#   '사람',
#   '심상',
#   '심상정',
#   '정',
#   '후보',
#   '이해',
#   '도움',
#   '가티브',
#   '티브',
#   '지도자'],
#  ['외부',
#   '외부인사',
#   '인사',
#   '추천',
#   '허',
#   '허경영',
#   '경영',
#   '안',
#   '안철수',
#   '철수',
#   '심상',
#   '심상정',
#   '정'],
#  ['사회',
#   '사회심리연구소',
#   '심리',
#   '연구소',
#   '의',
#   '김태형',
#   '소장',
#   '2010',
#   '2010년',
#   '년',
#   '심상',
#   '심상정',
#   '정',
#   '후보',
#   '후보측',
#   '측',
#   '요청',
#   '인물',
#   '책',
#   '공저',
#   '때',
#   '심리분석',
#   '분석',
#   '어른',
#   '얘기',
#   '10',
#   '10년전',
#   '전',
#   '책내용',
#   '내용',
#   '정의',
#   '정의당',
#   '당',
#   '니들',
#   '안',
#   '9',
#   '4'],
#  ['이재명', '윤', '열', '말', '정책', '심상', '심상정', '정'],
#  ['한국인', '한국인분', '분', '심상', '심상정', '정', '의원', '청와대'],
#  ['투자',
#   '입장',
#   '이재명',
#   '오너',
#   '자본',
#   '자본잠식',
#   '잠식',
#   '부실',
#   '부실기업',
#   '기업',
#   '윤',
#   '열',
#   '대가리',
#   '페이퍼',
#   '페이퍼컴퍼니',
#   '컴퍼니',
#   '심상',
#   '심상정',
#   '정',
#   '평',
#   '강',
#   '강소기업',
#   '소기업',
#   '주식',
#   '코',
#   '코인',
#   '인',
#   '광풍',
#   '나라',
#   '절대',
#   '꼬라지',
#   '한국',
#   '수준',
#   '상황',
#   '듯']]

# %%
print(corpus[2])#3번째 댓글 출력
# Out:
# [(5, 1), (48, 1), (49, 1), (50, 1), (51, 1), (52, 1), (53, 1), (54, 1), (55, 1), (56, 1), (57, 1), (58, 1), (59, 1), (60, 1), (61, 1), (62, 1), (63, 1), (64, 1), (65, 1)]

# %% [markdown]
# 총 학습된 단어의 개수를 확인

# %%
len(dictionary) #2128개 단어가 학습
# Out:
# 2128

# %% [markdown]
# #  LDA 모델을 훈련

# %% [markdown]
# 각 단어 앞에 붙은 수치는 단어의 해당 토픽에 대한 기여도를 보여줍니다. 또한 맨 앞에 있는 토픽 번호는 0부터 시작하므로 총 20개의 토픽은 0부터 19까지의 번호가 할당되어져 있습니다. passes는 알고리즘의 동작 횟수를 말하는데, 알고리즘이 결정하는 토픽의 값이 적절히 수렴할 수 있도록 충분히 적당한 횟수를 정해주면 됩니다. 여기서는 총 15회를 수행하였습니다. 여기서는 num_words=4로 총 4개의 단어만 출력하도록 하였습니다. 만약 10개의 단어를 출력하고 싶다면 아래의 코드를 수행하면 됩니다.

# %% [markdown]
# ### 토픽번호별 키워드중요도

# %% [markdown]
# #### 심상정의 경우 데이터의개수가300개 남짓하기 때문에 20개의 토픽별 키워드를 20개로 조정(다른 후보들은 7개)

# %%
import gensim
NUM_TOPICS = 20 #20개의 토픽(카테고리), k=20
ldamodel = gensim.models.ldamodel.LdaModel(corpus, num_topics = NUM_TOPICS, id2word=dictionary, passes=15)
topics = ldamodel.print_topics(num_words=20)
for topic in topics:
    print(topic)
# Out:
# (0, '0.031*"심상" + 0.029*"심상정" + 0.026*"정" + 0.021*"이재명" + 0.019*"4" + 0.019*"김" + 0.018*"5" + 0.018*"윤" + 0.017*"열" + 0.013*"철수" + 0.012*"1" + 0.012*"여론" + 0.012*"40" + 0.012*"39" + 0.011*"전" + 0.011*"0" + 0.010*"조사" + 0.010*"대선" + 0.010*"후보" + 0.010*"한국"')
# (1, '0.039*"심상" + 0.033*"당" + 0.032*"정" + 0.032*"심상정" + 0.029*"정의" + 0.026*"철수" + 0.025*"정의당" + 0.019*"안" + 0.014*"안철수" + 0.013*"후보" + 0.013*"조건" + 0.010*"3" + 0.010*"동연" + 0.010*"김동연" + 0.009*"저" + 0.008*"지대" + 0.007*"시일" + 0.007*"정치" + 0.007*"내" + 0.007*"심"')
# (2, '0.048*"심상" + 0.041*"정" + 0.037*"심상정" + 0.014*"정의" + 0.012*"당" + 0.008*"4" + 0.008*"윤" + 0.008*"이재명" + 0.008*"분" + 0.008*"주4일제" + 0.008*"일제" + 0.008*"정의당" + 0.007*"주" + 0.007*"우리" + 0.006*"후보" + 0.006*"대선" + 0.006*"남" + 0.006*"이번" + 0.006*"민주당" + 0.005*"무엇"')
# (3, '0.032*"심상" + 0.023*"심상정" + 0.023*"정" + 0.011*"후보" + 0.011*"김" + 0.010*"철수" + 0.007*"안" + 0.007*"이유" + 0.007*"정의" + 0.007*"건" + 0.007*"윤" + 0.006*"대통령" + 0.006*"비판" + 0.005*"안철수" + 0.005*"이재명" + 0.004*"심" + 0.004*"김동연" + 0.004*"동연" + 0.004*"국" + 0.004*"필요"')
# (4, '0.026*"심상" + 0.020*"심상정" + 0.020*"허" + 0.020*"허경영" + 0.020*"경영" + 0.020*"정" + 0.015*"다음뉴스" + 0.010*"거" + 0.010*"심상정의" + 0.010*"거기" + 0.009*"9" + 0.009*"2" + 0.009*"정의" + 0.008*"안" + 0.006*"사진관" + 0.005*"유시민" + 0.005*"유" + 0.005*"시민" + 0.005*"일" + 0.005*"0"')
# (5, '0.027*"심상" + 0.016*"정의" + 0.013*"당" + 0.012*"정도" + 0.012*"대선" + 0.010*"동안" + 0.010*"차기" + 0.010*"심상정도" + 0.008*"정의당" + 0.007*"20일" + 0.007*"19일" + 0.007*"결과" + 0.007*"로" + 0.007*"이틀" + 0.007*"19" + 0.007*"의" + 0.007*"20" + 0.007*"후보" + 0.007*"이번" + 0.006*"정"')
# (6, '0.033*"심상정" + 0.028*"심상" + 0.027*"정" + 0.012*"1" + 0.011*"심" + 0.011*"윤" + 0.010*"당" + 0.010*"이재명" + 0.009*"번" + 0.009*"상정" + 0.008*"나" + 0.008*"열" + 0.008*"철수" + 0.006*"2" + 0.006*"3" + 0.006*"김" + 0.006*"듯" + 0.006*"후보" + 0.006*"수" + 0.006*"씨"')
# (7, '0.039*"심상" + 0.033*"심상정" + 0.033*"정" + 0.016*"정의" + 0.013*"철수" + 0.013*"거" + 0.011*"유" + 0.011*"유시민" + 0.011*"시민" + 0.010*"7" + 0.009*"윤" + 0.009*"당" + 0.008*"진보당해산무효" + 0.008*"무효" + 0.008*"338" + 0.008*"민낯" + 0.008*"이" + 0.008*"진보당" + 0.008*"석방" + 0.008*"석기"')
# (8, '0.059*"심상" + 0.056*"정" + 0.054*"심상정" + 0.039*"안" + 0.038*"안철수" + 0.037*"철수" + 0.020*"3" + 0.018*"조건" + 0.016*"뉴스" + 0.014*"제안" + 0.014*"지대" + 0.014*"양당" + 0.012*"저" + 0.012*"3지대" + 0.011*"공조" + 0.011*"윤" + 0.011*"이재명" + 0.010*"종식" + 0.010*"체제" + 0.010*"다음"')
# (9, '0.024*"심상" + 0.012*"정의" + 0.012*"심상정" + 0.012*"정" + 0.006*"정의당의" + 0.006*"77" + 0.006*"걸림돌" + 0.006*"찬" + 0.006*"노회찬" + 0.006*"당의" + 0.006*"노회" + 0.006*"파" + 0.006*"정씨" + 0.006*"트위터" + 0.006*"윤" + 0.006*"심상정씨" + 0.006*"거" + 0.006*"원래" + 0.006*"남한" + 0.006*"음"')
# (10, '0.024*"정" + 0.024*"심상" + 0.022*"심상정" + 0.011*"당" + 0.011*"후보" + 0.011*"대선" + 0.009*"2" + 0.008*"안" + 0.008*"정의" + 0.008*"정의당" + 0.008*"중" + 0.008*"5" + 0.007*"필요" + 0.006*"문제" + 0.006*"김" + 0.006*"경선" + 0.006*"체제" + 0.006*"국" + 0.006*"일" + 0.005*"심"')
# (11, '0.028*"심상" + 0.025*"정" + 0.025*"심상정" + 0.010*"민주당" + 0.010*"듯" + 0.009*"이재명" + 0.007*"마음" + 0.007*"어디" + 0.007*"준석" + 0.007*"조" + 0.007*"대표" + 0.007*"대선" + 0.007*"거" + 0.007*"대통령" + 0.007*"야당" + 0.007*"이번" + 0.007*"때" + 0.006*"생각" + 0.006*"심" + 0.005*"당"')
# (12, '0.050*"심상" + 0.032*"정" + 0.032*"심상정" + 0.018*"당" + 0.016*"정의" + 0.013*"김" + 0.013*"안" + 0.012*"철수" + 0.010*"정의당" + 0.010*"심리" + 0.010*"방송" + 0.010*"안철수" + 0.009*"여자" + 0.008*"문제" + 0.008*"정이" + 0.008*"심상정이" + 0.008*"비판" + 0.007*"이재명" + 0.007*"거" + 0.007*"심리학자"')
# (13, '0.030*"심상" + 0.020*"심상정" + 0.020*"정" + 0.010*"후보" + 0.010*"당" + 0.010*"정의" + 0.010*"정의당" + 0.005*"이재명" + 0.005*"힘" + 0.005*"건" + 0.005*"전" + 0.005*"줄" + 0.005*"작용" + 0.005*"님" + 0.005*"국회의원" + 0.005*"국회의원이래" + 0.005*"나이만" + 0.005*"공수처법" + 0.005*"시장" + 0.005*"소아"')
# (14, '0.023*"심상" + 0.020*"정" + 0.020*"심상정" + 0.008*"거" + 0.008*"당" + 0.008*"수" + 0.008*"여성" + 0.008*"페미니스트" + 0.006*"정의" + 0.006*"정치" + 0.006*"3" + 0.006*"정치인" + 0.006*"지지" + 0.006*"대선" + 0.006*"남" + 0.006*"이대남" + 0.006*"이대" + 0.006*"차별" + 0.006*"금지법" + 0.006*"차별금지법"')
# (15, '0.053*"심상" + 0.035*"정" + 0.032*"심상정" + 0.017*"당" + 0.016*"정이" + 0.016*"심상정이" + 0.011*"이재명" + 0.011*"거" + 0.011*"성심" + 0.011*"성심당" + 0.008*"정의" + 0.008*"힘" + 0.008*"국민" + 0.005*"우리" + 0.005*"땜" + 0.005*"임" + 0.005*"선택지" + 0.005*"판" + 0.005*"정의당" + 0.005*"완주"')
# (16, '0.017*"분석" + 0.017*"심리분석" + 0.016*"심리" + 0.016*"심상정" + 0.013*"최" + 0.013*"188회" + 0.013*"최순실" + 0.013*"188" + 0.013*"어게인" + 0.013*"순" + 0.013*"모터스" + 0.013*"실" + 0.013*"도이치모터스" + 0.013*"도이치" + 0.013*"회" + 0.013*"준의" + 0.013*"상정" + 0.013*"다스" + 0.013*"심" + 0.012*"김"')
# (17, '0.039*"심상" + 0.035*"정" + 0.030*"심상정" + 0.014*"의원" + 0.009*"문" + 0.008*"분" + 0.007*"정의" + 0.006*"내" + 0.005*"임" + 0.005*"대선" + 0.005*"싸인" + 0.005*"다" + 0.005*"영광" + 0.005*"넥슨" + 0.005*"심상정님" + 0.005*"선" + 0.005*"사진" + 0.005*"랜선" + 0.005*"박" + 0.005*"랜"')
# (18, '0.029*"심상" + 0.025*"정" + 0.021*"심상정" + 0.014*"당" + 0.013*"후보" + 0.013*"고민" + 0.013*"노회" + 0.013*"노회찬" + 0.013*"찬" + 0.009*"최선" + 0.009*"인터뷰" + 0.009*"악" + 0.009*"국힘당" + 0.009*"지" + 0.008*"국" + 0.008*"선택" + 0.007*"힘" + 0.005*"0" + 0.005*"건" + 0.005*"김"')
# (19, '0.013*"심상" + 0.007*"김" + 0.007*"정이" + 0.007*"비난" + 0.007*"학자" + 0.007*"학문" + 0.007*"권력욕" + 0.007*"추측" + 0.007*"사회" + 0.007*"사회심리학" + 0.007*"심리학" + 0.007*"심리" + 0.007*"사회심리학자" + 0.007*"심상정이" + 0.007*"개개인" + 0.007*"궁예" + 0.007*"부분" + 0.007*"잘못" + 0.007*"자격" + 0.007*"여성혐오"')

# %%
print(ldamodel.print_topics())
# Out:
# [(0, '0.031*"심상" + 0.029*"심상정" + 0.026*"정" + 0.021*"이재명" + 0.019*"4" + 0.019*"김" + 0.018*"5" + 0.018*"윤" + 0.017*"열" + 0.013*"철수"'), (1, '0.039*"심상" + 0.033*"당" + 0.032*"정" + 0.032*"심상정" + 0.029*"정의" + 0.026*"철수" + 0.025*"정의당" + 0.019*"안" + 0.014*"안철수" + 0.013*"후보"'), (2, '0.048*"심상" + 0.041*"정" + 0.037*"심상정" + 0.014*"정의" + 0.012*"당" + 0.008*"4" + 0.008*"윤" + 0.008*"이재명" + 0.008*"분" + 0.008*"주4일제"'), (3, '0.032*"심상" + 0.023*"심상정" + 0.023*"정" + 0.011*"후보" + 0.011*"김" + 0.010*"철수" + 0.007*"안" + 0.007*"이유" + 0.007*"정의" + 0.007*"건"'), (4, '0.026*"심상" + 0.020*"심상정" + 0.020*"허" + 0.020*"허경영" + 0.020*"경영" + 0.020*"정" + 0.015*"다음뉴스" + 0.010*"거" + 0.010*"심상정의" + 0.010*"거기"'), (5, '0.027*"심상" + 0.016*"정의" + 0.013*"당" + 0.012*"정도" + 0.012*"대선" + 0.010*"동안" + 0.010*"차기" + 0.010*"심상정도" + 0.008*"정의당" + 0.007*"20일"'), (6, '0.033*"심상정" + 0.028*"심상" + 0.027*"정" + 0.012*"1" + 0.011*"심" + 0.011*"윤" + 0.010*"당" + 0.010*"이재명" + 0.009*"번" + 0.009*"상정"'), (7, '0.039*"심상" + 0.033*"심상정" + 0.033*"정" + 0.016*"정의" + 0.013*"철수" + 0.013*"거" + 0.011*"유" + 0.011*"유시민" + 0.011*"시민" + 0.010*"7"'), (8, '0.059*"심상" + 0.056*"정" + 0.054*"심상정" + 0.039*"안" + 0.038*"안철수" + 0.037*"철수" + 0.020*"3" + 0.018*"조건" + 0.016*"뉴스" + 0.014*"제안"'), (9, '0.024*"심상" + 0.012*"정의" + 0.012*"심상정" + 0.012*"정" + 0.006*"정의당의" + 0.006*"파" + 0.006*"노회" + 0.006*"걸림돌" + 0.006*"당의" + 0.006*"노회찬"'), (10, '0.024*"정" + 0.024*"심상" + 0.022*"심상정" + 0.011*"당" + 0.011*"후보" + 0.011*"대선" + 0.009*"2" + 0.008*"안" + 0.008*"정의" + 0.008*"정의당"'), (11, '0.028*"심상" + 0.025*"정" + 0.025*"심상정" + 0.010*"민주당" + 0.010*"듯" + 0.009*"이재명" + 0.007*"마음" + 0.007*"어디" + 0.007*"준석" + 0.007*"조"'), (12, '0.050*"심상" + 0.032*"정" + 0.032*"심상정" + 0.018*"당" + 0.016*"정의" + 0.013*"김" + 0.013*"안" + 0.012*"철수" + 0.010*"정의당" + 0.010*"심리"'), (13, '0.030*"심상" + 0.020*"심상정" + 0.020*"정" + 0.010*"후보" + 0.010*"당" + 0.010*"정의" + 0.010*"정의당" + 0.005*"이재명" + 0.005*"힘" + 0.005*"건"'), (14, '0.023*"심상" + 0.020*"정" + 0.020*"심상정" + 0.008*"거" + 0.008*"당" + 0.008*"수" + 0.008*"여성" + 0.008*"페미니스트" + 0.006*"정의" + 0.006*"정치"'), (15, '0.053*"심상" + 0.035*"정" + 0.032*"심상정" + 0.017*"당" + 0.016*"정이" + 0.016*"심상정이" + 0.011*"이재명" + 0.011*"거" + 0.011*"성심" + 0.011*"성심당"'), (16, '0.017*"분석" + 0.017*"심리분석" + 0.016*"심리" + 0.016*"심상정" + 0.013*"최" + 0.013*"188회" + 0.013*"최순실" + 0.013*"188" + 0.013*"어게인" + 0.013*"순"'), (17, '0.039*"심상" + 0.035*"정" + 0.030*"심상정" + 0.014*"의원" + 0.009*"문" + 0.008*"분" + 0.007*"정의" + 0.006*"내" + 0.005*"임" + 0.005*"대선"'), (18, '0.029*"심상" + 0.025*"정" + 0.021*"심상정" + 0.014*"당" + 0.013*"후보" + 0.013*"고민" + 0.013*"노회" + 0.013*"노회찬" + 0.013*"찬" + 0.009*"최선"'), (19, '0.013*"심상" + 0.007*"김" + 0.007*"심상정이" + 0.007*"심리학" + 0.007*"사회심리학자" + 0.007*"정이" + 0.007*"개개인" + 0.007*"궁예" + 0.007*"잘못" + 0.007*"부분"')]

# %% [markdown]
# # 문서 관점에서 topic과 document 알기(문서별 토픽 분포 보기)

# %% [markdown]
# 토픽별 단어 분포는 위에서 확인하였음. 문서별 토픽 분포에 대해 확인을 위해 이미 훈련된 LDA모델인 ldamodel[]에 전체 데이터가 정수 인코딩 된 결과를 넣은 후 확인 가능.

# %% [markdown]
# 상위 5개의 문서에 대해서만 토픽분포 확인

# %%
for i, topic_list in enumerate(ldamodel[corpus]):
    if i==5:
        break
    print(i,'번째 문서의 topic 비율은',topic_list)
# Out:
# 0 번째 문서의 topic 비율은 [(8, 0.9472222)]
# 1 번째 문서의 topic 비율은 [(1, 0.24856922), (8, 0.41791782), (17, 0.30922723)]
# 2 번째 문서의 topic 비율은 [(2, 0.9525)]
# 3 번째 문서의 topic 비율은 [(12, 0.94062495)]
# 4 번째 문서의 topic 비율은 [(10, 0.96199995)]

# %% [markdown]
# 위의 출력 결과에서 (숫자, 확률)은 토픽 번호와 해당토픽이 해당문서에서 차지하는 분포도를 의미.예를 들어 2번째 문서의 토픽 비율에서 (5, 0.16109002)은 5번 토픽이 16%의 분포도를 가지는 것을 의미

# %% [markdown]
# 좀 더 깔끔한 형태의 데이터프레임 형식으로 출력

# %%
def make_topictable_per_doc(ldamodel, corpus):
    topic_table = pd.DataFrame()

    # 몇 번째 문서인지를 의미하는 문서 번호와 해당 문서의 토픽 비중을 한 줄씩 꺼내온다.
    for i, topic_list in enumerate(ldamodel[corpus]):
        doc = topic_list[0] if ldamodel.per_word_topics else topic_list            
        doc = sorted(doc, key=lambda x: (x[1]), reverse=True)
        # 각 문서에 대해서 비중이 높은 토픽순으로 토픽을 정렬한다.
        # EX) 정렬 전 0번 문서 : (2번 토픽, 48.5%), (8번 토픽, 25%), (10번 토픽, 5%), (12번 토픽, 21.5%), 
        # Ex) 정렬 후 0번 문서 : (2번 토픽, 48.5%), (8번 토픽, 25%), (12번 토픽, 21.5%), (10번 토픽, 5%)
        # 48 > 25 > 21 > 5 순으로 정렬이 된 것.

        # 모든 문서에 대해서 각각 아래를 수행
        for j, (topic_num, prop_topic) in enumerate(doc): #  몇 번 토픽인지와 비중을 나눠서 저장한다.
            if j == 0:  # 정렬을 한 상태이므로 가장 앞에 있는 것이 가장 비중이 높은 토픽
                topic_table = topic_table.append(pd.Series([int(topic_num), round(prop_topic,4), topic_list]), ignore_index=True)
                # 가장 비중이 높은 토픽과, 가장 비중이 높은 토픽의 비중과, 전체 토픽의 비중을 저장한다.
            else:
                break
    return(topic_table)

# %%
topictable = make_topictable_per_doc(ldamodel, corpus)
topictable = topictable.reset_index() # 문서 번호을 의미하는 열(column)로 사용하기 위해서 인덱스 열을 하나 더 만든다.
topictable.columns = ['문서 번호', '가장 비중이 높은 토픽', '가장 높은 토픽의 비중', '각 토픽의 비중']
topictable[:10] #상위 10개 댓글별 비중이 높은 토픽은 무엇이고 얼만큼 차지하는지
# Out:
#    문서 번호  ...                                           각 토픽의 비중
# 0      0  ...                                   [(8, 0.9472222)]
# 1      1  ...  [(1, 0.24858074), (8, 0.41790625), (17, 0.3092...
# 2      2  ...                                      [(2, 0.9525)]
# 3      3  ...                                   [(12, 0.940625)]
# 4      4  ...                                 [(10, 0.96199995)]
# 5      5  ...                  [(4, 0.24255252), (8, 0.6931618)]
# 6      6  ...                  [(8, 0.4216423), (12, 0.5546735)]
# 7      7  ...                                  [(8, 0.89444447)]
# 8      8  ...                                 [(17, 0.89444447)]
# 9      9  ...                                   [(0, 0.9736111)]
#
# [10 rows x 4 columns]

# %% [markdown]
# # 단어 관점에서topic과 documents를 알기

# %%
keyword="노동자"
id_list=[]
for i in range(len(data)):
  if keyword in tokenized_doc[i]:
    print("해당 단어가 들어간 댓글:",i,"번 댓글",":",data['tweet'][i])
    for y in range(len(tokenized_doc[i])):
      if tokenized_doc[i][y]==keyword:
        key_id=corpus[i][y]
        print("해당단어의 아이디는",key_id)
        id_list.append(key_id[0])
# Out:
# 해당 단어가 들어간 댓글: 77 번 댓글 : 미쳐도 곱게 미쳐야지 숙명이 양당체제 종식인데 노동자 기반으로 한 당은 왜 들어가서 허송세월 했는지 결국 안철수 심상정 양당체제 종식 나의 숙명 안철수에 만남 제안 JrmWj27I26
# 해당단어의 아이디는 (33, 1)
# 해당 단어가 들어간 댓글: 266 번 댓글 : 심상정 이재명 정체성 엘리트 주의자 노동자 김태형 심리분석 다스뵈이다 NgUUovTpPH 출처 YouTube bMT8DtKqjQ
# 해당단어의 아이디는 (113, 1)
# 해당 단어가 들어간 댓글: 303 번 댓글 :  그러면서 김 소장은 무의식적으로 심 후보가 스스로를 노동자라고 생각 안 한다 라고도 했다 노동운동을 했으니까 의식적으로 노동자라고 생각하는 것 이라는 주장이다 심상정 대표 의원 세비 제한법 발의 원문보기 nnS5Z7At4P
# 해당단어의 아이디는 (81, 1)
# 해당 단어가 들어간 댓글: 304 번 댓글 : 김어준류에겐 이재명에게 우호적인가 아닌가가 노동자 정체성을 가르는 잣대 가령 전태일이 살아돌아와 이재명 비판하면 전태일도 노동자 정체성이 부족하다고 할 놈들 진영논리에 미치면 사람이 이래 됨 심상정은 노동운동사의 산 증인 가운데 한 명임
# 해당단어의 아이디는 (369, 1)

# %%
# 노동에 관련된 토픽(+토픽에 영향주는 키워드) 찾기
term_topic_dist = ldamodel.get_term_topics(33, minimum_probability=0)
sorted_term_topic = sorted(term_topic_dist, key=lambda x:x[1], reverse=True)
sorted_term_topic
# Out:
# [(8, 0.037250947),
#  (1, 0.013670907),
#  (12, 0.008839541),
#  (3, 0.0039988784),
#  (10, 0.0032531847),
#  (15, 6.833149e-05),
#  (0, 3.557261e-05),
#  (4, 2.7625235e-06),
#  (6, 1.2914711e-06)]

# %%
topics[8]
# Out:
# (8,
#  '0.059*"심상" + 0.056*"정" + 0.054*"심상정" + 0.039*"안" + 0.038*"안철수" + 0.037*"철수" + 0.020*"3" + 0.018*"조건" + 0.016*"뉴스" + 0.014*"제안" + 0.014*"지대" + 0.014*"양당" + 0.012*"저" + 0.012*"3지대" + 0.011*"공조" + 0.011*"윤" + 0.011*"이재명" + 0.010*"종식" + 0.010*"체제" + 0.010*"다음"')

# %%
for n in range(len(id_list)):
  term_topic_dist = ldamodel.get_term_topics(id_list[n], minimum_probability=0)
  sorted_term_topic = sorted(term_topic_dist, key=lambda x:x[1], reverse=True)
  print("토픽중요도:",round(int(sorted_term_topic[0][1]*100),2),"%","토픽번호 및 해당키워드중요도:",topics[sorted_term_topic[0][0]])
# Out:
# 토픽중요도: 3 % 토픽번호 및 해당키워드중요도: (8, '0.059*"심상" + 0.056*"정" + 0.054*"심상정" + 0.039*"안" + 0.038*"안철수" + 0.037*"철수" + 0.020*"3" + 0.018*"조건" + 0.016*"뉴스" + 0.014*"제안" + 0.014*"지대" + 0.014*"양당" + 0.012*"저" + 0.012*"3지대" + 0.011*"공조" + 0.011*"윤" + 0.011*"이재명" + 0.010*"종식" + 0.010*"체제" + 0.010*"다음"')
# 토픽중요도: 1 % 토픽번호 및 해당키워드중요도: (16, '0.017*"분석" + 0.017*"심리분석" + 0.016*"심리" + 0.016*"심상정" + 0.013*"최" + 0.013*"188회" + 0.013*"최순실" + 0.013*"188" + 0.013*"어게인" + 0.013*"순" + 0.013*"모터스" + 0.013*"실" + 0.013*"도이치모터스" + 0.013*"도이치" + 0.013*"회" + 0.013*"준의" + 0.013*"상정" + 0.013*"다스" + 0.013*"심" + 0.012*"김"')
# 토픽중요도: 1 % 토픽번호 및 해당키워드중요도: (17, '0.039*"심상" + 0.035*"정" + 0.030*"심상정" + 0.014*"의원" + 0.009*"문" + 0.008*"분" + 0.007*"정의" + 0.006*"내" + 0.005*"임" + 0.005*"대선" + 0.005*"싸인" + 0.005*"다" + 0.005*"영광" + 0.005*"넥슨" + 0.005*"심상정님" + 0.005*"선" + 0.005*"사진" + 0.005*"랜선" + 0.005*"박" + 0.005*"랜"')
# 토픽중요도: 0 % 토픽번호 및 해당키워드중요도: (12, '0.050*"심상" + 0.032*"정" + 0.032*"심상정" + 0.018*"당" + 0.016*"정의" + 0.013*"김" + 0.013*"안" + 0.012*"철수" + 0.010*"정의당" + 0.010*"심리" + 0.010*"방송" + 0.010*"안철수" + 0.009*"여자" + 0.008*"문제" + 0.008*"정이" + 0.008*"심상정이" + 0.008*"비판" + 0.007*"이재명" + 0.007*"거" + 0.007*"심리학자"')
